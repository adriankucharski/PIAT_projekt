# %%
from typing import Dict, Generator, Iterator, Tuple
import numpy as np

import warnings
from keras.utils import to_categorical

warnings.filterwarnings("ignore")
warnings.simplefilter(action="ignore", category=FutureWarning)
from dataset import load_tokenized_sentences

STEP = 2
MAX_INPUT_LEN = 100
BATCH_SIZE = 2048

dataset1 = load_tokenized_sentences("../datasets/pickled/chars/bajki-extend_str.pickle")
dataset2 = load_tokenized_sentences("../datasets/pickled/chars/books-raw_str.pickle")
dataset = dataset2
CHARS = sorted(list(set(dataset)))
C2I = dict((c, i) for i, c in enumerate(CHARS))
I2C = dict((i, c) for i, c in enumerate(CHARS))

print("Corpus length:", len(dataset))
print("Total chars:", len(CHARS))

def text_generator(
    dataset: str,
    c2i: Dict[str, int] = C2I,
    max_len: int = MAX_INPUT_LEN,
    step: int = STEP,
    shuffle=True,
    batch_size: int = 1024,
    sparse: bool = False
) -> Iterator[Tuple[np.ndarray, np.ndarray]]:
    sequences = []
    last_chars = []
    for i in range(0, len(dataset) - max_len, step):
        sequences.append([c2i[c] for c in dataset[i : i + max_len]])
        last_chars.append(c2i[dataset[i + max_len]])
    print("Number of sequences:", len(sequences))

    chars = len(c2i)
    x = np.array(sequences, dtype=int)
    y = np.array(last_chars, dtype=int)
    while True:
        if shuffle:
            p = np.random.permutation(len(sequences))
        for i in range(0, len(sequences) - batch_size + 1, batch_size):
            indx = np.s_[i:i+batch_size]
            if shuffle:
                indx = p[indx]
            _x = to_categorical(x[indx], chars)
            _y =  y[indx]
            if not sparse: 
                _y = to_categorical(_y, chars)
            yield _x, _y
# Out:
# Corpus length: 46877858
# Total chars: 44

# %%
gen = text_generator(
    dataset, C2I, MAX_INPUT_LEN, STEP, shuffle=True, batch_size=BATCH_SIZE, sparse=True
)
a, b = next(gen)
print(a.shape, b.shape)
# Out:
# Number of sequences: 23438879
# (2048, 100, 44) (2048,)

# %%
from keras.layers import LSTM, Dense, Dropout, Bidirectional, Input, Embedding, LeakyReLU
from keras.models import Sequential
from keras import optimizers, activations, regularizers, losses

def create_model(max_input_len: int, total_chars: int):
    model = Sequential([
        Input((max_input_len, len(CHARS))),
        Bidirectional(LSTM(128, return_sequences=True)),
        LSTM(256),
        Dropout(0.2),
        Dense(256, activation='relu', kernel_regularizer=regularizers.l2(1e-2)),
        Dense(total_chars)
    ])
    model.compile(loss=losses.SparseCategoricalCrossentropy(from_logits=True), optimizer=optimizers.Adam(1e-3))
    return model

model = create_model(MAX_INPUT_LEN, len(CHARS))
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_2 (Bidirectio  (None, 100, 256)         177152
#  nal)
#
#  lstm_5 (LSTM)               (None, 256)               525312
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_4 (Dense)             (None, 256)               65792
#
#  dense_5 (Dense)             (None, 44)                11308
#
# =================================================================
# Total params: 779,564
# Trainable params: 779,564
# Non-trainable params: 0
# _________________________________________________________________

# %%
import tensorflow as tf

class PredictCallback(tf.keras.callbacks.Callback):
    def __init__(
        self,
        seed_text: str,
        next_chars: int,
        max_input_len: int,
        temperature: float = 1.0,
        c2i=C2I,
        i2c=I2C,
    ):
        self.seed_text = seed_text.lower()
        self.next_chars = next_chars
        self.max_input_len = max_input_len
        self.temperature = temperature
        self.c2i = c2i
        self.i2c = i2c

    def sample(self, preds: np.ndarray):
        preds = tf.math.softmax(preds, axis=-1)
        preds = np.asarray(preds).astype("float64")
        preds = np.log(preds) / self.temperature
        exp_preds = np.exp(preds)
        preds = exp_preds / np.sum(exp_preds)
        probas = np.random.multinomial(1, preds, 1)
        return np.argmax(probas)

    def on_epoch_begin(self, epoch, logs=None):
        generated = ""
        sentence = self.seed_text[-self.max_input_len:]
        print(sentence)
        for _ in range(self.next_chars):
            x_pred = np.zeros((1, self.max_input_len, len(self.c2i)))
            for t, char in enumerate(sentence):
                x_pred[0, t, self.c2i[char]] = 1.0
            preds = self.model.predict_on_batch(x_pred)[0]
            next_index = self.sample(preds)
            next_char = self.i2c[next_index]
            sentence = sentence[1:] + next_char
            generated += next_char
        print("Epoch:", epoch, "Seed:", self.seed_text)
        print("Generated:", generated)
        return generated

# %%
model.fit(
    gen,
    steps_per_epoch=len(dataset) // STEP // BATCH_SIZE,
    epochs=10,
    verbose=1,
    callbacks=[
        PredictCallback("dawno temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i", 500, MAX_INPUT_LEN, 0.5, C2I, I2C),
        PredictCallback("dawno temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i", 500, MAX_INPUT_LEN, 0.2, C2I, I2C),
        PredictCallback("dawno temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i", 500, MAX_INPUT_LEN, 0.1, C2I, I2C),
        tf.keras.callbacks.ModelCheckpoint('../lstm_models/chars/model_best_4.h5', monitor='loss', save_best_only=True, save_weights_only=False)
    ],
)
# Out:
#  temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Epoch: 0 Seed: dawno temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Generated: em  isrpp   odywyaao im a d  t  a a  ed aa,aeu za tns di t      n  oy   a epr en cee e l wg csoe      n     aas  n  a e  dzw     ee y ei    i e  a a  o a    s , ng t o   o ł eo    oz  oioao tsk     w eaysszn rsej a  d odoearw.w oacno iim  nec  eri a    sewyo  eć ł e i  z  w eeta  ac  s e i    yer aae  o w  ea  tły z e  rai.io  n eo   i     t aoaka   n aas   aa  b i m a    e ao w opane   da toeęa    n     ac i a oasaiyina ie c e deca   iasc.d jt  zeo  o o zp adjeist e   y e t cayo w ię  naboa  a
#  temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Epoch: 0 Seed: dawno temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Generated:                             a  z    i            t              a o             o                            ia a               a                                            e                     o                    a          a a   a              a   e    a   e   a                       a                            a                             o    e       e                  i          a                 t                                                   o        a     e
#  temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Epoch: 0 Seed: dawno temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Generated:
# Epoch 1/10
# 11444/11444 [==============================] - 1614s 141ms/step - loss: 1.9061
#  temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Epoch: 1 Seed: dawno temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Generated:  zanim się w swoim na bardzo wysokość.ten wszystkiego nie przeczyna się ze strony przygromadzy, a pan przecie się mieć zapalać się do niego na to jasne oczy z przeszłych postaci w dobrze i do ciego w oczach po przeciwnikaniu wyrazem w głowy i już przechodziło się od wargi i chodząc trzeba na wszystkich służących z tego porwały na szczęście którego obraz po salonych stanu głodnych i sama zakrzywiał się z powróciwem w prawo niebie przeciw palenka rozpoczął się panowania się do przechodzić miał w k
#  temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Epoch: 1 Seed: dawno temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Generated:  pod swoją pod swego pod podniem i pod tego samego stanie wysokość i wystawiał się z początku się po powietrze pod siebie w tym sposób sposób powiedział i wyszedł się na samego strony i wysokiego zasadzanego wysokości i za swego pod swego sposób jak się w podziane z siebie i wysoko spostrzegł się z powodu i pod tym sposób i od powietrzu i podobne w niej podobne spostrzegł się po powietrze wysokiego zawołał się na stronę w swoich sposób i pod swoją podobnych postanowił się po połową i postanowił
#  temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Epoch: 1 Seed: dawno temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Generated:  pod strony i pod strony w każdym stanie się w nich wyszedł i pod siebie i pod podwórzem i w swoją siebie z niepokojem i pod samego pod strony pod samego pod siebie pod siebie i pod strony i pod swoją wysokość i pod siebie i spostrzegł się w powietrze i w każdym wysokie pod swoją siebie w tej strony pod swojej strony i pod strony starannie z każdym się z niego na szczęście wyszedł z każdym się w każdym siebie wysokiego w karach przeciw pod swoją siebie i pod podobnego pod samego strony i pod str
# Epoch 2/10
# 11444/11444 [==============================] - 1618s 141ms/step - loss: 1.6186
#  temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Epoch: 2 Seed: dawno temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Generated:  po okródach na widok stary pochodziły mieszkać za dobrym wypadkiem i pod staną kulasz ponosić wydawał przez czynić pod uczyniem pod naszym przeciwników.wieczorem zaczynał się za wielkie i w swoich roku przypadkiem.nie wiem pokazać za nim w konie serca, że nie miałem ci przyjdzie przyszło wali się na prostokie spojrzał na to mały do przed swawymi podziwem, ale tak dobrze, że jak się o przeszkadzach wykonać moje spokojnie, za powierzchnię się stało rozpowiadać się na przykład od kolana.pierwszy s
#  temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Epoch: 2 Seed: dawno temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Generated:  rozpaczy po stanie przez chwilę od przyjaciół i zaraz począł się przed szybkością pod powierzchnię i po policzku pod postaci wystawiał mi po słowach i zaczęła się powiedzieć przed podwórzem i powiedział też po polskiej stopniu przyjaciół i pod przyjaciół i pod przerwał za powierzchnię w powietrzu i pod czym miał wyraz z nieprzyjacielnym i pod starym do wielkiego siebie do wyspy przyjaciół w porządnie pod szybkiego rozpaczy i pod podróży przez cały przez się na pokoju w podziwca i postanowił się
#  temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Epoch: 2 Seed: dawno temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Generated:  pod stronę pod podobnymi pod podobnymi pod podobnymi pod podróży i pod podobnymi pod podobnymi pod podróży pod starym podróży i pod starym pod stronym pokoju i pod strony przez się pod stronę pod strachu w stanie pod strony i pod strony pod strachu i pod strachu pod starym pod podniesieniem pod strachu pod strony pod podróży i pod strony pod starym pod strachu pod stronym starym przedstawieniem zapomniał się na podwórze i przyjaciela w stanie pod starym starym pod wykonaniem i pod podobnymi prz
# Epoch 3/10
# 11444/11444 [==============================] - 1625s 142ms/step - loss: 1.5609
#  temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Epoch: 3 Seed: dawno temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Generated:  skrzydłością na pościech pod nim był zapewne, jak kiedy wielkie pod naszym przyjaciółmi chrześcijańskim w ognie zbliżył się niepodobne na drogę przed pomocą konia przez tym postacią w tej chwili, usłyszone z nich na trzydziestu stopnia ustanawiał się na kilka garskim przyjaciółki umychali.nie był to zdanie, jakie czy tak najlepsze była poprosiła mu w polu na drugie zaprzeczone róże, a tak był zapewne za stołanie i przedmioty od jednego umiejących z sokoła.na chwilę złożył się w tej chwili w pol
#  temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Epoch: 3 Seed: dawno temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Generated:  pod nim i powiedział na podwórze i przyszłość w niej pod strony i oddalił się na podwórzach i przyjdzie i wyszedł na starych pokoju w swym pokoju w stanie na sam przyjaciółkę i przed siebie przed nim z przyjaciółką na powierzchnię i pod powietrzami pani przed nim w wielkim powiedzianiu i przez pana de la mole przecież wyszedł na pana rzeczywistości i powiedział mu się na podwórze przed powierzchnią i przed siebie w podwórzu i pod wielkiem szczególnym przez morza i powiedział przed podwórzem i p
#  temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Epoch: 3 Seed: dawno temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Generated:  przyszłość i przed siebie przez powiedział przed siebie i pod powierzchnią starannie pod nim pod powierzchnią pod oknami pod podwórzami do podstawa się w polu przed siebie i pod powierzchnią przez powierzchnię i pod powierzchnią przyszłością po polsku i przez podwórza przez pod stronę i pod powierzchnią pod powierzchnią przez pod starego pod powierzchnią pod podwórzem na podwórzach przyszłości i pod powierzchnią przed siebie w stanie przed siebie i przed siebie przed siebie i przyszłość i powie
# Epoch 4/10
# 11444/11444 [==============================] - 1637s 143ms/step - loss: 1.5292
#  temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Epoch: 4 Seed: dawno temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Generated:  od spokoju, której mnie wyszedł, a nie podwójnik sterczał go bieganie.miał pod czasem po drodze wyniosła się w jej stronie północnych w korytarzu, a czekając obłoki, a zapał odpowiedział w tym porządku, w którym stary wykonał się w nim w nocy, jak tak i wystrające go coraz szczęścia.gdy przez cały jego miasta wyżej takiej przerażenia nie przedstawiając się za starością i wydawały się w sobie w ramiona, w którym wygrały się za nim za pana michała i nie można przychylony i jego charakter wielkieg
#  temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Epoch: 4 Seed: dawno temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Generated:  począł się w powiedzieć na dobrowolnie i wystarczyło się na podwórzu w stronę pod podnoszącego w podobnej sposób pod wielkim krokiem i po czym jak na starości powiedział w swojej podziwu i przed nim pod nim w poraniach podniósł się na podwórzu.po czym jest stary pod wielkim wysokością i nie wystarczył przez dom starości w podobnej stronie pod powierzchnymi kolegiem i przez drogę w sposób za nim pod nim szczerości i przed nim spojrzał na przestrzeni i przed nią od powodu z niego nie pomyślał sob
#  temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Epoch: 4 Seed: dawno temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Generated:  podniesionych pod stronę i pod powierzchnią pod nim pod starością przez domu w stanie pod stroną w stanie pod starością pod szerokością i pod powierzchnią i pod powierzchnią w stanie się po prostu w podobnej stronie pod nim w porządku w podobnej podobnej podobnej przedmiocie i podniesionych w podobnej porze się na pokoju i pod stroną pod starością pod wielkim wysokością w podobnych pokoju i podniesionych pod powierzchnią pod powierzchnią w stronę pod koniec w podobnej stronie pod starością w po
# Epoch 5/10
# 11444/11444 [==============================] - 1593s 139ms/step - loss: 1.5089
#  temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Epoch: 5 Seed: dawno temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Generated:  tak od panny polityka i pod ogórami z siebie.sławy nie potrafił się w pani nie poprowadzić, że kto pan mieli powiedzieć.czy tak się nie odpowie u takich okręcać się na pierwszy początku nieubłagania i pozwoli następca i inni przebiły między nimi w promieniętej chwili nie pozwalając się zawsze za wysokość i przecież widok mężczyzny nie było i nie ostać z wielkim starem poczęły mieć w pokoju i szlachcic nie postawił się do powietrzu, w którym nie dawał nie było dostać na mnie i nie zrozumiał się
#  temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Epoch: 5 Seed: dawno temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Generated:  pod wielkim oddziałym straszliwym wielką przestrzeniem i zawsze z nimi pod nim zapalił się i wyszedł na podróżnikach i przez chwilę się w stronę szacunka przypominała się na podwórze, a za nimi przez chwilę postanowił się w porządku za nim na podwórze pod straszliwością i pozostawiając z powrotem i pod wielkim politycznym przestrachem w porządku, zapaliła się na stronę i przez chwilę po podziwej podziwej od strony pod powietrzem po czym nie wiedział na wieki starego w stoliku i po czym wszystko
#  temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Epoch: 5 Seed: dawno temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Generated:  postawił się na podróżnikach i pod straszliwym straszliwym porządkiem po czym wyszedł z nimi i pod powietrzem i pod straszliwym porządkiem po politycznym przestrzeni przez siebie pod wielkim podróżnikiem i przez chwilę przez chwilę po politycznym porządku pod straszliwym politykiem pod straszliwym przestrzeniem w obronie pod straszliwym porządkiem przez chwilę pod powietrzem zapalił się na podróży i po czym po powietrzu podniósł się w porządku i pod straszliwym starem pod powietrzem i przez chw
# Epoch 6/10
# 11444/11444 [==============================] - 1598s 140ms/step - loss: 1.4939
#  temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Epoch: 6 Seed: dawno temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Generated:  czasem przypatrzał się jak strzelaną polskie występek i zamiaru wypadkiem w nich pierwsze i trzy starożytne wielkie jak gdyby przestraszają się do poprzednich dzieci i wybiegł wyroki policzek z pierwszą sobą z dziennikami.jak mówił z niego wkrótce tak było wydarzenie się z daleka, że nie ustąpił z nią wielkie tych siebie wielkiego podobnego wyspy swoim odczytanem spokojnym i podniosła je na podskokach.a przecie za wielkie bogaczy już się pokrywają króla i wybranych pracy w niewyspanie do domu.p
#  temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Epoch: 6 Seed: dawno temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Generated:  podniósł się z nimi i zapach w podziwu podniósł się w krzyżacy i podniósł się i podniósł się z końca i postanowił zapewnić na portret i podniósł się na stronę i podniósł się na podwórzu i nie było w tym sposób pod szerokie pod szyję i podczas podniósł w stronę wojny i zapraszał mu za pomocą i zaczął się podnosić po pokoju i nie poprzednio nie powiedział po drugiej stronie i przez końca zaczęła się wypowiedzieć na powrotne podobne pod konieczką i zaprzeczał na twarzy i powiedział potem na krzywd
#  temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Epoch: 6 Seed: dawno temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Generated:  podniósł się do siebie i zapomniał na siebie i podniósł się z nimi i podniósł się do siebie i podniósł się do siebie i podniósł się z nim pod portretami i zapamiętał się z nim pod powierzchnię i podniósł się w podobnym pokoju i podniósł się do pokoju i podniósł się na podróży i podniósł się na podróży i zapomniał na podróż i wyszedł do pokoju i podniósł się do pokoju i podniósł się na podróży i podniósł się do siebie i podniósł się do pokoju i podniósł się na podróży i podniósł się do pokoju i
# Epoch 7/10
# 11444/11444 [==============================] - 1593s 139ms/step - loss: 1.4831
#  temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Epoch: 7 Seed: dawno temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Generated:  ojciec z nieboszczykiem, a przede wszystkim z koniecznością wyszli w krajach i w ten sposób w szkole przywileju za dziesięć krzeczowskich z pierwszej samej przed nim i pierwszy z tobą nie ustanowić człowieka, co wiecznie w tym miejscu rozrywając na niego na starannie i patrzył na widok głowy i w sercu na polu w galerii, podstawionym okrutne panny galery, przed postaciami prawa z drugiej porwie w miejscu pod wieków w chwili w naszej chwili zamknął coraz do podróż na wspomnienie i przez artykułem
#  temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Epoch: 7 Seed: dawno temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Generated:  podnosząc w sobie za pomocą i nie mogła podnieść się w podobnej postaci na wieś w podobnym pokoju i za to wielkie pod stronę podobnych w podstawie od wszystkich podobnych i podobnych starożytnej do wieczności i zastanowienia w podziemiach do końca przez wielkie pod podróżnym okrutnym przez podobne wysokość i na podwórze i podróżniczej czy powiedział się w wielkiej porze w sposób na to za pomocą i podobno z konieczności i zapalił się w powietrzu i z niej pod podnoszą się na wszystkim spojrzenie
#  temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Epoch: 7 Seed: dawno temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Generated:  podnosił się w stronę i zaczęła się podnosić z niej pod wieczność i podobnych w podróży i w podobnym stanie zapalił się w podróż i powiedział po tej chwili w ten sposób w tej chwili w tej chwili po tym wyspie podnosił się w ten sposób i podnosił się na niego w podróży i podnosił się z niej w podróży i podniósł się do podobnego podobnego podobnego podobnego podobnego pod wiecznością i podnosił się w podróż i podniósł się z niej w podróży i podniósł się na wieś w podróż i w tym wyspie podnosił si
# Epoch 8/10
# 11444/11444 [==============================] - 1596s 139ms/step - loss: 1.4740
#  temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Epoch: 8 Seed: dawno temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Generated:  starannie do siebie, nie więc jeszcze ustawił przed przeszłami z naszych wesołych i głębinę i siostrzeńców.nie mogłem być do szczędzania i z daleka do domu, który zaczęła posłużyć, a nawet się z nim nie potrzebuje rzekł głowę mało, a przy tym w szczęście pod tym niemal wielki starzec jest czynimy z określenia i nie stało się na to potajemnie przy pojedzeniu niewolników, a jeszcze miał przez wyjawiło z posypniętem do końca, a do przeciwnej filozofii i posadziwszy na słowa ze strony i zaczęła się
#  temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Epoch: 8 Seed: dawno temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Generated:  zawsze za nim nie może przecie wysłuchać i pod wiecznym podobne pod pokoju i powiedział w tym przedsięwzięciu i w niewoli w niebie przed siebie w tym postaci miał na przykład przed postacią w swoim pokoju i w podróży w starej wojennych wysokości jest w szczęściu w powietrzu i pod wiecznym przyjacielem w powietrzu, a potem pod wiecznym niewinnej podróży na przeciwnym pokoju i w starożyciele występuje po starego rozpaczy i szczęścia i wielkie wysokie przyjaciele przed nim w podróżni występuje w p
#  temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Epoch: 8 Seed: dawno temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Generated:  pod strachem i przyszłych w podróżni po przyjacielu i powiedział po starego pod koniem i pod powietrzem i powiedział po przeciwnym pokoju i pod wiecznym podobnym podróżywem pod wiecznym podobnym podwórzem i przeciw niej pod powietrzem i pod pozostałym starem przed siebie i przyszło na przeciwnym pokoju i powiedział po przeciwnym pokoju i pod wiecznym przeciwnym przeciwnym podróżywym podróży.nie mogłem powiedzieć z niego w stanie i powiedział z powrotem i powinien zawsze powiedzieć, że powiedzia
# Epoch 9/10
# 11444/11444 [==============================] - 1596s 139ms/step - loss: 1.4665
#  temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Epoch: 9 Seed: dawno temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Generated:  chcąc się mogła wolno powiedzieć nie zaś jego wyprawić w walki i postanowił jej wiadomość o rzeczy do niego z wielką wiekiem, a musi być wielkie dobroczynność radziwiłł i bardzo nie mógł w tym sposobić, bo mnie tak nie upodoba się w podobnych słowach i nie ma wielkiego politycznych kołatków.co to jest to nie obawiać się w tym zapałek ostatniej części i zmorze i ostatniej kobiety, coraz pokryte dziecię i pojedynek, pokryty na nasz drzwi w korytarzu przerażających się z samego widnokręgu.tymczase
#  temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Epoch: 9 Seed: dawno temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Generated:  nie powinni nie powiedzieć na to za pomocą i powiedział to na to największym powiedział do siebie i powiedział z nim w tym samym zachodzie i nie powinno być za pomocą i powiedział nie mógł zapomnieć na tym, że nie powinno być powiedział mi to powiedział po tym powietrze i powiedział pan do niego na to za niego i za to powiedział po tym nie zamieszkał i podrzucił na podwórze i podobne po obiedzie i podniesienia się z koniecznego powodu i wielkie podstawione przez korytarzem i starannie do podobn
#  temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Epoch: 9 Seed: dawno temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Generated:  powiedział na to największy podobny pod podróży i pod straszną podobnym pod strony i postanowił powiedzieć na podwórze i powiedział pod stroną i powiedział to powiedział mi się do niego nie podobało się nie zapomnieć na to w podobnym powietrzu i powiedział mi nie zawierając się na stronie strony i powiedział mu powiedział mi na to w tym powietrzu i postanowił powiedzieć nie może za nim podobać się na podobieństwo i podniesienie się w podobnym pokoju i powiedział mi na to w tym samym powietrzu i
# Epoch 10/10
# 11444/11444 [==============================] - 1598s 140ms/step - loss: 1.4602

# %%
pc = PredictCallback("dawno temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. Zabrała se sobą koszyczek z ciastem i", 500, MAX_INPUT_LEN, 0.5, C2I, I2C)
pc.model = model
pc.temperature = 1.2
pc.on_epoch_begin(0)
pc.temperature = 1.0
pc.on_epoch_begin(0)
pc.temperature = 0.5
pc.on_epoch_begin(0)
pc.temperature = 0.2
pc.on_epoch_begin(0)
pc.temperature = 0.1
pc.on_epoch_begin(0)
# Out:
#  temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Epoch: 0 Seed: dawno temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Generated:  wdział w swoim wykonaniu.piotro się sądził w jedneberach, ale cornelchowie, głośno, który z ustcheniu takiego pręzami, siedząco w powhodni, ozwał się trzecia całego ślęczki, sją wciąż dokadywał gamzę!jeżeli w to mdy serce i umoga jednalniejszej: patrzyć nacisków?zapomniała.czekali różne uzdlnienie, że wszyscy się pozewszyli swoją i proroką potwornaki widowisko, jak niektóre wywłóczbały oczy opieki!caremona grzmoty, którą mamy na kwiatów nauczących kecholic genua sam od tego dłużającego rożnymi
#  temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Epoch: 0 Seed: dawno temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Generated:  ludziom powodu dość nie tylko w pobliże! może tę, którą będzie na miejscu, słyszy siedem eh ówczej, jakieś krótkie dlabrzylnym rennymi w pospolonym chaty, a na tego ptaki, witold i grnia.tak, przez wielkie krajowych czy wcale.trzeba nie moją, ściany, a duma.ich więc żadnych skrępowe ani zdolnom tak samo się pytał.moja to wiekera, sencha wybrał parą domu obcej przyszłości wzburzania.ach!zawołał w jednej chwili z głosami niezłym.wzbawino anzelm hinniści, jakim miał dwie kłaje, robiono.a metarowie
#  temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Epoch: 0 Seed: dawno temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Generated:  po czterech pomyśleniu, skoro posiadała za to dziwnie na wszystkich ostatnich miejscach, na które w podróży leżał drugą powiedział, jak się mogła wziąć przy poza siebie serce, który nie za pomocą od progu nie odpowiedział na to, że tak wybiega na starego pod wielkim głosem na cześć z wami zgodnie do gromadki sposób, ale który przez niego obecnie spostrzegł na przykład i w pobliżu od boku nie mogła postępować z powodu w czym jak największą rzeczą wyciągnął szlachcic, a przy przykład robił się pr
#  temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Epoch: 0 Seed: dawno temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Generated:  powiedział sobie ten podobny szlachtę i zaczął się przez korzyść z powodu wyprawy przed sobą w przeszkodzie i starannie po szczegółu i powiedział sobie po pole po prostu i po czym do podniesienia się zapomniał i podobał się do siebie.przecież tak się przyszedł, że to tylko nie pozwolił powiedzieć na podróż i podobno z takim przyjacielem i powiedział sobie tak samo w swoje przeszkody i pod siodło w podróż w tym miejscu, a stary zawsze przed nim zapomniał w ten sposób w domu i w tym wielkiej rozk
#  temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Epoch: 0 Seed: dawno temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Generated:  pod stronę pod podstawę i pod podwórzem po stronie pod przeszkody i pod podróżnym starem pod strony przed nim pod podstawę i pod strony pod podstawym pod podstawym pod strony pod podstawym przez się po prostu i pod podstawym pod strony pod nim po policzku i podobne starego pod podstawym powietrzem w podobne szczęście pod podstawym i przed sobą przed nim w podobne strony i pod strony pod wielkim pod podwórzem i pod nim pod nim w szerokiej stronie pod przeszkody i pod strony pod podstawym pod str
# ' pod stronę pod podstawę i pod podwórzem po stronie pod przeszkody i pod podróżnym starem pod strony przed nim pod podstawę i pod strony pod podstawym pod podstawym pod strony pod podstawym przez się po prostu i pod podstawym pod strony pod nim po policzku i podobne starego pod podstawym powietrzem w podobne szczęście pod podstawym i przed sobą przed nim w podobne strony i pod strony pod wielkim pod podwórzem i pod nim pod nim w szerokiej stronie pod przeszkody i pod strony pod podstawym pod str'

# %%
from keras.models import load_model, Model
model: Model = load_model('../lstm_models/chars/model_best_4.h5')

for layer in model.layers[:1]:
    layer.trainable = False

model.summary()

dataset_fin = load_tokenized_sentences("../datasets/pickled/chars/bajki-extend_str.pickle")
gen_fin = text_generator(
    dataset_fin, C2I, MAX_INPUT_LEN, 2, shuffle=True, batch_size=BATCH_SIZE, sparse=True
)

model.fit(
    gen_fin,
    steps_per_epoch=len(dataset_fin) // STEP // BATCH_SIZE,
    epochs=10,
    verbose=1,
    callbacks=[
        PredictCallback("dawno temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. Zabrała se sobą koszyczek z ciastem i", 500, MAX_INPUT_LEN, 0.5, C2I, I2C),
        PredictCallback("dawno temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. Zabrała se sobą koszyczek z ciastem i", 500, MAX_INPUT_LEN, 0.2, C2I, I2C),
        PredictCallback("dawno temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. Zabrała se sobą koszyczek z ciastem i", 500, MAX_INPUT_LEN, 0.1, C2I, I2C),
        tf.keras.callbacks.ModelCheckpoint('../lstm_models/chars/model_best_4_retrain.h5', monitor='loss', save_best_only=True, save_weights_only=False)
    ],
)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_2 (Bidirectio  (None, 100, 256)         177152
#  nal)
#
#  lstm_5 (LSTM)               (None, 256)               525312
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_4 (Dense)             (None, 256)               65792
#
#  dense_5 (Dense)             (None, 44)                11308
#
# =================================================================
# Total params: 779,564
# Trainable params: 602,412
# Non-trainable params: 177,152
# _________________________________________________________________
# Number of sequences: 1829739
#  temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Epoch: 0 Seed: dawno temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Generated:  przy nim szepty po boku woli, pod którą przyszła z nimi za to po raz pani de rnal, nie pomogła powiedzieć, co jest zaprzeczyć z siebie przepaść do swego siłach i gotowa kochanki na cieniu powodu.więc wyprawiał przez dzień bez naganania.po tej chwili przepraszał szlachtę w kolację, zamiast w nim wyciągnienia, aby się wydać się do stołu i spokojnie, a na wszystkie sześć pierwszego pokoło powodu od charakteru nie uprzedziła się do dziewczynka, a potem z samego szczerbica.to dobrze, by się nie prze
#  temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Epoch: 0 Seed: dawno temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Generated:  pod podstawę i po prostu na statku w niej nie mogła się podnieść się do niego w podobne strony i w tej chwili po południu nie było po prostu i pod stroną pod dziewczyną po polach i pod nasze podobne i pod wielkim rokiem w starego przedmiotów w tym czasie powiedział mu na przykład i pod wielkim stopniem po drodze w podwórzu nie podobał się przez czynie po prostu i zawsze na to od niego przyszło na to pod podwórzem i pod wielkim położeniem przed sobą po pokoju i w tym postaci pod podstawym przed
#  temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Epoch: 0 Seed: dawno temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Generated:  pod podstawą po prostu i pod stronę po pokoju i pod podstawą i pod podróżnym pod podwórzem po prostu i pod wielkim stopy i pod strony pod przeszkody i pod podstawym pod podróżnym pod podwórza pod podstawym pod strony w podobne strony pod wielkim straszliwe pod podwórzem po prostu i pod podstawym pod podstawym pod podstawy i pod strony pod szeroko po drodze i pod podróżnym pod podróżnym pod podstawym pod podstawym strony przed nimi po prostu i pod podstawę i pod strony pod strony pod wielkim pod
# Epoch 1/10
# 893/893 [==============================] - 128s 141ms/step - loss: 1.4749
#  temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Epoch: 1 Seed: dawno temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Generated:  czując się z miejsca po plecy i ładniejszy nieco po węgierza szybko widział do potem pod szale.w ten sposób był chłopiec i powiedziała o śmierci i nie wiedziała.dobrze za sto głos nie dostał się jednak w warszawie po swoim opowieści i w wysokości czynił mu wyraz przed nimi przez pustelnika.odpowiedział na mnie sam w małe okna to przed siebie nie stanie, że w tej samej chwili zamiast się powiedzieć, że jest królewna, która czasem ziemia pod pieczęciem nie znalazł, że donieść pod straszliwe obawy
#  temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Epoch: 1 Seed: dawno temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Generated:  wyszedł do domu i pod podróży i wystrzał się na podwórze i zaczęła się zastanawiać się w ręku i pod wieczór i zapalił się w brzeg i pod nieprzejrzeniem na wyspie pod szyję i powiedziała jej po kolana.pod wpływem pod drzwiami wyszedł z powrotem i pod wieczorem stary wystawił się w drogę i pod podziemikę w domu zaczęła się pod postacią za małym starym powierzchnią na podwórze i w szalonych przeszłach pod straży i w domu w końcu powiedziała się z nim przed siebie i zapalił się do niej na podwórze
#  temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Epoch: 1 Seed: dawno temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Generated:  wyszedł do siebie i wyszedł do wielkiej strony i pod podłogą wyszedł do stołu i pod tym samym zamku i pod powierzchnią pod warunkiem pod podziemikiem i pod powierzchnią pod wieczorem w stronę pod wieczorem i pod podwórzem w stronę przed siebie pod podziemikami i pod szyję i pod podwórzem w podróży pod podziemikami i pod powietrzem w domu pod wieczorem w stronę pod wieczorem w stronę pod niebem w drogę i pod podwórzem w podróży zapalił się w domu i zaczęła się pod nim na niego pod wieczorem za p
# Epoch 2/10
# 893/893 [==============================] - 127s 142ms/step - loss: 1.4401
#  temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Epoch: 2 Seed: dawno temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Generated:  zapadła do domu i podobała się na pytanie szatan i wywoływał się w wieku z naszej siedem pod oknem na korzenie.przez czarne uderzenie zaczęły zaczęło na dach się wykorzystywać, a do spowiedniejszego zamkowej drugiego odparła więc po głowie po ciemku.co to się podziękowali, moja kobieta poszedł do głowy.przypomniałem sobie o tym na początku chłopca, wszystko to takie słowa, że to powiedział moja godzina, że chrzestna to była szczęśliwa ciekawa i zaniesie za sobą w tej samej rzeczy, czy to wszyst
#  temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Epoch: 2 Seed: dawno temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Generated:  wyszedł do siebie i zaczęła się za nim wyszedł do pokoju.nie mogła się na niego zapalona, a więc nie mogła nic wyciągnąć po powrocie i zaczęła się pod strachiwem przyjacielem za nim pod podarem pod wpływem wysokiego pod przestrzeń i pod podarem pod strachiwem pod przestrzeń w stronę pod strachu i pod przepierzeniem pod strachiwem do królewskiej wojny.po czym wychodził do swojej strony i wypadła do pokoju i pod podróżą po powrocie zapalił się na podróż i pod trzy komnaty i pod strachu zapanowały
#  temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Epoch: 2 Seed: dawno temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Generated:  pod wpływem pod wieczorem i pod podróżą po powrocie wysokiej pod podwórkami i pod strachem w podróży i pod podróżą w stronę pod podziemiem pod podróżą i pod nim pod podwórkami i pod przestrzeń za pomocą stron w podróż i pod strachu po powrocie wysokiej pod strachu i pod podróżą po drodze i pod podróży pod przestrzeń pod podziałkiem i pod podziemiem i przed siebie po powrocie zaczęła się zapalić i pod nim w stronę strachu i pod podróżą po powrocie pod podróżą w podróży i w podróży pod strachu po
# Epoch 3/10
# 893/893 [==============================] - 130s 145ms/step - loss: 1.4225
#  temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Epoch: 3 Seed: dawno temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Generated:  rzekł król i zaledwie w tym stanie o tym jeszcze mogła wybrać się do pałacu.zaczął się je zamierzać do swego porządku i była sama do siebie zagadkę.zaczął to nastawić i postanowił zamierzać swoje drogocenne za groszem, ale jak tylko zapomniał o tym przed siebie i przestały na wieki z prawej chaty, który był za strażnikom za swej sposobności, które za trawy zarobił dzieci i wyczerpał się jak u przystoi do końca i zaczął tomciować trzeciego kamienia.jak to jest przedsiek do tego samego króla z ró
#  temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Epoch: 3 Seed: dawno temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Generated:  podniósł się do swojej królewny.po chwili rozmarzone pod kominem zaczęła się wystarczać na stronę i pod kominami i pod palcami i królewnym wieki z królewną królewną pod stolikiem w podziemiach królewskiej wielkiej królewski.wielki przed siebie przestał się zastanawiać się na stronę i pod porankiem po królewskim przekonaniu i pod panny przerażenia się zapadła do swego powrotu i powiedziała sobie przed sobą i przez ten sposób podniósł się do swego przed siebie i powiedział: nie mogę tam zaczekać
#  temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Epoch: 3 Seed: dawno temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Generated:  powiedział: to jest to najwyższe pod wieczorem i pod powietrzem w tej samej chwili zaczęła się przed nim wyszedł do swego podziemia i powiedziała sobie w swojej stronie i powiedział sobie przy tym w końcu staruszka i powiedziała mu się na to pod porankiem zaczęła się przed porządkiem wystawić na podwórze i pod strachem w królewskim powietrzu pod królem i królewny pod strachem w królewskim powietrzu przez królewna pod królem i królewnym pod królewną pod podziemiem staruszka i pod porządkiem pod
# Epoch 4/10
# 893/893 [==============================] - 130s 145ms/step - loss: 1.4097
#  temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Epoch: 4 Seed: dawno temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Generated:  kazał wystawić szewc, a kościelnie rozpaczał szybko.ale co to może być się poruszać, jak droga mi się wyrządzili, a kobieta wtedy mogę zapewne zrobić na wielkiej koronie.nie mogę więc sprawę iść z tego powiedzenia.królewicz nie przestraszyła się powiedzieć o powierzchni, a czy nie do jedzenia.podniósł się na królewskim pobliżu drugiego szatana i biegł na ławę i wydawało się jej na wysiłkę.po co mi się zabrał w dziewięć czterech słów, w której mogę na wysokość z nieba stanowić, co się przecież n
#  temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Epoch: 4 Seed: dawno temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Generated:  powiedział: nie mogę to przyjść na mnie i powiedziała marysia na to podziemny powiedział po powietrzu, że tak się nie umie za nim w chałupie zamknąć.nie mogę mieć na to za to samo się przecież nie mogę mieć na siebie strachu, a ty tak się tak się stało, a tak się wyszła na to siebie przez ten czas na to za nią po chwili pod sposobem przestrzegał się z nim pod podróżą i powiedział: nie ma tak się tak nie mogę, że to ma małego dnia z powrotem na stronie powiedziała maruda i powiedziała marysia i
#  temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Epoch: 4 Seed: dawno temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Generated:  powiedział: to moja starego dnia powiedziała marysia i powiedziała marysia i powiedziała mu się nie mogła zapadła na siebie.powiedziała mu się nie mogła powiedzieć do siebie.nie mogę to się nie powiedzieć.ale to jest to się tak się podziękowała i powiedziała marysia i powiedziała mu się tak przyjdzie z tego starego starego powietrza.po chwili zaczęła się zastanawiać się przed siebie i zapytał się z powrotem na wysokie pod stronę i powiedział: nie ma takiego starego starego powietrza na to przec
# Epoch 5/10
# 893/893 [==============================] - 127s 142ms/step - loss: 1.3988
#  temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Epoch: 5 Seed: dawno temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Generated:  uważnie w wielkiej świecie do szkaradnego pokoju, którego przyrzekła po wysokości i z jego ziemi, a w dzień przyjaciółki na palcach wysłał chałupy, które podał po swojej ostatniej kopycie zamiarów, po czym znalazł się na ziemię i zawołała za mąż od konia na świecie i przyszedł więc w połowie szafy i czerwony wody od stołu mieszkał w podziemiach i nad siebie w zamian posiadał się z wolnych domów, a co jej można wyprawach.wtedy stara przyszli do czerwonym z morza.w dzieci chciał przebrzec podać n
#  temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Epoch: 5 Seed: dawno temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Generated:  zapytał: wielki podziękował się z niego z powrotem i zapytał z koniecznym i podniósł się do stołu, a potem podobał się do niego w podróż i szepnął z przestrogiem i zaczęła się zastanawiać w podróż i podróżował po szeroki pod wieczór i wyszedł do komnaty i zapytał: nie mogę powiedzieć, że to za mną zawsze może zawsze zachować się na wierzchołku, a potem zasiadał się na podwórze, a na wierzchołku podobny wyprowadzono na stronę i podniósł się z wolna i podał się na moje pod ziemią.król zaczęła pod
#  temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Epoch: 5 Seed: dawno temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Generated:  zaczęła się zastanawiać w swojej stronie i podniósł się w końcu i podszedł do swojej podziemia i podszedł do siebie i zaczęła podobać się w podziemiach i podniósł się w podróż i zaczęła powiedzieć do siebie i powiedziała na niego pod podłogę i zaczęła się zastanawiać w swojej podziemiach i zaczęła się wydać do siebie i zaczęła się zastanawiać z powrotem i pod podłodze i zaczęły się zastanawiać się w podróż i zaczęła zapadła w swojej komnacie i podszedł do swojej komnacie i zaczęła się zastanawi
# Epoch 6/10
# 893/893 [==============================] - 128s 143ms/step - loss: 1.3897
#  temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Epoch: 6 Seed: dawno temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Generated:  oddalił się tak poranek, że nie wiedział do domu, a nie zapłakał do rozmowy.w tym razie powiedział po czym od niego pogwizduje korzenie czarnego marynarza.chyba królewskie było w głowie.musieli stracić do wielkiego podróży.więc jednak wybierał się je do świątyni pani pod wodą, musieli się ze swych przyszłości się na stronę chodzić.po ciemku po czym dotarł na wyspę i kupił w mieście wielki dziewuszka i podziękowała ciemność.przyszłość na niego za to do rumaka.to bardzo dobrze zaraz król to powie
#  temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Epoch: 6 Seed: dawno temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Generated:  powiedział: to jest tak powiedziała królewna.za to dobrze powiedział tak dobrze i pod podłogą starego podróży z królewskim starem pod polanę pod podstawą po drugiej stronie i pod tym wszystkimi pod komnaty i zawsze się pod wierzchołkiem po strasznej stronie pod brzegiem przez polanie z komnaty, a teraz powiedział staruszki i w ten sposób powiedział: powiedział król i podobał się z powrotem po swojej stronie i zaczął się zaprosić na niego z powrotem po trzy podróży.po chwili wyciągnął do domu i
#  temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Epoch: 6 Seed: dawno temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Generated:  pod podłogą pod podłogę zaczęły się podobać i pod podłogą pod wpływem wysokości powiedział staruszkę i powiedział: to nie mogę powiedzieć takie pod straszliwym powiekiem i powiedziała marysia i powiedziała po trzy strony i pod nim pod nim w podróż podniósł się na podwórze i pod strachem po czym podniósł się na podwórze i pod podłogą pod strachem pod podłogą pod podłogą pod podłogą wystawił się na stronę wielkiego podziemia, a potem pod porankiem przed siebie wyszedł do domu i powiedział: to pow
# Epoch 7/10
# 893/893 [==============================] - 130s 145ms/step - loss: 1.3816
#  temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Epoch: 7 Seed: dawno temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Generated:  zasnął w rozpacz i do końca zaczął się spodziewać i kraju królewskim płonącym z piekła, gdy się jej mieszkała i wydarła podróży.w stajni majątku się przeszedł do miasta i spoglądając na podwórze pod królewską balsami w jej zamku i zadrżała do nas z głodu, jednak nie mógł zapachniać te strony i zaczął się na niego wysokość, tylko z wielką po powrotu przyszłość mieszkała po drugiej przestrzeni w skrzyni na krzyż od tysiąca bali kraju, przeciągłem zostawiając w drogę, a wysłała księżniczka razem z
#  temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Epoch: 7 Seed: dawno temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Generated:  zaczął się w tej samej chwili powiedzieć, że nie mogła się zaprosić na podwórze i zaczął się zaparła, a na podwórzu pod podróżą się nie zastanawiał i powiedział: za niego szczerze mojej przestrogi i powiedział król do królewskiego starego króla i pod wieczór z krzaków i postanowił powiedzieć do swojej krzywdy, a tak się podzieliła się w czasie mieszkańców, a wieczorem przyszło mu z drzewa i nie mogła się zaprosić w stronę królewskiej i pod wieczór przez szyję i szedł po drugiej chałupie i szata
#  temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Epoch: 7 Seed: dawno temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Generated:  pod podwieczeń pod szeroko zapadła w szaty i pod wieczór i zaczął się zapalone zapadły i pod podziemnym strachem po drugiej stronie i pod niebezpieczeństwem zapadła się w stronę i pod szerokim starem i pod wieczór i pod szeroko pod podwórkom pod szerokim strażem w podziemiach i zaczął się podobać się w swojej podziemiach i pod nogi i pod strachem zaczął się zaprosić na podwórze i zapytał: nie mogę więc zaprosić na to powiedziała maruda i powiedziała mu się po powrocie i podał w swojej podziemia
# Epoch 8/10
# 893/893 [==============================] - 130s 145ms/step - loss: 1.3750
#  temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Epoch: 8 Seed: dawno temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Generated:  pod stopniami mieszkał na niego przed siebie, zaczęli się z nim przechodzić.bo jeszcze tylko się podniósł trollica, bo wiem za to przyjacielu, odparł król powiedział, jak się tam jeszcze to było.nie potrafiło już poszła z trzech dziwacznej krzywej w głębi mil i postanowiłem, powiedział to do tego zamiaru czy panienka nie mogę podobnego, a nie zastanawiaj się, czy za to powiedziała syna i przyszedłem do swojego starym, potrafił przechodzić na podstawie: matko jest w końcu do króla, to potrafisz
#  temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Epoch: 8 Seed: dawno temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Generated:  zaczęli się podobać się na podwórze i pod starą stronę staruszka przechodziła w trzech pierwszej kraju.w tej chwili zaprowadził się w tym samym stanie i wypatrzył się na szyję i zaczęła się zaprowadzić w szarakiem do domu.po czym poszła do swego starego podziwu i zapytała się na podwórze, a tak powiedział mu się nie zaprowadził i wyszedł do swojej odwagi, a tak się podniósł przez dziewczynkę i powiedział: to jest tak samo pod nosem w staruszku.ale nie mam nic nie wiem, jak nie ma więcej niż na
#  temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Epoch: 8 Seed: dawno temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Generated:  pod straszniejszym starem starego starej strony zaczęły się podobać się w stronę królewny i zaczęli się podobać się w powietrzu i zaczęli się zaprowadzić i poszła do starucha.po czym zaś starała się za to samo na podwórzu i postanowił zaprowadzić swego starucha, a tak się tam zaprowadził, że nie ma takiego przyjaciela, że nie ma jeszcze nie może.a to jest tak samo w tej samej chwili na to pod tym samym staniem, że ta się podobała się na szyję i postanowiła nas powiedzieć, że to po powrocie star
# Epoch 9/10
# 893/893 [==============================] - 127s 142ms/step - loss: 1.3680
#  temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Epoch: 9 Seed: dawno temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Generated:  założył w kominie za przeciwność i pod czarodziejskim starym podwórkom i ani zgodził się z wolna z powrotem pod nazwanie czasem i zawołał: i w tej stronie powiedział i tak obiecał sam widok.widziałem od strachu.przedtem wszystko miał córkę za pośpiechem.wtedy zaczęła się nad nieboszczyka, nie czekała służąca.przebiegł pan i wszyscy wyciągały się z nimi i zapytali za swoją drogę w pobliżu.więc nawet stary podróży i zadzierał jej stary zaczął je przychodzić z torbem, a ze sbenem na samym wieści,
#  temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Epoch: 9 Seed: dawno temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Generated:  zaczął się przyjąć strażników i pod podstawą przez niego przez siedziorę i powiedział do strasznego słowa i podszedł do domu i zawołał: za to było na to wszystko może na to powiedzieć na podwórzu i powiedział po chwili za starym królem i zaczął się wyszła i podszedł do strachu i zawołał: nie ma takiej wielkiej podróży i pomyślał pan baron i poszedł do swej podróży.w tym wielkim strachu zaczął się z powrotem powiedzieć do swojej strony i po chwili zapadła do siebie i podróży na podwórzu zaczął p
#  temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Epoch: 9 Seed: dawno temu czerwony kapturek poszedł do lasu, aby odwiedzić babcię. zabrała se sobą koszyczek z ciastem i
# Generated:  zaczął się zapalić i powiedział: nie ma takiej wielkiej podróży i zaczął się podziałać i powiedziała po powietrzu i zaczął się podziałać i zaczął podziękować z powrotem i zaczął się zaprowadzić i powiedział po czym zaczął się podzielić i zaczął się podziałać i zaczął zapadła i zaczął zapadła z powrotem i powiedział: chciałbym się podobać się na podwórzu i powiedział król i w tej chwili zaczął się podziałać się w podróż i pod podstawieniem po powietrzu po powietrzu po powrocie i zaczął się podob
# Epoch 10/10
# 893/893 [==============================] - 125s 140ms/step - loss: 1.3619

# %%
pc = PredictCallback("tego dnia wieczorem, kiedy maciuś zaganiał stado do sołtysowego obejścia, krasula z łaciatą zaczęły", 500, MAX_INPUT_LEN, 0.5, C2I, I2C)
pc.model = model
pc.temperature = 1.2
pc.on_epoch_begin(0)
pc.temperature = 1.0
pc.on_epoch_begin(0)
pc.temperature = 0.5
pc.on_epoch_begin(0)
pc.temperature = 0.2
pc.on_epoch_begin(0)
pc.temperature = 0.1
pc.on_epoch_begin(0)
