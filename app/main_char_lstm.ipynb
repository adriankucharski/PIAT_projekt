# %%
# keras module for building LSTM
from keras.utils import pad_sequences
from keras.layers import Embedding, LSTM, Dense, Dropout, Bidirectional
from keras.preprocessing.text import Tokenizer
from keras.callbacks import EarlyStopping
from keras.models import Sequential
import keras.utils as ku

# set seeds for reproducability
import tensorflow as tf

import pandas as pd
import numpy as np
import string, os

import warnings
import matplotlib.pyplot as plt
from keras.preprocessing.text import tokenizer_from_json
warnings.filterwarnings("ignore")
warnings.simplefilter(action="ignore", category=FutureWarning)

from dataset import load_tokenized_sentences

sentence_len_min_limit = 2
sentence_len_max_limit = 25

dataset_temp = load_tokenized_sentences("../datasets/pickled/books_clear.pickle")
print(len(dataset_temp), dataset_temp[:5])
dataset = load_tokenized_sentences("../datasets/pickled/bajki_clear.pickle") 
print(len(dataset), dataset[:5])
dataset = dataset_temp + dataset
dataset_join = []
for sentence in dataset:
    if len(sentence) > sentence_len_max_limit:
        for i in range(0, len(sentence) - sentence_len_min_limit, sentence_len_max_limit):
           dataset_join.append(" ".join(sentence[i:i+sentence_len_max_limit])) 
    if sentence_len_min_limit <= len(sentence) <= sentence_len_max_limit:
        dataset_join.append(" ".join(sentence))
#dataset = [" ".join(sentence) for sentence in dataset if sentence_len_min_limit <= len(sentence) <= sentence_len_max_limit]
dataset = dataset_join

# for i in range(len(dataset)):
#     for _char in ".,?!:;":
#         dataset[i] = dataset[i].replace(' ' + _char, _char)
        
print(len(dataset), dataset[:5])
# Out:
# 542601 [['jules', 'verne', 'mil', 'podmorskiej', 'żeglugitłum'], ['tłumacz', 'nieznanyisbn', 'skała', 'uciekającanie', 'zapomniano', 'zapewne', 'dotąd', 'wypadku', 'dziwnego', 'niepojętego', 'i', 'trudnego', 'do', 'objaśnienia', 'zjawiska', 'jakim', 'się', 'odznaczył', 'rok'], ['nie', 'mówiąc', 'już', 'o', 'pogłoskach', 'niepokojących', 'ludność', 'portów', 'i', 'zajmujących', 'ogół', 'na', 'wszystkich', 'lądach', 'dodać', 'wypada', 'że', 'marynarze', 'byli', 'najmocniej', 'zaniepokojeni'], ['kupcy', 'armatorzy', 'dowódcy', 'okrętów', 'szyprowie', 'i', 'sternicy', 'statków', 'europejskich', 'i', 'amerykańskich', 'oficerowie', 'marynarki', 'wojennej', 'wszystkich', 'krajów', 'a', 'nawet', 'rządy', 'różnych', 'państw', 'obu', 'lądów', 'do', 'najwyższego', 'stopnia', 'zajęci', 'byli', 'tym', 'wydarzeniem'], ['od', 'niejakiego', 'czasu', 'okręty', 'napotykały', 'na', 'morzu', 'jakąś', 'rzecz', 'ogromną', 'przedmiot', 'długi', 'kształtu', 'wrzecionowatego', 'niekiedy', 'świecący', 'nieskończenie', 'większy', 'i', 'szybszy', 'od', 'wieloryba']]
# 20208 [['jacob', 'i', 'wilhelm', 'grimmczerwony', 'kapturektłum'], ['marceli', 'tarnowskiisbn', 'była', 'raz', 'mała', 'słodka', 'dzieweczka', 'którą', 'kochał', 'każdy', 'kto', 'ją', 'tylko', 'ujrzał', 'a', 'najwięcej', 'kochała', 'ją', 'babcia', 'nie', 'wiedziała', 'wprost', 'co', 'jej', 'dać'], ['pewnego', 'razu', 'podarowała', 'jej', 'kapturek', 'z', 'czerwonego', 'aksamitu', 'a', 'dziewczynce', 'tak', 'się', 'ten', 'kapturek', 'podobał', 'że', 'nie', 'chciała', 'nosić', 'żadnego', 'innego', 'toteż', 'nazwano', 'ją', 'czerwonym', 'kapturkiem'], ['pewnego', 'razu', 'rzekła', 'matka', 'do', 'czerwonego', 'kapturka', 'oto', 'masz', 'dziecko', 'w', 'koszyku', 'placek', 'i', 'flaszkę', 'wina', 'zanieś', 'to', 'babci', 'która', 'jest', 'chora', 'i', 'słaba', 'i', 'ucieszy', 'się', 'bardzo', 'tym', 'podarunkiem'], ['idź', 'zaraz', 'póki', 'nie', 'ma', 'wielkiego', 'upału', 'a', 'idąc', 'nie', 'biegaj', 'i', 'nie', 'zbaczaj', 'z', 'drogi', 'bo', 'mogłabyś', 'upaść', 'i', 'stłuc', 'butelkę']]
# 603906 ['jules verne mil podmorskiej żeglugitłum', 'tłumacz nieznanyisbn skała uciekającanie zapomniano zapewne dotąd wypadku dziwnego niepojętego i trudnego do objaśnienia zjawiska jakim się odznaczył rok', 'nie mówiąc już o pogłoskach niepokojących ludność portów i zajmujących ogół na wszystkich lądach dodać wypada że marynarze byli najmocniej zaniepokojeni', 'kupcy armatorzy dowódcy okrętów szyprowie i sternicy statków europejskich i amerykańskich oficerowie marynarki wojennej wszystkich krajów a nawet rządy różnych państw obu lądów do najwyższego', 'stopnia zajęci byli tym wydarzeniem']

# %%
from typing import List


def get_sequence_of_tokens(dataset: List[str], tokenizer: Tokenizer = None):
    if tokenizer is None:
        tokenizer = Tokenizer()
        tokenizer.fit_on_texts(dataset)

    total_words = len(tokenizer.word_index) + 1
    word2int_sequences = []
    for line in dataset:
        token_list = tokenizer.texts_to_sequences([line])[0]
        for i in range(sentence_len_min_limit, len(token_list)):
            n_gram_sequence = token_list[: i + 1]
            word2int_sequences.append(n_gram_sequence)
    return word2int_sequences, total_words, tokenizer


def generate_padded_sequences(word2int_sequences: List[List[int]]):
    max_sequence_len = max([len(x) for x in word2int_sequences])
    word2int_sequences = np.array(
        pad_sequences(word2int_sequences, maxlen=max_sequence_len, padding="pre")
    )
    predictors, label = word2int_sequences[:, :-1], word2int_sequences[:, -1]
    return predictors, label, max_sequence_len


def dataset_generator(predictors, label, batch_size=256):
    while True:
        p = np.random.permutation(len(predictors))
        for i in range(0, len(predictors) - batch_size + 1, batch_size):
            indexes = p[i : i + batch_size]
            yield predictors[indexes], label[indexes]

tokenizer = tokenizer_from_json('../lstm_models/tokenizer.json')
word2int_sequences, total_words, tokenizer = get_sequence_of_tokens(dataset, tokenizer)
print(word2int_sequences[:10])

predictors, label, max_sequence_len = generate_padded_sequences(word2int_sequences)
print(predictors.shape, label.shape)


batch_size = 256
gen = dataset_generator(predictors, label, 256)
a, b = next(gen)
print(a.shape, b.shape)
# [[62859, 103749, 1245], [62859, 103749, 1245, 33519], [62859, 103749, 1245, 33519, 171004], [21370, 88416, 9660], [21370, 88416, 9660, 171005], [21370, 88416, 9660, 171005, 13608], [21370, 88416, 9660, 171005, 13608, 532], [21370, 88416, 9660, 171005, 13608, 532, 539], [21370, 88416, 9660, 171005, 13608, 532, 539, 1731], [21370, 88416, 9660, 171005, 13608, 532, 539, 1731, 2222]]
# (6218251, 24) (6218251,)
# (256, 24) (256,)
# Out:
# [[62859, 103749, 1245], [62859, 103749, 1245, 33519], [62859, 103749, 1245, 33519, 171004], [21370, 88416, 9660], [21370, 88416, 9660, 171005], [21370, 88416, 9660, 171005, 13608], [21370, 88416, 9660, 171005, 13608, 532], [21370, 88416, 9660, 171005, 13608, 532, 539], [21370, 88416, 9660, 171005, 13608, 532, 539, 1731], [21370, 88416, 9660, 171005, 13608, 532, 539, 1731, 2222]]
# (6218251, 24) (6218251,)
# (256, 24) (256,)

# %%
import random


class PredictCallback(tf.keras.callbacks.Callback):
    def __init__(self, seed_text, next_words, max_sequence_len, randomize=True):
        self.seed_text = seed_text
        self.next_words = next_words
        self.max_sequence_len = max_sequence_len
        self.randomize = randomize

    def on_epoch_begin(self, epoch, logs=None):
        seed_text: str = self.seed_text
        for _ in range(self.next_words):
            token_list = tokenizer.texts_to_sequences([seed_text])[0]
            token_list = pad_sequences(
                [token_list], maxlen=self.max_sequence_len - 1, padding="pre"
            )
            predicted = self.model.predict_on_batch(token_list)[0]
            if self.randomize:
                indc = np.argpartition(predicted, -5)[-5:]
                predicted = random.choice(indc)
            else:
                predicted = predicted.argmax()
            
            output_word = ""
            for word, index in tokenizer.word_index.items():
                if index == predicted:
                    output_word = word
                    break
            seed_text += " " + output_word
        print(f"Start epoch {epoch} of training; Generated text:", seed_text)


def create_model(max_sequence_len, total_words):
    input_len = max_sequence_len - 1
    model = Sequential()
    model.add(Embedding(total_words, 50, input_length=input_len))
    model.add(LSTM(128, return_sequences=True))
    model.add(Dropout(0.2))
    model.add(LSTM(256, return_sequences=True))
    model.add(LSTM(512))
    model.add(Dense(total_words, activation="softmax"))
    model.compile(loss="sparse_categorical_crossentropy", optimizer="adam")
    return model

print(total_words, max_sequence_len)
model = create_model(max_sequence_len, total_words)
model.summary()
# Out:
# 331307 25
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 24, 50)            16565350
#
#  lstm (LSTM)                 (None, 24, 128)           91648
#
#  dropout (Dropout)           (None, 24, 128)           0
#
#  lstm_1 (LSTM)               (None, 24, 256)           394240
#
#  lstm_2 (LSTM)               (None, 512)               1574912
#
#  dense (Dense)               (None, 331307)            169960491
#
# =================================================================
# Total params: 188,586,641
# Trainable params: 188,586,641
# Non-trainable params: 0
# _________________________________________________________________
# Start epoch 0 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu balladzie balladzie posąg wdzierał posąg przylądkowi przycumowaliśmy przylądkowi przylądkowi dragońskim leonowi oskarżycielu przycumowaliśmy ustając lejbkem lejbkem drżała skórąo łaciny nastroiły łaciny osadzał łaciny odszczekaćże drucika
# Start epoch 0 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu balladzie posąg posąg posąg posąg kłoda kłoda jaśniaszka jaśniaszka odumarła odumarła feliksową feliksową feliksową feliksową traciliśmy przewyższają przewyższają otwieranymi otwieranymi podśpiewywać podśpiewywać podśpiewywać podśpiewywać podśpiewywać
# Epoch 1/100
# 24290/24290 [==============================] - 1666s 68ms/step - loss: 8.4188
# Start epoch 1 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i w którym jest nie miał nic więcej na świecie że nie ma nic do nich ani słowa nie mógł ani co ani więcej nie
# Start epoch 1 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i z uśmiechem i nie ma się z nim na to że nie ma się z nim na to nie ma ani słowa ani słowa
# Epoch 2/100
# 24290/24290 [==============================] - 1670s 69ms/step - loss: 7.7275
# Start epoch 2 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu do czasu na jego widok i w oczach a gdy go już się z nimi stało w oczach i z wolna do niego i z
# Start epoch 2 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i rzekł z uśmiechem i nie mógł się powstrzymać w tym miejscu i nie mógł się powstrzymać w tym miejscu i w tej chwili z
# Epoch 3/100
# 24290/24290 [==============================] - 1668s 69ms/step - loss: 7.3766
# Start epoch 3 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu a potem po chwili z płaczem w ręku z wielką twarzą i z uśmiechem że z nich był to z nich nie było ani razu
# Start epoch 3 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i z powrotem do domu i z powrotem do domu i z powrotem do domu i z powrotem do domu i rzekł z cicha i
# Epoch 4/100
# 24290/24290 [==============================] - 1671s 69ms/step - loss: 7.1062
# Start epoch 4 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i nie ma ani słowa nie miał już czasu w jego źrenicach i nie było już nic do powiedzenia a w chwili potem nie mogłem
# Start epoch 4 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i z wolna i z wolna na ziemię i w mgnieniu oka i począł się rozchodzić i z wolna na ziemię i począł się żegnać
# Epoch 5/100
# 24290/24290 [==============================] - 1670s 69ms/step - loss: 6.8808
# Start epoch 5 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu a stamtąd na czele w domu w którym siedzieli z powrotem do domu a w drugiej stronie domu była już zamknięta od niego jak zwykle
# Start epoch 5 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i z powrotem do domu i z powrotem do domu i w końcu siedziała na progu i rzekł z powagą i dobitnie i nie chcę
# Epoch 6/100
# 24290/24290 [==============================] - 1672s 69ms/step - loss: 6.6812
# Start epoch 6 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu a w izbie było cicho bo nie wiada już nic z chałupy jeno jeno nie było i tak cięgiem w końcu i z lubością a
# Start epoch 6 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i z powrotem do lasu i z powrotem na czele i w opłotkach się nie spodziewał się że to było i że się nie bał
# Epoch 7/100
# 24290/24290 [==============================] - 1673s 69ms/step - loss: 6.5100
# Start epoch 7 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i z krzykiem i z wolna na dół z taką ulgą że nie ustawał i ani cienia ni dymu ani granie było to że na
# Start epoch 7 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i z wolna na wieś i w końcu się nie przebudził i nie wiada co się dzieje w tej chwili i w końcu nie było
# Epoch 8/100
# 24290/24290 [==============================] - 1680s 69ms/step - loss: 6.3634
# Start epoch 8 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu z wiadrami z wody a na czele tych drzew nie było słychać na jednym z kamiennych gruszy i głosy ludzkie poczęły wysuwać z niej plik
# Start epoch 8 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i na powrót do domu i w końcu nie było już już ani śladu i nie mógł się powstrzymać w głowie i że nie mógł
# Epoch 9/100
# 24290/24290 [==============================] - 1671s 69ms/step - loss: 6.2310
# Start epoch 9 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu ale z wolna do góry i na chwilę nie zważał i że go tak nie chciał i nie mogła zrozumieć czy to był to i
# Start epoch 9 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i nie wiedząc co się stało z nimi i z wolna i z wolna i z wolna wynurzył się z wolna i z wolna i
# Epoch 10/100
# 24290/24290 [==============================] - 1670s 69ms/step - loss: 6.1136
# Start epoch 10 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu a potem po ukończeniu postoju w lutym na obiedzie w niedzielę po południu a na progu izby siedział i w milczeniu z otwartymi nozdrzami i
# Start epoch 10 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i z płaczem na ustach i w mgnieniu oka z twarzą ukrytą w uchu i w chwili gdy się obudził i począł się żegnać z
# Epoch 11/100
# 24290/24290 [==============================] - 1672s 69ms/step - loss: 6.0106
# Start epoch 11 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu gdzie nie przymierzając z powrotem w stronę mostu po południu na podwórzu i z powrotem i z tyłu z wolna i młodzi młodzi ludzie którzy
# Start epoch 11 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i nie zważając na to co się stało na wozie i na lewo i na koniec umilkli jak to i na koniec umilkli i z
# Epoch 12/100
# 24290/24290 [==============================] - 1676s 69ms/step - loss: 5.9209
# Start epoch 12 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu na czworakach i po chwili po kilku miejscach na których było pełno było w ostępie stojących przy tym wszystkim z daleka a z daleka na
# Start epoch 12 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i nie było już w pobliżu miasta i w ogóle nie było w pobliżu ani okien ani gwaru ani piechurów ani gwaru ani ptaków ani
# Epoch 13/100
# 24290/24290 [==============================] - 1670s 69ms/step - loss: 5.8447
# Start epoch 13 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu na przełaj na przedzie a gdy już w dole na ganku rozległy ją nawoływanie puszczę z daleka prażąc go senność za nogą i w dyrdy
# Start epoch 13 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i z powrotem do domu i z powrotem do domu i z powrotem do domu i z powrotem do domu i z nią nie wiem
# Epoch 14/100
# 24290/24290 [==============================] - 1685s 69ms/step - loss: 5.7695
# Start epoch 14 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu gdzie to były przejścia a gdy drzwi zamknęły i skręcili w górę by go z nim skryć z daleka nie szczędząc furmanek a gdy już
# Start epoch 14 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i nie czekając na nikogo nie gdzieżby już nie było widać było w tej chwili że nie mógł się wstrzymać od głośnego śmiechu i lęku
# Epoch 15/100
# 24290/24290 [==============================] - 1670s 69ms/step - loss: 5.6945
# Start epoch 15 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu w kąt i w tej właśnie bitwie i nie ma w pobliżu ani znaku spoczynku ani chwili ani na sekundę a gdy go na świat
# Start epoch 15 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i nie bacząc na pytania kłębiącego się w milczeniu i z przerażeniem na ustach śpiewającego z cicha i markotnością i najsprytniejsi a zarazem nie mógł
# Epoch 16/100
# 24290/24290 [==============================] - 1676s 69ms/step - loss: 5.6223
# Start epoch 16 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu gdzie się schroniła do pana z osobna i do czego to było gotowe do czego nie było i tak go nie ma ale gdy go
# Start epoch 16 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i nie było już nic do roboty i że to jest w korsuniu i że to jest w wodzie i że nie ma już nic
# Epoch 17/100
# 24290/24290 [==============================] - 1670s 69ms/step - loss: 5.5550
# Start epoch 17 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu a on się obejrzał w stronę placu gdzie na polach drzewa na którym bielił swe plamy to już nie było światła a gdy na końcu
# Start epoch 17 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i nie mogąc się powstrzymać od śmiechu i nie mógł się powstrzymać od śmiechu i nie mógł się powstrzymać od śmiechu i nie mógł się
# Epoch 18/100
# 24290/24290 [==============================] - 1670s 69ms/step - loss: 5.5025
# Start epoch 18 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu ale nie mogąc już wytrzymać ale w tej izbie nie mogła się już pomieścić i na chwilę gdy nagle w niej trzęsło ją się z
# Start epoch 18 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i nie bacząc na to maksyma i nie było już nic innego jak tylko na tym świecie że nie mógł się oprzeć pokusie i nie
# Epoch 19/100
# 24290/24290 [==============================] - 1670s 69ms/step - loss: 5.4566
# Start epoch 19 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu w szarugę do swego dworu ale z nagła i z radością nie było widać było tylko w sobie coś niepojętego i że gdy ją już
# Start epoch 19 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i nie mógł się powstrzymać od śmiechu do tego stopnia że w tej chwili nie było nikogo innego i nie wątpiła że to nie było
# Epoch 20/100
# 24290/24290 [==============================] - 1670s 69ms/step - loss: 5.4087
# Start epoch 20 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu a stamtąd do drzwi izby a potem wszedł w bramę i zawołał to co tam słychać drogi o czekających świńskie la roue dzbanek i w
# Start epoch 20 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i nie mogłem się powstrzymać od śmiechu słysząc że to jest łgarstwo błędnych rycerzów i wykwintnych ludzi którzy nie otrzymali za złe krzywdy i uczciwości
# Epoch 21/100
# 24290/24290 [==============================] - 1677s 69ms/step - loss: 5.3577
# Start epoch 21 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i rozchyliwszy usta że już nie mógł dosłyszeć i że nie miał nic wspólnego w tej gospodzie do lasu kurzyli i łasice i garbami śniegów
# Start epoch 21 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i z płaczem do ust i powiększona hałaśliwej dwuklasowej królestwa w ojczystej mowie była głęboka jak aniołek drzemała w pustkowiu w wieczornej pracy i utonęła
# Epoch 22/100
# 24290/24290 [==============================] - 1678s 69ms/step - loss: 5.3148
# Start epoch 22 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i już nie mogła wytrzymać bo się w niego ujęła jak huragan który rżał w biegu bo już się już w niej nie widział że
# Start epoch 22 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i nie było już nic innego że się nie przeciwił i nie mógł się ruszyć z miejsca bo nie było już w komorze bo nie
# Epoch 23/100
# 24290/24290 [==============================] - 1671s 69ms/step - loss: 5.2716
# Start epoch 23 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu ale po odejściu rzędziana nadciągnęli w parę dni na przełaz do wasągu i machając nogami a pobok wrzasnął kuba a za nimi razem wójt i
# Start epoch 23 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i rozglądał się po izbie i rzekł do niej to ty idziesz na koniu i przynieś mi kawy i zanieś mnie do domu i przynieś
# Epoch 24/100
# 24290/24290 [==============================] - 1672s 69ms/step - loss: 5.2364
# Start epoch 24 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu z której na bruk było ciemno a gdy się obudził w powietrzu rozległ mi się na niebie że w nocy walili w wodę a to
# Start epoch 24 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i nie było już nic do roboty ani o glejty ani o glejty ani o elekcji ani o tatarskim nie wiedział ale nie było w
# Epoch 25/100
# 24290/24290 [==============================] - 1677s 69ms/step - loss: 5.1977
# Start epoch 25 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i znowu na wstępie w nocy i z taką siłą iż w końcu nie mógł się pomieścić i nie ruszała i nie tylko na to
# Start epoch 25 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i nie mogła się powstrzymać od śmiechu i nie mógł się powstrzymać od śmiechu i nie mógł się powstrzymać od śmiechu i nie mogła się
# Epoch 26/100
# 24290/24290 [==============================] - 1672s 69ms/step - loss: 5.1552
# Start epoch 26 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu w górę na samą porę że hance już dech i zęby trzęsły a jeno ruchać w miejscu skowronki wykręcało od karczmy trzęsła mu w gardzieli
# Start epoch 26 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i chrapał jak szalony zwierz który w tej chwili przybiegł do siebie i podparłszy laseczką w ręku i w tejże chwili zapełniać go na kwaśne
# Epoch 27/100
# 24290/24290 [==============================] - 1673s 69ms/step - loss: 5.1223
# Start epoch 27 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu na złamanie skórze i wlókł go w bok za wsią w stronę kapturach w las kosy na polanie pierzchnął ogromny krótki mokry ciepły wiatr zdarł
# Start epoch 27 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i ująwszy się za boki ku młynowi i jął odwalać z osobna i z krwawym szumem i szumem pognał za wisłę i miedzami dobierał się
# Epoch 28/100
# 24290/24290 [==============================] - 1669s 69ms/step - loss: 5.0900
# Start epoch 28 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu ale wnet się nie odezwała co to się dzieje w tej chwili i tak że już w nocy na stepie nie spocznę a potem na
# Start epoch 28 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i nie ustawała w zapamiętaniu ale w mig poleciała do chałupy i szczekał do karczmy a chłopaki co się widziało w garście co się dzieje
# Epoch 29/100
# 24290/24290 [==============================] - 1676s 69ms/step - loss: 5.0575
# Start epoch 29 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu na strych a w opłotkach nie było żywej wody jaka akuratnie się w pół przebudził w komin kiej to na warcie w kruchcie kiej to
# Start epoch 29 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i ująwszy się za ręce i trzymając w ręku piłkę że w tej chwili sypnęły się na łóżku i zapalić fajkę i skakankę nie rozciął
# Epoch 30/100
# 24290/24290 [==============================] - 1670s 69ms/step - loss: 5.0221
# Start epoch 30 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu hanka i szły za nią do taktu i zanosiła z komina że organista chwycił się oburącz do kolan a nie dochodził już jęku po twarzy
# Start epoch 30 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i nie mogła się ruszyć z miejsca ale gdy już już nie było słychać było słychać było tylko miarowe stukanie i sapanie a w końcu
# Epoch 31/100
# 24290/24290 [==============================] - 1677s 69ms/step - loss: 4.9925
# Start epoch 31 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu gdzie się schroniła na wotywę z maćkiem kłębowym z brzozowej i z nim podrwiwać na antka i że mu nabił fajkę a latała w borynę
# Start epoch 31 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i chrapał jak szalony zwierz z gołymi rapierami i z meą w zębach pognał do ataku dońca cichymi krokami po bitwie i w nocy przepijali
# Epoch 32/100
# 24290/24290 [==============================] - 1675s 69ms/step - loss: 4.9614
# Start epoch 32 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu kapuśniaku i już jeszcze nie wrócił ani do roboty a nawet na wieś nie poredził się na niego gniewać ale i tak było jakby w
# Start epoch 32 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i ująwszy ją za ręce i poczęła całować się wzajemnie szepcąc jagusi się płaczem ozwała się urągliwie a zmądrzałem a morusek i józek pozostawieni szczepańską
# Epoch 33/100
# 24290/24290 [==============================] - 1695s 70ms/step - loss: 4.9306
# Start epoch 33 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i tam nie było w izbie i przędła a jagna nie odzywała i kryjomo kiej ten pies diabelski taki samym udręką jeno się nie pomiarkował
# Start epoch 33 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i wkrótce się zatrzasnęły i drzwi alkierza otworzyły się na oścież i wszedł trębacz służbowy z oznajmieniem że mu się wielce umeblował i rozeszli się
# Epoch 34/100
# 24290/24290 [==============================] - 1698s 70ms/step - loss: 4.9044
# Start epoch 34 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu ale się z pościeli do spychowa zobaczyć bo już i w bogdańcu było pusto było że jeno na koniach z czeladzią a nawet zgrabiałe ręce
# Start epoch 34 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i inszych a śpiewania nie było już w gotowości do bitki i jagienki nie chciało się na nią i rozmyślała że to nie poredził się
# Epoch 35/100
# 24290/24290 [==============================] - 1712s 70ms/step - loss: 4.8813
# Start epoch 35 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu na strych do kuchni i z motyką i kryjówek pobiegła śpiesznie na przełaj do katafalku aż na ganek i ukazały głos świetlisty zaczął prosić pana
# Start epoch 35 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i nie pokazała się już i nic nie było słychać było tylko miarowe kroki tupanie było pusto i parskanie koni i skrzyp kopyt końskich w
# Epoch 36/100
# 24290/24290 [==============================] - 1711s 70ms/step - loss: 4.8595
# Start epoch 36 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu na strych na prawo grudy wsi gdzieniegdzie naszczekiwały różowo w stawie na dole w komorze ledwie się tam zebrało do kłębów a siano w trawie
# Start epoch 36 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i nie mogła się powstrzymać od śmiechu do tego stopnia że nie mógł się oprzeć pokusie pożartowania z szykowną szklanką owinięta w ręku spodni i
# Epoch 37/100
# 24290/24290 [==============================] - 1686s 69ms/step - loss: 4.8318
# Start epoch 37 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i z cicha do wnętrza jaskini padała i nucąc litanię po śniegach jaże się chwiały a hu zapamiętale i hance zastąpiły bezładną drogę dojrzał jaże
# Start epoch 37 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i nie mogła się powstrzymać od głośnego okrzyku zdziwienia i oklaskami coraz bardziej i oderwała się od niego oderwać i począł rozumowaćstało się krzyku i
# Epoch 38/100
# 24290/24290 [==============================] - 1672s 69ms/step - loss: 4.8044
# Start epoch 38 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu hanka cicho kręciła się dookoła bo ledwie się już już w pole zahuczały ozwała ją rzewliwie jaże antek beknął nastawiła i po wargi chodziły i
# Start epoch 38 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i owijając się w ręce wbiegł do pokoju i zawołałem a bywajcie psubraty józek i wpuść mnie wpuść siostrzyczko i czarci zgodą przyślij mi pan
# Epoch 39/100
# 24290/24290 [==============================] - 1669s 69ms/step - loss: 4.7773
# Start epoch 39 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu a potem i po chwili zaczęły jej oczy podnosić i wołać do mnie marku i pójdź no na to co to uczynił i niech się
# Start epoch 39 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i nie było już wyjścia z drogi a gdy się obudził w pobliżu mostu i zobaczyliśmy go dziwując się w lustrze z marysią i począłem
# Epoch 40/100
# 24290/24290 [==============================] - 1669s 69ms/step - loss: 4.7485
# Start epoch 40 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu a stamtąd wydrapał z powrotem do łódki a pan zięba ze srebrną szatę z garbem na myciu z koźlej ziemi ustawił w pokoju za sobą
# Start epoch 40 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i z płaczem nie dobiega do siebie ale dojrzawszy jak najdokładniej i całował go w zapaskę i złamał ją z uśmiechem i poczęła powtarzać wzruszonym
# Epoch 41/100
# 24290/24290 [==============================] - 1669s 69ms/step - loss: 4.7294
# Start epoch 41 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu gdzie nie można by było na morzach rzeki które stanęły w ciemnościach na drewnianym koniu wdychając w kominie tłukąc i wygrzewać w błękity i żołnierstwo
# Start epoch 41 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i owijając się w drzazgi krzycząc że nie ma w pobliżu chałupy i w ogóle nie ma rady na jutrzejszą czasy i na to że
# Epoch 42/100
# 24290/24290 [==============================] - 1672s 69ms/step - loss: 4.7121
# Start epoch 42 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu hanka wzburzona a magda była całkiem ciężka a rzewnie krzątała na niej oczy wilgotne oczy biła się kiej przydeptana glista żarłoczny naści na sercu tak
# Start epoch 42 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i nie śmiała się ruszyć z miejsca i rozglądając się po okolicy i obchodził się z widocznem okrzykiem i ewką z osobna trwała w nich
# Epoch 43/100
# 24290/24290 [==============================] - 1671s 69ms/step - loss: 4.6904
# Start epoch 43 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu na obiad ale późno się bali bo mu markotno brakło mu i z bekiem że nawet w dyrdy się nie widać stało się i że
# Start epoch 43 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i nie mogła się oprzeć bo się w niej rozkochał i tak się stało że się w niej ściemniało że spodziewał się że się już
# Epoch 44/100
# 24290/24290 [==============================] - 1669s 69ms/step - loss: 4.6739
# Start epoch 44 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu aby nie wywrócić się w tył i z taką siłą że z nagła stanęła pośrodku jak maleńki cień i iskry w szczelinie księżyca rozlega się
# Start epoch 44 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i tam już nie było już w pobliżu stawu bitej drogi i nie było już pusto było w pobliżu izby i siano i kury grzebały
# Epoch 45/100
# 24290/24290 [==============================] - 1669s 69ms/step - loss: 4.6547
# Start epoch 45 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu ale on się tylko zerwał ale jeszcze raz i machnął oczyma i rzekł hej mi jakowe szczęście boś na bogdańcu i z dziećmi chadzał a
# Start epoch 45 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i zdechł jak wicher na kominie i się z nią dzielił i pogroził se i dziwuje się że mu się nie chce a ino bych
# Epoch 46/100
# 24290/24290 [==============================] - 1670s 69ms/step - loss: 4.6310
# Start epoch 46 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu a nie mogąc znaleźć żadnej odpowiedzi do tego miejsca że się z niego ożenił a i jego syn izaak i tak był w tej mierze
# Start epoch 46 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i nie śmiała się z nią dogadać i nie mógł się z nią dogadać i nie mógł się już cofnąć do ucieczki i począł biec
# Epoch 47/100
# 24290/24290 [==============================] - 1689s 70ms/step - loss: 4.6021
# Start epoch 47 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu ale już i nic jeszcze nie widziano że się w tej chwili przywiązał do płota a próbował go widzieć ale gdy już się zachłysnął wstał
# Start epoch 47 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i nie mogła się doczekać cudom i nie mógł się powstrzymać od śmiechu i nie mógł się uspokoić z radości i że nie ma prawa
# Epoch 48/100
# 24290/24290 [==============================] - 1707s 70ms/step - loss: 4.5836
# Start epoch 48 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu ale nie mogłem jej wychylić oczów od tamtej lecę za próg piwnicy bo to była harda dziewczyna wzięła papierek pocałowała ją w rękę i wyszła
# Start epoch 48 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i uśmiechała się do siebie że to jest niemały i profit się nie pomieszał a co się stanie z prostakami a co się z nim
# Epoch 49/100
# 24290/24290 [==============================] - 1695s 70ms/step - loss: 4.5621
# Start epoch 49 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu żeby się z nią nie wymknął i nie mógł się doczekać ciszy w ciemności z obawy żeby jej powstrzymać w dołku widną w tym samym
# Start epoch 49 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i nie ruszało do lubicza nie było w namiocie bo w bogdańcu trwając i nie było sposobu by się z chmielnickim połączyć i nie chciał
# Epoch 50/100
# 24290/24290 [==============================] - 1687s 69ms/step - loss: 4.5423
# Start epoch 50 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu a już się z trzaskiem w opłotkach borynów wrzeszczały a tak gwarno że stojał w mig nie wyskoczą na wypominki nie było do kogo gęby
# Start epoch 50 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i jęła się z wolna rozjeżdżać się z barłogu i wolnymi drogami ruszyli do lasu i przepadł jak trusia kiejdany zaś się już długo zaczynało
# Epoch 51/100
# 24290/24290 [==============================] - 1675s 69ms/step - loss: 4.5228
# Start epoch 51 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu a potem zaczęła ją znowu zobaczyć co to stało na przedzie i mary a w izbie zdziwiły ją się hałas i krzyki a dudnienie nie
# Start epoch 51 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i zaglądał w głuche wrota i zasypiała w nich że w końcu nie było już nic do roboty jeno i nie zliczyć się z dala
# Epoch 52/100
# 24290/24290 [==============================] - 1666s 69ms/step - loss: 4.5001
# Start epoch 52 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i wkrótce po chwili powróciła w górę do izby do której nie było czasu na ulicy nie bacząc do posiłku ale jagusia była prawie taka
# Start epoch 52 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i nie mogła się powstrzymać od śmiechu i nie mógł się uspokoić nie mógł oderwać oczów od picia i stękała po twarzy rotgiera i że
# Epoch 53/100
# 24290/24290 [==============================] - 1668s 69ms/step - loss: 4.4808
# Start epoch 53 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu ale basia już siedziała na małym domku ale w tej ciszy nie było widać że nic z tego z stracenia i w tej samej sekundzie
# Start epoch 53 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i uśmiechała się do siebie i jął krzyczeć do siebie i tak się stało że się w nim trzęsło spłynęły i kieby wilcy zjuszone rypnęły
# Epoch 54/100
# 24290/24290 [==============================] - 1666s 69ms/step - loss: 4.4665
# Start epoch 54 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu muzyka pełna ciepła i piersi w piersi się zapaść w płuca i serce poczęło dochodzić ku niemu coraz gwałtowniej powtarzali słowa z powodu głupiego pana
# Start epoch 54 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i wkrótce się już zmęczyły z nagła i gwarno było w powietrzu że już się już widziało i zorze zaśpiewały pod chałupami zakręcał wisiało nad
# Epoch 55/100
# 24290/24290 [==============================] - 1669s 69ms/step - loss: 4.4489
# Start epoch 55 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i z trudnością do domu widno było i jakby się do czegoś stało że zapomniawszy o tym przebraniu i zaczynała krzyczeć do domu choremu i
# Start epoch 55 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i już już nie było widać kolacji i usnęła w zapamiętaniu i w zapamiętaniu szukał się i podnosił na powrót do pacierza i niesła się
# Epoch 56/100
# 24290/24290 [==============================] - 1666s 69ms/step - loss: 4.4280
# Start epoch 56 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i już już nie mógł się jej dotknąć i nie wiedziała czy ma się ożenić z czym się ożeni gosiewskim który nasłuchawszy ich by go
# Start epoch 56 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i jęła się z wolna rwać i z krzykiem skrzybot garści i wrzaskliwe lodowate stąpania pacierzy rozległy się brzęki echa fujarki i smaki lecą liście
# Epoch 57/100
# 24290/24290 [==============================] - 1666s 69ms/step - loss: 4.4044
# Start epoch 57 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu a nawet na drugi brzeg wygramolili zrywała się raźnie aż do rana nie mogąc go dosłyszeć a jeno ksiądz z nimi w nocy pobiegł przodem
# Start epoch 57 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i już już nie było w domu ani na noc ani na noc ani na noc jak na wesele i nie było czasu że się
# Epoch 58/100
# 24290/24290 [==============================] - 1668s 69ms/step - loss: 4.3855
# Start epoch 58 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i rzuciwszy do chlewa bryczkę z ławy do połowy i na klucz do drzwi weszło do pokoju a w oknach podała im do kufra strzelbę
# Start epoch 58 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i rwąc się na ręce marysi i niespodziewanie że się w niej nie przelewa i nie mógł się z nimi dogadać i nie było sposobu
# Epoch 59/100
# 24290/24290 [==============================] - 1666s 69ms/step - loss: 4.3675
# Start epoch 59 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu szykować i do niego obaczyć co on wyprawia a on zaś miał już na myśli co to ma znaczyć a co z nim zrobić i
# Start epoch 59 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu świeciło się w cieniach skowronki a rozgłośnie taneczną i cichuśko w sadach że skowronki się nie było wyniesło kłosami rzezi a czasem przepijali na smętarz
# Epoch 60/100
# 24290/24290 [==============================] - 1665s 69ms/step - loss: 4.3580
# Start epoch 60 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu w stronę podwórza i znowu na dół na podwórze do wsi świeciło ciepło śmiały mu tęgie przysmaki z jarmarku a dobrodziej siedzi na kupie a
# Start epoch 60 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i uśmiechała się do mnie i tak się stało że się nie dowiem że się nie dowiedział że to już dawno nie było przyjemne i
# Epoch 61/100
# 24290/24290 [==============================] - 1669s 69ms/step - loss: 4.3306
# Start epoch 61 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu szykować ją na postronku ale w takim chłodzie i tak było jak w ulu schowam mu się w dołku na mnie kiej tu nie dam
# Start epoch 61 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i już nie było nikogo kto by się nie zapamiętał i nie zdradził i nie rozumiał co się dzieje z tą sprawą duchową i smętną
# Epoch 62/100
# 24290/24290 [==============================] - 1668s 69ms/step - loss: 4.3132
# Start epoch 62 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu na strych ale już nic się zerwała nie może lękliwie nawet gdy się w górę rozsypywało z krzykiem i jakoby to co się stało że
# Start epoch 62 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i nie ruszało się z nią bo nie wiedział co się stało z jagusią i dominikową nie chciało a choćby się puszył z wójtem i
# Epoch 63/100
# 24290/24290 [==============================] - 1666s 69ms/step - loss: 4.2947
# Start epoch 63 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu ale nie było czasu żeby nie mógł uciekać od razu i sam na wszelkie dni letnich zaczęło kłaść w pęki włosów które furmani po drabinie
# Start epoch 63 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i tam już nie było w domu ani śladu ani popiołu ani jednego dnia z rana do lasu i odwiózł do domu aby się dowiedzieć
# Epoch 64/100
# 24290/24290 [==============================] - 1667s 69ms/step - loss: 4.2794
# Start epoch 64 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i w końcu i po niejakim momencie na podwórzu ukazała mu na oczach skry i zawołał ochrypłym głosem sprzedajcie mi tu łaskę ale i koronę
# Start epoch 64 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i znowu po chwili gdy nagle przypomniał sobie że to jest krasnoludek książęcy i chytry i z siwymi wąsami i podejrzliwym obrońcą dworaka który okazywał
# Epoch 65/100
# 24290/24290 [==============================] - 1667s 69ms/step - loss: 4.2602
# Start epoch 65 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu to i tam w tej samej izbie która była ukryta i w domu było duszno wesoło i że wszyscy byli w gąszczu co gdzieniegdzie naszczekiwały
# Start epoch 65 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i uśmiechała się do siebie i wydrapał się na ławie i usnął znowu na powrót do alkierza i powlókł się do karczmy roztrącając się w
# Epoch 66/100
# 24290/24290 [==============================] - 1667s 69ms/step - loss: 4.2416
# Start epoch 66 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu w stronę lasu pełno domów dziewczyn świeżych ludzi a na nim zamykano na ławkach w oborze w głąb lasu dojeżdżał na czworakach pietrek gnój za
# Start epoch 66 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i rzuciwszy się na środek izby i siadła na przyzbie na podwórze i pojechali do domu na przełaj przez tłum wydostałem się na dół i
# Epoch 67/100
# 24290/24290 [==============================] - 1665s 69ms/step - loss: 4.2253
# Start epoch 67 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu ale jeszcze się jeszcze w oko mieniło a trudno już było wyciągnąć i już zajętą plątała a nikaj bicie płotów wspominki wspominki jakżeby to nie
# Start epoch 67 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i błogi wiał od wschodu i zachodu puste stąpania od wschodu do zachodu słońca odzywały się głosy biegnących ku środkowi areny i przepadł w ciemnościach
# Epoch 68/100
# 24290/24290 [==============================] - 1666s 69ms/step - loss: 4.2092
# Start epoch 68 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu ale się pohamował ale jakoś się nie odezwała a w końcu i znowu objęła go za głowę i runął przed oczy jak szalona z objęć
# Start epoch 68 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i już nie było nikogo kto by się nie bał na wieś nie było już nikogo a i józka pilnowały ją kole ostrego zwierza i
# Epoch 69/100
# 24290/24290 [==============================] - 1673s 69ms/step - loss: 4.1969
# Start epoch 69 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i uśmiechała głowę na tamtą ścianę mignął mu do drzwi karczmy i tam cicho szukał roboty w lipcach się przebiera a to właśnie na odwieczerzu
# Start epoch 69 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i uśmiechała się do siebie i drzemać z taką ochotą do karczmy i tak cicho że sakramenta przekroczył z nauczycielami i rozeszli się do śniadania
# Epoch 70/100
# 24290/24290 [==============================] - 1630s 67ms/step - loss: 4.1773
# Start epoch 70 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu a nawet w sobotę na noc było już pełno dworzan którzy siedzieli za drzwiami i gwarzyli na podwórze plebanii walili przez konie aby za letniej
# Start epoch 70 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i uśmiechała się do niej i pyta co się stanie z tymi ludźmi i nie pozwoliłem mu się ruszyć do domu i nie czekając na
# Epoch 71/100
# 24290/24290 [==============================] - 1577s 65ms/step - loss: 4.1641
# Start epoch 71 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu na świat zarządziła się z targowiska jasiek i już magda a teraz już na nic się w noc wyspał najśliczniejszym roboty w polu chodził chodził
# Start epoch 71 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i już nie było widać że się jej nie podobał i nie mógł się z nią wydobyć i nie mógł już się z nią zbliżyć
# Epoch 72/100
# 24290/24290 [==============================] - 1570s 65ms/step - loss: 4.1446
# Start epoch 72 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu na podwórze a w drugiej uprzęży w małej odzieży z czerwonymi brodami którą kocham to nie było w zwyczaju nic dziwnego jak zatopić nić i
# Start epoch 72 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i uśmiechała się do niego z gorącą prośbą do nel rozmyślała o wszystkim co się dzieje z lejblem końskowolskim niewinnym wiedziała że kamboh szła piechotą
# Epoch 73/100
# 24290/24290 [==============================] - 1570s 65ms/step - loss: 4.1331
# Start epoch 73 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i nie było w chałupie nie było świateł ale w noc panował mrok i noc noc ogarniał wieś a ogień jeszcze z dachów widać a
# Start epoch 73 of training; Generated text: dawno temu czerwony kapturek poszedł do lasu i już nie było nikogo kto by się nie zapamiętał i nie mógł pojąć począł krzyczeć wniebogłosy bo nie mógł się powstrzymać od uniesienia i
# Epoch 74/100
# 18976/24290 [======================>.......] - ETA: 5:43 - loss: 4.0860

# %%
model.fit(
    gen,
    steps_per_epoch=len(predictors) // batch_size,
    epochs=100,
    verbose=1,
    callbacks=[
        PredictCallback("dawno temu czerwony kapturek poszedł do lasu", 25, max_sequence_len, True),
        PredictCallback("dawno temu czerwony kapturek poszedł do lasu", 25, max_sequence_len, False),
        tf.keras.callbacks.ModelCheckpoint('../lstm_models/model_best_2.h5', monitor='loss', save_best_only=True, save_weights_only=True)
    ],
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 model.summary()
#
# NameError: name 'model' is not defined

# %%
import json as pjson
json = tokenizer.to_json()

with open('../lstm_models/tokenizer.json', 'w', encoding='utf-8') as f:
    f.write(pjson.dumps(json, ensure_ascii=False))
