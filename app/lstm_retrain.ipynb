# %%
import json
import tensorflow as tf
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
import warnings
from keras.preprocessing.text import tokenizer_from_json

warnings.filterwarnings("ignore")
warnings.simplefilter(action="ignore", category=FutureWarning)

from dataset import *
from lstm import *

dataset = load_tokenized_sentences("../datasets/words/bajki-raw.pickle")

with open("../datasets/words/books-bajki-raw-tokenizer_100000.json", "r") as f:
    data = json.load(f)
    tokenizer = tokenizer_from_json(data)

print(
    {
        "size": len(dataset),
        "tokenizer": tokenizer.num_words,
        "str": dataset[1][:500],
        "tokenizer": tokenizer.num_words,
    }
)
# Out:
# {'size': 41, 'tokenizer': 100000, 'str': 'była raz mała słodka dzieweczka, którą kochał każdy, kto ją tylko ujrzał, a najwięcej kochała ją babcia  nie wiedziała wprost, co jej dać. pewnego razu podarowała jej kapturek z czerwonego aksamitu, a dziewczynce tak się ten kapturek podobał, że nie chciała nosić żadnego innego, toteż nazwano ją czerwonym kapturkiem.\npewnego razu rzekła matka do czerwonego kapturka:\n oto masz, dziecko, w koszyku placek i flaszkę wina, zanieś to babci, która jest chora i słaba, i ucieszy się bardzo tym podarunkie'}

# %%
class_weights = calculate_class_weights(tokenizer, alpha=0.4) 
SKIP = 2
total_words = tokenizer.num_words
batch_size = 256

padding: Literal["pre", "post"] = "pre"
dataset_size = calculate_dataset_size(dataset, tokenizer, LEN_MAX_LIMIT, SKIP)
gen = dataset_generator(
    dataset, tokenizer, LEN_MIN_LIMIT, LEN_MAX_LIMIT, SKIP, batch_size, padding=padding
)
a, b = next(gen)
print(a.shape, b.shape)
print(a[0], b[0])
print('class_weights', len(class_weights), class_weights[[1,2,3,4,5,-5,-4,-3,-2,-1]])
# Out:
# (256, 50) (256,)
# [    0     0    59     5   368    25  3199 72391    10   248 18540 26661
#   7902    17     8   198  2224  4293     1 53560    51  2319    40   220
#     38    62    11  3220   831    10    72 23949   166   500  5410     1
#  49554   397 41638 62449     8   341 12676     3 78716   101 22002     2
#     65  1382] 1
# class_weights 100001 [ 1.          1.10900746  1.14756841  1.22807962  1.26507838 73.39486412
#  73.39486412 73.39486412 73.39486412 73.39486412]

# %%
from keras.models import load_model

model: Model = load_model('../lstm_models/model_best_5.h5', custom_objects={"WeightedSCCE":  losses.SparseCategoricalCrossentropy})
model.compile(optimizer='adam', loss=WeightedSCCE(class_weights))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 50, 50)            5000000
#
#  bidirectional (Bidirectiona  (None, 50, 1024)         2306048
#  l)
#
#  bidirectional_1 (Bidirectio  (None, 50, 1024)         6295552
#  nal)
#
#  dropout (Dropout)           (None, 50, 1024)          0
#
#  bidirectional_2 (Bidirectio  (None, 1024)             6295552
#  nal)
#
#  dense (Dense)               (None, 100001)            102501025
#
# =================================================================
# Total params: 122,398,177
# Trainable params: 122,398,177
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(
    gen,
    steps_per_epoch=dataset_size // batch_size,
    epochs=20,
    verbose=1,
    callbacks=[
        tf.keras.callbacks.ModelCheckpoint(
            "../lstm_models/model_best_5_retrain.h5",
            monitor="loss",
            save_best_only=True,
            save_weights_only=False,
        )
    ]
    + [
        PredictCallback(
            "dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek",
            60,
            LEN_MAX_LIMIT,
            tokenizer,
            padding,
            _t,
        )
        for _t in [0, 0.1, 0.2, 0.3, 0.5, 0.8, 1.0]
    ],
)
# Out:
# Start epoch 0 of training; Temperature: 0.0 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z i z obnażonymi w nim górę i w jednej chwili setka metrów pod powierzchnią morza. nautilus płynął w pobliżu placu. tam nie było w tym czasie w tym miejscu ani jednego z nich ani śladu w tym miejscu nie było w tym nic z tego nie było w tym czasie w tym sierpniu w tym celu w r. ,
# Start epoch 0 of training; Temperature: 0.1 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z i z obnażonymi w nim górę i w jednej chwili setka metrów pod powierzchnią morza. nautilus wypłynął na powierzchnię morza na powierzchnię morza, nie było w tym czasie regularnych drzew i w których się podniósł, się w ciągu jednej z czapeczki i zachód, z rozpuszczonymi tysiącami świec z których parły się i w powietrzu się w górę i w
# Start epoch 0 of training; Temperature: 0.2 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z i z obnażonymi w nim górę i w mgnieniu oka do góry w kierunku z wolna do niej w tej chwili w kształcie jaja, które się w nim i w tej chwili na wpół do dziewiątej rano. w tej chwili zapukano do drzwi i zaczął go z wielką i tak się z nim że nie ma w tym nic
# Start epoch 0 of training; Temperature: 0.3 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z i z w których się w tym stanie nie było w tym nic dziwnego, że w tym miejscu znajduje się cały dzień w tej chwili w cieniu drzew i na ścianach wisiały szkice i się w tym celu do najdalszych lektur.
# ten krzywosąd i norwegii, w domenie publicznej.
# wszystkie materiały dodatkowe (przypisy, motywy literackie) są udostępnione na licencji wolnej sztuki ..
#
# fundacja
# Start epoch 0 of training; Temperature: 0.5 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z pistoletu, który ze swej strony był to jedyny rzut oka na drogę i z zapartym tchem się w nim na koniec na nowo w ten sposób, że w końcu nie było w tym nic nie mogło się w niej i nie się w tym więc razie w tej chwili na zamku siedział stary maćko i ja go do niej
# Start epoch 0 of training; Temperature: 0.8 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek na kopie, owszem, tam gotowała się staruszce, że właśnie w połowie drogi stało się przeciwnie. był to pałac w ogniu razem z i w których kolan. zaczął mówić o tym z które jednak go mocno nosił. lecz o tym nie była to krzysia przystojna kobieta z i czystą jak zatrute w chwilach hołdu nie było ani córeczkę, a jednak już
# Start epoch 0 of training; Temperature: 1.0 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek cztery dwie wielkich pokojów. w tej chwili spala swego pastora według może ostatni minister, był najszczęśliwszym zresztą dla nich nie będzie już tego po raz drugi po stanowisko dołączyła się z ignasiu, nigdy jednak nie umiał powiedzieć w jego pamięci, że, mahbubie ali, uprzedzając naprzeciw prośby, zabij syna ale tym nie możesz się łudzić chwila śmierci. ta podłoga już w
# Epoch 1/20
#    6/1095 [..............................] - ETA: 2:54 - loss: 86.0928WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0438s vs `on_train_batch_end` time: 0.0984s). Check your callbacks.
# 1095/1095 [==============================] - 188s 167ms/step - loss: 84.7227
# Start epoch 1 of training; Temperature: 0.0 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z różowymi i w ogóle na pokładzie okrętu nie było słychać, jak na dłoni, ale nie było widać. gdy nagle posłyszałem w szczelinie jakieś żałosne głosy i dźwięki trąb i srebrem.
# - nie ma być? - rzekł - nie - rzecze - a co to za - pyta się - a co to za - pyta się bartek. - nie
# Start epoch 1 of training; Temperature: 0.1 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z różowymi i z których każda z nich była to pierwsza próba i złą, i wyłączną bronią, która była w nim tak głęboka, że nie miały siły do niczego się nie i nie mogli się pozbyć od tego, że w końcu i w ogóle nie mogli się pozbyć od tego, co się z nim dzieje, poślubisz i że nie ma
# Start epoch 1 of training; Temperature: 0.2 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z różowymi i w ogóle na pokładzie okrętu nie było słychać, co to za wesołe i tak się że nie można było zaufać i oderwania od razu do odjazdu. i wszyscy byli na pokładzie, a gdy tylko obudził, był tak oszołomiony, że tatuńciu! jacuś i nie zwlekając ani chwili, gdy tylko narodzi się na pięcie i wypić w mig się
# Start epoch 1 of training; Temperature: 0.3 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z różowymi i wszyscy troje na na czele armii, która w tej chwili nie mogli się z nimi rozstać. wieczorem karbowy zajączki ruszyli w drogę. kosmatka zeszła na dwór królewski. gdy król ujrzał piękną królewnę i spytała, co to za dziwny zdjęta i nieruchomy. ale gdy tylko król tak się do niczego.
#
#  a co to za spytał pan - zawołała
# Start epoch 1 of training; Temperature: 0.5 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z różowymi złota. w której mieszkał pewien szakal z pieniędzmi. był słowik, szczęśliwy i ma się rozumieć, że w końcu się w ziemię i to już nie tylko w nocy, ale i tak nie ma sił na tyle, że na tych pluskać się co prędzej na śmierć i na na co w tym czasie w z każdym razem nie na
# Start epoch 1 of training; Temperature: 0.8 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek na głowach. kiedy siedzi obok którego od dawna w trumnie nie było nikogo. próżno mi wpakował za puls list diabła do szkoły, ale bardzo się zdziwił, że przyjął z tęsknotą i nie zastanawiając się ani z nikim, ani do niego księciem niebywałym po kopał te zaczęły już poczęli go pieścić i kiwać i na jego była oszołomiona tym sposobem pewnego
# Start epoch 1 of training; Temperature: 1.0 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z wozami na brzuchach które znajdując się i szczodrze otoczoną dosyć płaszcz z czerwonemi policzkami, rozpozna złoty spojrzeć, a za to joasia o jej posłano pewien w odwiedziny do mocnych diabeł po to, ażeby wziąć udział w tym zakątku w głębokich wojsku. mogę panu jak wam przykro, kapustę, i ach! on taki zły, potrafisz ją widzę twoje suknie i drżącą
# Epoch 2/20
# 1095/1095 [==============================] - 183s 167ms/step - loss: 80.5977
# Start epoch 2 of training; Temperature: 0.0 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z różowymi i z których jeden miał w podziemiach, a potem okręty na łbach i na lewo, na kształt i w w których się pólko było w a z nimi na i w stawie, na i w środku stał wielki diament, który w tej chwili mógł się przekonać, czy to nie oskierko. ale gdy się już w końcu nie pokazuj
# Start epoch 2 of training; Temperature: 0.1 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z różowymi i z których jeden miał na sobie na wyspie i tak się że nie było w tym mieście ani ani ani ani ani ani ani ani ani ani ani ani ani na ani na uznawany sobie nawet na nie na w podziemiach, jak czynisz. ani o tym nie nie rzucisz się na to w nie ma nic do
# Start epoch 2 of training; Temperature: 0.2 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z różowymi i z których jeden miał w podziemiach, a potem z w kształcie a stamtąd do miasta i w tym samym czasie dotarli do wsi, gdzie mieszkała zaczarowany w domu i wkrótce po powrocie do bagdadu do balsory pod wieczór wypatrzył go siedzącą na i zapytał:
# - co to za spytał piekieł, co to za spytał król.
#  - rzekł -
# Start epoch 2 of training; Temperature: 0.3 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z różowymi i wkrótce cała rodzina miała sprać a jego królewska wysokość chińczyk rozniosła się po ulicach i po kilku miesiącach żeglugi pozostawał na pagórku koło bagdadu do balsory pod koniec uczty i tam byłem, że królewicz, nie mogąc się doczekać swej uczciwości. a gdy król wrócił do domu i już też!
# - - krzyczeli i uśmiechać i mówi:
# - nie
# Start epoch 2 of training; Temperature: 0.5 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z obrazkami, a w tej chwili było coś w rodzaju budowania trzech żywiołów, które jej nogi były tak piękne, że nie mogły się powstrzymać od łez, ale nie mogła się powstrzymać od śmiechu, bo się tak w niej i że nie wiedziała, co począć. zaraz po pewnym czasie i po chwili jednak powinna się przekonać, czy nikt nie zechciałby dobrać
# Start epoch 2 of training; Temperature: 0.8 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z obrazkami, a następnie znowu kupiec postanowił wyruszyć w świat z księżniczką i zostać królem w drodze do domu, gdzie przysłano mu rękę i i w ten sposób w takim właśnie czasie dostanie się do tego domu. spytał co tam tak fantastycznie do ucha tę dziewczynę, ale nie mówił nic nie mylę. pani majstrowa nie miała się stąd na powiedziała
# Start epoch 2 of training; Temperature: 1.0 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek do bieguna za zamknął pola, się, pomiędzy wzgórzami twardej straży wznosiły się szerokie skały, jak murem wicekróla zazwyczaj noc była północ, niby czarne, ale nadejście stóp pewna zamknęła firankę, w zamian połowę mózgu. w chwili niespodzianej dziecięcych lat dziesięć, dwadzieścia cztery pojechał? spytał dukaty, chłonąc pokrytego zbliżył się dziwnie do pustego gdy wtem jeden ze posłańców ostatniego tendencja dał mu
# Epoch 3/20
# 1095/1095 [==============================] - 188s 172ms/step - loss: 75.5528
# Start epoch 3 of training; Temperature: 0.0 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z wodą na głowie, a ojciec nie ma już żadnej odpowiedzi, ukroił mu sito, jak gdyby z dachu wejściowe na grzbiecie.
# - nie powiadajcie! - wołała matka. - nie ma już żadnej odpowiedzi, ukroił mu krowę z kieszeni.
# - nie powiadajcie! - wrzasnęła - nie - odrzekł - bo jasiowy placuszek wyszońka i jego żona powiedziała :
# - - nie mogę
# Start epoch 3 of training; Temperature: 0.1 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek na ziemi, a w tym samym momencie znikła i ujrzał roka, jak się to stało, że nie ma już żadnej odpowiedzi, ukroił mu sito, jak gdyby z pobliskiej karocy i na widok pastucha i picia. na próżno się do niej przywiązała do rymowane mi się, że to jest jej życzenie i nie mogłem się nadziwić - powiedziała mamusia. - nie
# Start epoch 3 of training; Temperature: 0.2 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z wodą na głowie, a w tej samej chwili gęsta postać urgeli przepełniła się dreszczem, w której się otwierały i w lewo, w powietrze i w powietrzu słychać było żałosne głosy i ciche pietrzyk skoczył na boki.
# gdy nagle zaczęła. tatuńciu! królewscy pozbywa się i rzecze:
#  a gdzie tam, w tej samej chwili drzwi się otworzyły i weszła do chałupy.
# Start epoch 3 of training; Temperature: 0.3 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z wodą i zawołała:
#  stoliczku, nakryj się!, a potem na zegarmistrza są malutkie i złote jabłko, które potoczyło się przez las, a potem odpocząć i w końcu dotarli na skraj lasu i zaczął dukaty garściami wypatrując swojej i pięknej dolinie, ale w tej samej chwili z lekka poklepał go po strapionej w stronę i z wielką kamratów w i w
# Start epoch 3 of training; Temperature: 0.5 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z wodą, a ojciec chrzestny i rzekł:
#  nie wiem, co cię czeka, bo nie mogę tego zrobić dla mnie to samo, co dziewczynce do mnie w tym samym momencie zobaczyła zawiniątko przywiązane do nieba i zbliżyła się do wieży.
# gdy nagle obmył demokracji, bazyliszek i chodząc po lesie i nie mógł się powstrzymać od śmiechu, gdy go ujrzał, a kot
# Start epoch 3 of training; Temperature: 0.8 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z wodą wspaniały sztucznego ptaka, który szedł za domem, aby się z nią położyć do stołu, a przez nie bury były zabrał się do roboty. po jakimś czasie królowa trollica skinęła na braciszka, zobaczyła trzy które potrawy była bardzo zadowolona. usiadła i już chciała wyjść od swojej roboty, ale młoda ta zgodziła się zwiedzić królewnę. kochana dziewczyna i nie chce
# Start epoch 3 of training; Temperature: 1.0 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek na srebrnych rumakach, lesie, mieniąc się czarnymi rycerze i rozbawione panie bez prawda, że wyrosło śliczne języki, bo postanowił swobodnie je tymczasem podano plon wasza królewska mość przyszedł po za pychę i odparł:
#  niestety, mów. cóż mnie, w o tem ano, tak przez dziewięć lat, aby mi powiedział: moje biedne dziecko. lepiej jestem cechami powiedział piękna. wtedy pójdę natychmiast i
# Epoch 4/20
# 1095/1095 [==============================] - 189s 173ms/step - loss: 71.2676
# Start epoch 4 of training; Temperature: 0.0 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z obrazkami, a w końcu żywiłem się coś z sobą i z całego serca i nie odwracać się do tego, by się nie udało uciec na te słowa, nie mogli się powstrzymać i rozmawiać z nią na noc. ale kiedy się spotkały, rozmawiały o tym z i o tym, że nie namyślając się długo, siwa i błagając o litość. gdy
# Start epoch 4 of training; Temperature: 0.1 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z obrazkami, a w tym domu nie ma nikogo, kto by się nie udało uciec na takie oto słowa:
#  trudno, aby się nie narażać na to, że nie mają prawa do niczego. nie ma nic wspólnego z naszym roślinnym niepodobna nam było z tego powodu czynić za to i tak się też stało. ale jeśli nie uda się na stajań
# Start epoch 4 of training; Temperature: 0.2 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z wodą, a potem do browaru tam bal, który miał córkę i że go w końcu nie tylko nie było nikogo, ktoby chciał się z nim wspinać na górę, a gdy się już do góry i królewna się z nią i z na pewno nie ma nic do nie ma w domu żywej duszy. ale nie ma w domu nic
# Start epoch 4 of training; Temperature: 0.3 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek na ziemi, a dzieci z tego powodu nie mogli się oprzeć pałacowi kapitan wraz z tysiącem ludzi chwalił się, w jaki sposób się do tego dnia król wyruszył w drogę. gdy w domu króla i na czele kilku rycerzy powolutku zabrali się do roboty, a w końcu z i z na które wyrzucony przenigdy! na co się na pięcie i
# Start epoch 4 of training; Temperature: 0.5 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek na ziemi dwa talary i dwa worki z guzikami, na której miotała się w niej z otwartymi ramionami i z lekka poklepał go po ramieniu. a może i tak się stało i tak urzekła taka głupia o to i ja jestem do mnie nieszczęśliwy, że nie mogę się powstrzymać nawet na świecie. jak ci się zdaje? jest to wryty i
# Start epoch 4 of training; Temperature: 0.8 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z kotliny. na głowie parę palców i wyleciała jeszcze bardziej, gdy wyjęła kołowrotek zerwał się z miejsca, gdzie ją a tak mówić i napił się i umyć. oczyma miała małe, czerwone oczy jej rzuciły się pod jej stopami ze skargą, że widzę taką samą z jaką ty rzekła poważnie dworskie po śmierci a to jest miejsce ale morskiej. czułem, że
# Start epoch 4 of training; Temperature: 1.0 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek zeń talerz, drugą pięścią kapotę na ognisku i zatrzymał się przed ognisko męża. tutaj nie było tak i wiosła. brał że już przy blasku słonecznym migały się schody.
# ale tak głośno różnobarwne, wypełniało jeszcze domki z muzyką, a najstarsza ze swych przybyła już jako i dalej, bo uderzyła go gorącą i przenikały przez po lewym końcu i zostawała przez pokój
# Epoch 5/20
# 1095/1095 [==============================] - 190s 173ms/step - loss: 66.7580
# Start epoch 5 of training; Temperature: 0.0 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z obrazkami, a w tym samym momencie wstęgi nad jeziorem siedziała piękna kobieta wpakowała w ręce wilka obie siostry zaczęły w końcu załodze tańczyć z nim przeżyła domek z dukatami i codziennie mijał obiad, a gdy się już w końcu królewna wystroiła się i przyozdobiła drogocennymi klejnotami, a potem szybko na nie zeskoczyć z łóżka i dalejże je na to
# Start epoch 5 of training; Temperature: 0.1 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z obrazkami, a w tym samym momencie wstęgi nad jeziorem siedziała piękna kobieta wpakowała w ręce wilka obie siostry zaczęły w końcu załodze tańczyć i oddaliła się z dachu nad i spostrzegli, że to jest duża góra, na którym przeżyła i wytrzeszczył, jak się okazało, na co się w tej chwili nie było ani ani ani ani ani w nie
# Start epoch 5 of training; Temperature: 0.2 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z obrazkami, a w tym samym momencie wstęgi nad jeziorem siedziała piękna na szczycie góry. bolko włożył je do wody. gdy ujrzał przed sobą wspaniale zawołał:
# - dziewczynko, dziewczynko, wyjmij mnie z rąk obydwa które ci się pieczone gospodarze, którzy się na jasio i nie się z nim nawet na żarty. ale placuszek nie mógł się powstrzymać od krużganku na i
# Start epoch 5 of training; Temperature: 0.3 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z woreczka na sprzedaż. gdy zobaczył malutką ludzką dziewczynę o rozkazał mu uprząść złotą nitkę i głośno zaczęła z bólu i podnosili ją do piersi.
# - a co to - zapytała dziewczyna - ale ja piesek i ja się nie przyniosę na a ja ci się nie uda. wtedy jonas powiedział:
# - nie - powiedziała lotta.
# - tak, to ja, - spytała
# Start epoch 5 of training; Temperature: 0.5 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z powrotem. - rzekł tom.
# - pewnie, że tak bardzo przyjemnie i słodko, że to był tylko malutki, malutki z obawy miał tak tępą i że okienko w głębi duszy jest to droga, pierwszą rzeczą, którą akurat w dzień jeśli nie dostanie srebrnego za to rzekł do siebie i z tajemniczą na to z nie do licha! ojej, jak to się
# Start epoch 5 of training; Temperature: 0.8 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z jęczmienia, a raczej tylko drewniaki i pilnował polny kwiatek i cały świat był nawet maleńki który z zamku. był już tak daleko, że niby stary i wytrawny marynarz zbliżył się do strażnika i rzekł do dlaczego ci nogą po chwili już o nie znam lalek. uciekniemy po swoją rodziną i na nice głowy nie zwlekając ani chwili wrócił do
# Start epoch 5 of training; Temperature: 1.0 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z przedziwną szybkością na polowanie z do miasteczka zaniosły matala tam z powrotem do ogrodu i wrzucili ją do wody. w końcu przekonał się, że dziewczyna straciła jedną z ludzi. jaki to zbój wyglądał tak pan a teraz idę z nim jeden po drugim z drewnem dał sobie aż konia, jeszcze go ani póki nieszczęścia ich nie nadawał spokojnie, powtarzał
# Epoch 6/20
# 1095/1095 [==============================] - 190s 173ms/step - loss: 62.9453
# Start epoch 6 of training; Temperature: 0.0 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z murów. - rzekł - nie ma co bo to jest misie powiedział król i zabrał się do jedzenia. gdy się lękał, by nie podziękować, to nie ma co do więc trzeba było iść i iść do sezamu i mamrotała między sobą żaba i mówiła:
#  nie ma co do na to trzeba było się zdarzyć. - powiedziała do a to
# Start epoch 6 of training; Temperature: 0.1 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z murów. - rzekł - nie ma co bo to nie jest takie jak ja - powiedział - ale nie mogę się już doczekać - powiedział - nie zwracaj uwagi na to, że nie ma co bo jak nie ma - powiedział i już nie będę się z nim bawić, bo to są nie do wiary! a ja i lotta.
# Start epoch 6 of training; Temperature: 0.2 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z murów. - złota.
# - a ile? ile?
# - za ziemię! - oddałeś wam jakąś słyszałam od waszej wysokości i z tymi słowy wrócę do masz rację, bo nie wiem, co się mrugnął na mnie i rzekł:
#  co to ma na myśli i nic nie ma. a co dalej? co za siła na to.
#  a co dalej? co za szczęście!
# Start epoch 6 of training; Temperature: 0.3 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z murów.
# - w imię boże! - rzekł - nie ma co bo to są moje - rzekł - bo inaczej nie ma co bo i tak nie a to bądźcie - rzekł - bo inaczej nie ma co bo tam podziomka bo co do tego nie ma co bo to przecie nie będzie z to nie bardzo się ale
# Start epoch 6 of training; Temperature: 0.5 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z murów. - dziwili się bardzo, ale się omylił. a że chłop nie chciał się zgodzić na to, że jest to najlepszy i najpiękniejszy z ciebie odpowiedź, którą ci ofiarowałem ci wszystko, co robisz, rzekł fred niema teraz innego sposobu na oczy. ale teraz już nie było do mnie ani przez chwilę. ale muszę je nazywać z największą chęcią odpowiedział
# Start epoch 6 of training; Temperature: 0.8 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z dziećmi w parafii w a na dnie był jasny dzień, potworny słońce padało na siebie i sprzedawali ich ludzie takie uważały za ale jak królewna skończyła się pracą uczciwą i nie ma już żadnej wartości. czy to ona jest księżniczką. może nawet i na tym polu i nic nie tak, jak nie mam szczęście - rzekła królewna i ją
# Start epoch 6 of training; Temperature: 1.0 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z koszami na wierzchole której mułów zostali głębinie wielkie, tam jesteśmy, tak jak raz w pobliżu. jedni nie widzieli gromady mieszkańców trzęsipiórek bo owe przez brzydko były to bowiem czasy czerwone, zamiast który podobnych możliwości spełniać się już ma znowu strzec klatkę, gdyż ludzie szybko rodziny tak więc o tylko bo wieczorami zawsze rzeczy sięgnąć, a znajdziesz się w krwawych
# Epoch 7/20
# 1095/1095 [==============================] - 187s 170ms/step - loss: 59.6788
# Start epoch 7 of training; Temperature: 0.0 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z najpiękniejszych i tak się że nie miała nic do roboty, a nawet na pewno nie się z ani do picia. w tym celu rozpędził się wokół skały. otwór się już dobrze otworzył. za nią. królowa urodziła dziecko, była bowiem jedyną rzeczą, której nie wiedziała o tym, co się stało. w ten sposób udało się jej nabrać gadając ją z
# Start epoch 7 of training; Temperature: 0.1 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z najpiękniejszych i tak się że nie miała już ani jedzenia, ani kąta, w jaki sposób nie miała nic w ustach i ani na chwilę. w końcu postanowiła przesiedzieć coś z wielkiem i dziwiło to głupim charakter swej i obie jej kwiatek, wsłuchując się w jego sercu w jego sercu i uprzedził, że nie znajdę w tym czarów. pamiętam, jak
# Start epoch 7 of training; Temperature: 0.2 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z najpiękniejszych i tak mu się podobał, że nie miała nic do roboty, a ponieważ była bardzo miła i dziewczyna nie domyślała się niczego, tak jak i w końcu uległ prośbom chłopca i że nie ma nic prócz gęby, na tym palcu. - rzekł król i zabrał niktusia a gdy już był w domu. a gdy ujrzał zająca uwięzionego w
# Start epoch 7 of training; Temperature: 0.3 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z najpiękniejszych i tak mu się podobał, że nie miała już czasu zastanowić się nad tem, co jej wpadło w jej kierunku myśleć. gdy królewicz chciał go poślubić. ale gdy król chciał się przekonać, jak się to wszystko nie podoba, że nie jest to moje i nie ma co się z nim rozstać. wieczorem, gdy królewna bolko powiedział jej, że
# Start epoch 7 of training; Temperature: 0.5 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek na ziemi, a w kąciku sansonetto ruszył w dalszą no i złapałem go na wszystkie strony, a teraz z początku nie było już w stanie posłać do domu! krzyczał kujbaba z wieścią, że w tych czasach król wysłał syna do księcia i do jakiejś pięknej stolicy. przybył z miasta do przeżyła na nocleg, tym bardziej szeleścił jego szczęście za jego
# Start epoch 7 of training; Temperature: 0.8 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z rozmaitych kwiatów, po większej części jak je pokusa, by uczcić jego szczęściem. za każdym razem rodzina jego jest dość trudna. a w końcu do tego jeszcze żaden z nich nie wiedział, co ma teraz robić. po dawnemu nikt mu nie zażąda od jego powrotu. biedna matka robiła coś w to cudownie, to, ale po drodze jagodami mieli za krótkie,
# Start epoch 7 of training; Temperature: 1.0 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek na ogólny grobowiec pt. a na swoją zabawę dla zmarłego króla i minister tak się zamierzał przekonać, kto to za to, że mu spłatał swemi mąką, a widząc, że niczego nie znajdę w życiu. miłość ta skończy się w jakiejkolwiek chwili, i oto na chwilę swoją potem błogosławił mu powiadać nad co znaczyło przygotowane wytrwale, siedząc w i po drodze,
# Epoch 8/20
# 1095/1095 [==============================] - 189s 173ms/step - loss: 56.2433
# Start epoch 8 of training; Temperature: 0.0 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z najpiękniejszych urodzenia. właściciel, i odeszła w ślad za nią, ujrzała na zakręcie ulicy krzywą, twarz miała jedwabną suknię, a królewicz spytał ją, czy nie jest ona tak mała, ale nie wiem, co ma zrobić, a ja też nie będę miała nic do roboty, a gdy się tak bardzo uśmiechnęła, a potem znów się kościej z powrotem pobiegła do lasu,
# Start epoch 8 of training; Temperature: 0.1 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z najpiękniejszych urodzenia. właściciel, i odeszła w ślad za nią, ujrzała pomnik. na pokładzie sądowej siedział owczarz, który natychmiast zaczął wrzeszczeć i wzbił w świat. a gdy zobaczył godzinki swoje i tak wielki i czarodziejski skok dał
# mu za to, że w tym celu nie ma nikogo, kto by się nie robiąc i nie mógł się z nim wdawać w
# Start epoch 8 of training; Temperature: 0.2 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z najpiękniejszych urodzenia. właściciel, i odeszła w ślad za nim i znalazła się na pokładzie, zapytał matkę, czy nie ma w tym czarów. pamiętam, jak się dowiedziała klara zaś rzekła:
#  nie mogę tu wić się i prosić o pomoc, jeśli nie zgadnie zawołał sługa, bo był taki zwyczaj, że zamykała się na baczności, a potem wrócił do domu z i
# Start epoch 8 of training; Temperature: 0.3 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z wodą połeć brylantów, skacze, najgłośniej jak w sercu i w świetle miesięcznym się nagle w górę i po chwili rozległ się głos, a w tej samej chwili zjawił się w sali i ujrzał w wodzie kłębek wysadzana i rzekł: wrzuć kawę, a resztę umowę na popiół, pozdrów cię ode mnie wyskoczyły z tej się i czułem, że w tej
# Start epoch 8 of training; Temperature: 0.5 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z murów. był jeden z tych dwóch groźnych rycerzy, a w dodatku tak że w razie potrzeby oczekiwać trzech śpiewających liści i tęskniła do wieczoru w dnia odbył się ślub królewski. kasia królowa pomyślała o swoim ukochanym i o tym, jak wzruszała ją żałość i jak jej wesoło! a gdy o zmroku janek życzył sobie sił. kiedy jednak słudzy z
# Start epoch 8 of training; Temperature: 0.8 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z rozmaitych osób. była to dziwna choroba wielkiej radości i królowa śniegu mówiły sobie tylko to, co niezrozumiałe i pianę rano przyglądał się cudnej urody przed ojcem. żadne nie mogły znaleźć drogi od jego zwiększonych gęsi i nagle jego oczy. nikt nie był w stanie powiedzieć, jakie jest jego radość! a kiedy mnie tak wahała się, o co mi się
# Start epoch 8 of training; Temperature: 1.0 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z córkami myśliwego i inne innych codziennych najpierw zbyt prostu mnie to nazywała na razie, jeśli odpowiesz mi na ten przykład, czy też innemu krzywdę i szlachetne, musimy wybrać w się wieczorem, ludzie z afryki poszli za każdego, abyście obnosił ptaszka, zginiesz ludziom. bądź co bądź szczęśliwy, gdyby przypadkowo wszyscy razem zmarnował cały dzień i podszedł ku wiosce z dziadkiem
# Epoch 9/20
# 1095/1095 [==============================] - 189s 172ms/step - loss: 52.6862
# Start epoch 9 of training; Temperature: 0.0 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z głazów, które razem z jej wnętrza się w ten sposób powstała książka o i czemu, w którym mieszkają. wszystko to było takie trudne. jeśli nie mają ochoty wyjść za przepowiednia więc zasłużona mikesz, staruszek przystąpił do kamienia. wreszcie amina pojąć nie tylko wspomnianą maścią ani chwili, ani się nie ani ani ani ani nie znudził się ani chwili, lecz
# Start epoch 9 of training; Temperature: 0.1 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z lasek na wyższej ulicy czekały na niej niezwykle duże, czarne buciki, tańczyły w jej policzkach. były to jednak okienko wychodzące na podłogę i kiedy już był gotowy, chłopiec porwał ją z całej siły i
# - a co się z wami przychodzisz, jak niemowlę, a zniósł, że to nie jest w głowę.
#  jak ci na tym i ja i tak
# Start epoch 9 of training; Temperature: 0.2 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z najpiękniejszych talerza do chin i podała mu go do powiek. kapela wróżka i otarłszy oczy, podeszła do okna i zaczęła się martwić, co się stało z w ręku, i zapukała do drzwi i zawołała:
#  piękny mam towar i bardzo wychyliła się z łóżka i po chwili znów zaczął się i się w końcu śpiewanie nie zmrużył oka ani na
# Start epoch 9 of training; Temperature: 0.3 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z lodu, a że nawet nie przyznawała się do tego, co jej się podobało. przyszła mu rozkosz ta sama, która jej pozostała w tej samej chwili wstawała coraz bardziej, przyglądając się pannie, lecz w końcu przestała się więc przyglądać i prosiła pacierz, aby się zdziwił, że nie żyje. a kiedy się rnal; fred ustawił stolik na się.
# - gdzie tylko masz
# Start epoch 9 of training; Temperature: 0.5 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z przedziwną pogardą. nie zatrzymuję się dopóty, dopóki nie nie na żaden z nich nie wie, jak to będzie dobrze, jeśli to będzie - odrzekł - bo tam jest nasz znajomy podziomek. ale kiedy go nie ma - pyta doktor.
# - no, a cóż to za spytał drwal i wyszedł na wesele, żeby się z nami ale to już nie
# Start epoch 9 of training; Temperature: 0.8 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z kwitnących kęsem pewnego rodzaju najdroższa, co ty mówisz, zawołała. dlaczego nie chcesz mi skrócić tej i muszę cię ale podejdź z pewnością i bardzo będę ci posłuszny i będziesz panem na to odpowiedział murumadarkos diabłem nie znoszę koloru i cała tkanina męcząca bijącym od chwil kości wróciły do letniego kiedy dworzanie zaczęli się było domyślić, co spojrzy na nim:
# Start epoch 9 of training; Temperature: 1.0 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z najpiękniejszych talerza po całym mieście, a w lesie mieszkał siostra a królowa stanęła przy tak rozmawiali, podnosił gałązki, aż droga doń drżała ze świeżych ach, wyjątkowo piękne buciki kiedy się do tego kot to mu się udało! chce się powieść, gdy sobie poradzę, nie nauczyły się ich to takim jak i powtarzała mało, jak cień prawdziwy. ale jeśli mnie
# Epoch 10/20
# 1095/1095 [==============================] - 189s 173ms/step - loss: 50.0184
# Start epoch 10 of training; Temperature: 0.0 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z najpiękniejszych przedpokój posłusznie udał się na dwór królewski, do którego mieszkała królowa miała syna jedynaka, który był bardzo bogaty, a jego młodym ludziom uważnym obudził swoją siostrę i dał jej pieniądz ta wrona w tak że nie odpowiadam za skurczu czego ode mnie ocalił ci życie. widzę, że umiem być nie ma prawa do cierpliwości, cierpliwości, człowieku jak i
# Start epoch 10 of training; Temperature: 0.1 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z najpiękniejszych przedpokój posłusznie udał się na dwór królewski, do którego mieszkała królowa miała syna jedynaka, który był bardzo bogaty, a jego młodym ludziom uważnym obudził się i zaczął wybierać na kupno kija, co się nie działo i poszedł do domu poruszyły się jak w głowę.
#  nie płacz, tylko błagam cię, abyś nie wyrządził mi żadnej krzywdy. musisz więc oddać
# Start epoch 10 of training; Temperature: 0.2 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z najpiękniejszych przedpokój posłusznie udał się na dwór królewski, do którego mieszkała królowa miała syna jedynaka, którego zrobił z deską dworu i z powrotem do szkatułki, a ponieważ jego bracia nie mieli innego wyjścia, jak tylko czekać, a nie tylko się w nich ale i tak nie pozwala. a tu i owdzie obrała sobie glinianym więcej na świecie rosły i
# Start epoch 10 of training; Temperature: 0.3 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z najpiękniejszych przedpokój posłusznie udał się na dwór królewski, do którego mieszkała królowa miała córki i całe towarzystwo, oprócz trzech różnych tebańskich i srebrnych jabłek, które wpatrywały się w siebie z ludźmi i z pewnością nie może równać się z jej hi, hi, hi, hi, hi, hi, hi, hi, hi, hi, hi, hi, hi, hi, hi, hi, hi, hi, hi,
# Start epoch 10 of training; Temperature: 0.5 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek za mąż. aladyn pokazał z powrotem swą prawdziwą córkę, a siostra jego tajemniczej i pięknej kobiety. nie mogąc już dłużej wytrzymać, zabił go, lasse kazał więc wyprawić do kościoła i raniutko, by chodzić po mieście, natychmiast wrócili do domu. i tak oto w podwieczerz uniosłem do niego rękę, która przykazał, a potem sprytnie się i że musi być z tego
# Start epoch 10 of training; Temperature: 0.8 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z najpiękniejszych przedpokój skoro nie udało się na jego ręce, a siostra tymczasem staruszka udała się do zamku, ojciec i matka cudowny zapełnił się a jego dzieci zaczęły przeraźliwie robić smaczne gdy stół roił się od nagłego śmiechu, bo gdy tylko szukała u jej twarzyczki i że rozsądnie nie zwlekając nigdy nie słyszał o gorączce. zbudziłem się i brama sezamu
# Start epoch 10 of training; Temperature: 1.0 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek za mąż. kiedy przyszli na łąkę, zdołała j ą czy darł się jej nie mogą najmniejszego kija ją brakowało. ale jemu po tej chwili coś a sama coś zarobił albo na życie, wobec tego, że gdyby ondra miał brata gdy trolle zwlekając, nie słyszał jeszcze, gdzie by na sobie podzielić rzemiosło, konia, ale niczego mu się nie zda że jak
# Epoch 11/20
# 1095/1095 [==============================] - 187s 171ms/step - loss: 47.3523
# Start epoch 11 of training; Temperature: 0.0 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z szyb. kowal zaczynał śpiewać. a żeglarze zaczęli
# się z nich robić tak pięknie, że aż kiwit! tatarzy!
# - - wołali do
# - to prawda, że
# - a to wy, kumo, o to chodzi, a ja wam mówię, że na nich litce i że nie umiałbym tego nikczemnego i nudzić się nie ale ja go nie ale ja cholewy, bo
# Start epoch 11 of training; Temperature: 0.1 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z szyb. kowal zaczynał śpiewać. a żeglarze zaczęli
# się z nich robić tak pięknie, że aż kiwit! tatarzy!
# - - wołali - nie ma! nie ma! nie ma! nie ma! nie ma! nie ma! nie wierzycie, dwuoczko,
# - nie lękaj się ciebie - powiedziała do orzeszek i
# kazał się wieźć na i ruszył w dalszą drogę na poszukiwanie na i
# Start epoch 11 of training; Temperature: 0.2 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z szyb. kowal zaczynał śpiewać. a żeglarze zaczęli
# się z nich robić tak pięknie, że aż
# nagle z góry się w powietrzu zajączki ale to tak że nie było tam nigdzie za wąsy i ze strachu, gdyby mu się nie stało i nie i po co by się stało z a kiedy się to
# tak - i nie możemy się
# Start epoch 11 of training; Temperature: 0.3 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek za jedną z najpiękniejszych prosiły, by je nie mógł, żalił się na duchu i powiedział:
#  jeśli chcesz, to ci powiem: jestem z mojem wujem odrzekł ojciec chrzestny jesteś już bogaty i mam nadzieję, że jestem naprawdę biednym panem i że nie kumowie i o dziwy! szklanym tym razem nie rób mi krzywdy, cynamonu, wbiegłem na brzeg z w którym właśnie
# Start epoch 11 of training; Temperature: 0.5 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z mlekiem. zaniesiono go do rzeźnik nie mógł już przebywać w domu. a kiedy przyszedł olbrzym z polowania, okazało się, że dukaty było pięknie, ale król udawał, że nie może się ruszyć z miejsca. gdy się zbliżyła do brzegu, się i umrze. ale teraz już nie będzie mogła wrócić do domu przed kulawym uwielbia się w tych stronach, gdzie się
# Start epoch 11 of training; Temperature: 0.8 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek za kilka minut ojciec zbliżył się do stołu z w którym stał się chłopak inny i zapytał: czerwony blask porwawszy w plecy jego wzruszyła ramionami i rzecze:
#  teraz jesteś! wykrzyknął janek ale wpierw dwa razy niedołężnym klasnął w dłonie.
#  o! oto ty, na miłość boską, dowódca usiądziesz na rozdrożu, zawodzi, a jakże! nie pamiętam! to jest nie potrafię, jeden ze
# Start epoch 11 of training; Temperature: 1.0 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek za starą murami w okresie bożego narodzenia, joasia gdzie się spalić w stronę otwieraj, kasztelana jeśli królewska żeście ale nie na wszelki wypadek, to na dachu, nie na tyle większy jak mąż. a to wnet jest wyrok królewski, jak ty. powiedz gdzie się otworzyć? wybieraj z dołu buchnął wysoki krzyk większego się bajka kupił, co raz majster z prochu, ze
# Epoch 12/20
# 1095/1095 [==============================] - 189s 172ms/step - loss: 44.4617
# Start epoch 12 of training; Temperature: 0.0 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z niemi, z świeżych kwiatów. w końcu znosiła dźwięki natur zielonej, i przeczuwał, że słońce jest tak że nie widać było nawet ścieżki. trudno było zrozumieć, jak wiele było, bo nie było ani ani ani kuba, ani głodu, ani prośbą nie było, jak tylko to się i co się z nią stało, że nie ma co robić, co to za
# Start epoch 12 of training; Temperature: 0.1 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z niemi, z świeżych kwiatów. w końcu znosiła dźwięki natur zielonej, i przeczuwał, że słońce jest tak że nie widać było dziewczynce żadnej rysy. zawołał więc olbrzym, ale nie wiem, jak się do tego to powiedziawszy, mądra kobieta nakazała jej chrzestna rozwiąż go i rzekła do matko, mi placek i nie mieszaj mi się do tego ucieszył i połyskiwała schwał,
# Start epoch 12 of training; Temperature: 0.2 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z niemi, z świeżych kwiatów. w końcu znosiła dźwięki natur zielonej, i przeczuwał, że słońce jest tak że nie widać było dziewczynce żadnej rysy. zawołał więc po raz pierwszy w życiu widziałam ją już dziś w nocy na tym nie mogę upiec na palcach do nie mogę się już doczekać i zanim się z nią nie było w tym czasie
# Start epoch 12 of training; Temperature: 0.3 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z gęstwiny wyruszyło znowu.
#  więc bądź spokojny dlatego, że siedziałeś tu i tam, gdzie jest moja spytał pan.
#  go. czy to przyjemnie zrobić. przekonani, że nigdy przedtem nie jadłem - powiedziała mamusia. - przecież nie mogę wytrzymać w domu, bo inaczej nie będę czapnika w to rzekła myszka i jej z oskarżenia, że nie mogę tego zrobić. to będzie krowie,
# Start epoch 12 of training; Temperature: 0.5 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z niemi, z świeżych kwiatów, od do których przyczepione są małe dzwonki pięknie pod okiem południowym. obyczaj jego czaruje mnie, zębami walce króla w celu ratowania swego i jego królewskiej córki. traf jego umierał ze swojej historii. starzec słuchał opowiadania odzianego w zwykłą poczuła, mlaskając językiem, po rudej i plecach, z takiem co mi pomyślał i zaraz się jej od
# Start epoch 12 of training; Temperature: 0.8 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z gęstwiny wyruszyło znowu.
#  byłem pewien, że już za każdym razem masz słuszność rzekła badrulbudura. dałam mi natychmiast ten piękny sposób, a przekonasz się, że nigdy dotąd nie spędzałem u królewny łóżka ani w tej samej chwili per i nikt nie miał pojęcia, w co się tak działo, kiedy sługa i wszyscy się przez nie czy nie było to wcale
# Start epoch 12 of training; Temperature: 1.0 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z się wszystkim porządną z okolicznych legend odrzekł grzecznie przy i po odczytaniu tego, co mu rozkaże zrobić z tą rzekł aladyn zgadzam się na długo. teraz, podczas gdy ja nauczyłam się za pierwszego i dziwno mi było pomyśleć, że umrę ze błotne bo zaraz znajdziesz się na tej za i sobotę, kiedy ja się tego domu, więc rok już
# Epoch 13/20
# 1095/1095 [==============================] - 183s 167ms/step - loss: 41.9978
# Start epoch 13 of training; Temperature: 0.0 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z niemi, z świeżych kwiatów, od których nie radowało się ani słowem, ani ani ani ani ani stróża, ani chińczyk nie zapytał:
# - czego żądasz, drogi mój najdroższy panie - rzekł - wybacz, jeśli cię tym, co mam powiedzieć. czy zdajesz sobie sprawę z tego, że nie mam zbójców, czy masz tu iść i podskakiwać tak potężnie, rzuć się na dół,
# Start epoch 13 of training; Temperature: 0.1 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z niemi, z świeżych kwiatów, od których nie radowało się ani słowem, ani ani ani ani ani stróża, ani chińczyk nie zapytał:
# - czego żądasz, drogi mój najdroższy panie - rzekł - wybacz, jeśli cię tym, co mam powiedzieć. czy zdajesz sobie sprawę z tego, że nie mam zbójców, czy masz do załatwienia tego pożytek. bo jeśli kasza nie przyjdą, ocali
# Start epoch 13 of training; Temperature: 0.2 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z niemi, z świeżych kwiatów, od których nie radowało się ani chwili. nie troszczyła się ścigała cieszyła się dobrym zdrowiem. żona księcia nie miała ochoty iść dalej i odprawił strażnika. przez cały dzień wędrując jedynie przez siedem lat, a wodnika przed chwilką nie było już w stanie powtórzyć, że w tym czasie, kiedy już wszyscy razem kasi, się nie klepignat
# Start epoch 13 of training; Temperature: 0.3 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z niemi, z świeżych kwiatów, od których nie się w rozmowie z tarabuk. precz z tego, kto posiada i myślę, iż nie jest ono zbyt piękna lecz jednocześnie komuś nie wolno nam podglądać przerwał się i skierował się ku wyjściu jaskini sułtan z rozpaczą stanął na nim ze swą tokarz od do i po raz pierwszy ujrzały śnieżkę leżącą na
# Start epoch 13 of training; Temperature: 0.5 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z niemi, z świeżych kwiatów, do konnej jazdy, muzyki, nieznanych żadnemu z rozrywki nie wydawało jej się wcale. w końcu usnęła i obudziła się więc myślą, że jest królem, a potem ren był to znany i ma miejsce dla króla, który ją i na całym jego miejscu mieszkał ojciec i syn króla i królowej, a za pochew tak wrażliwy na
# Start epoch 13 of training; Temperature: 0.8 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek za mąż. aladyn tłumaczył o małej podróży. mówiąc bez względu na to, że przelatuje jak srebro. obydwaj z powrotem będą jeść, a co z tego, że martwię się o rękopis i mogę cię zapewnić, że nie mam zbójców, bo odparło rozumiał. juści! klara, nie mnie, lecz abyście zdążyli przecież chwiać się niezadługo, matko, niech cię na koniec jaki się ten
# Start epoch 13 of training; Temperature: 1.0 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z pieniędzmi, i tyle mu guziki nie parobcy matkę na ręce dobrą ignac uczynił i zrabował śmierć i że trzyma w ręku sakwy, strzępy, to jeszcze czuję się parę lat od środka i na tej się nie, te słowa co? pytały mała jak ich tu nic nie było? spytała babcia. i się wstrętna wtedy, gdy mogą z nią zwierzyć się
# Epoch 14/20
# 1095/1095 [==============================] - 182s 166ms/step - loss: 40.3424
# Start epoch 14 of training; Temperature: 0.0 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z owocami i chłopak się uspokoił, a gdy pan rajca strubicz czarownikiem go nazywał, to jeno tak że był i był zawsze za to tak wielki, a w dodatku bandę w tych i w innych i w innych z których każdy z tych dwóch ludzi na ziemi jest i w tym się a to się nie i zostawiłam kiedykolwiek. w
# Start epoch 14 of training; Temperature: 0.1 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z owocami i chłopak się uspokoił, a gdy minął miesiąc i amina na widok zorzy. ognistym ze złota, rubinów, pereł i zagarnęli cały dwór królewski był dziwakiem, zawracał głowę cienkimi i wnet ujrzałem scenę, księżniczkę, a z każdego niebezpieczeństwa się do sosny. nie miała już więcej do roboty, gdyż odmawiam ci spokoju. jestem zmęczona, toby cię tak że nie potrafisz
# ...
# Start epoch 15 of training; Temperature: 0.3 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z wronich piór. do sukni miał być błękitny. ujrzałem w powietrzu rybę skrzydła, inne węże z takim było i wygodnie, na szczęście popatrywał na jego otwartą i powiedzieliśmy, że nie mógł się powstrzymać od śmiechu, widząc zamek, spadł i pił z beczki. a pan jego ucieczce zadarł się szczelnie, w tej repertuaru, daję! dlaczego nie trzaśnie obmyślić beztrosko drzewo. ówże
# Start epoch 15 of training; Temperature: 0.5 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z wronich piór i wesołych jak zwykle, zjedzony i jego ojca padł na kolana, wołając z sobą! to mi się podoba! pomyślała sobie i to być może bym się stąd uniósł do swego pana w zeszłym tygodniu schwycił myśliwy trąbą, aby z nim razem do domu, a ludożerca i chwycił się za głowę.
#  jeśli nie pójdziesz do mojej a niktuś
# Start epoch 15 of training; Temperature: 0.8 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z pokładu pannę, która miała na sobie szaty książęce, przetykane srebrem i złotem, niby gołąb z dawnymi należy teraz, kiedy go na i wszelako wstąpił w las i wydobywał z sił. pięć listków wieść o nocnym odbyło się tak, jak macieja widzieli. i już chyba jeszcze nie żarty, oddała garniec z w i wreszcie ścisnął go za sznur. wreszcie pojawił
# Start epoch 15 of training; Temperature: 1.0 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z mąką na jak to jedzie inny kuba z pełną ministrów, będziesz na włos nie czekaliśmy niedługo. koń morski wynurzył się z nich szalony i przerażony, się, że z trudem zdoła się nazywać śpiącego chłopak o pustym świecie. tyś mnie obdarzył niewdzięczny wydałaś w potrzeby biednego najwyższego szczęścia, na miłość dla rąbkiem całego dworu, za mego wuja. będzie jej skwapliwie
# Epoch 16/20
# 1095/1095 [==============================] - 184s 168ms/step - loss: 35.7689
# Start epoch 16 of training; Temperature: 0.0 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z wronich piór. do sukni miał być na swej drodze o dwudziestu czterech to mieli w którym nie było nikogo, siedmiu małych myśli miał piękny papier. lecz nie było nic innego jak nic na świecie nie widać. wreszcie królewna poczuła śpiącego sakiewkę, która była tak dalece tak mówiła, że jej nie było w tym nic nie ma jej ujrzeć. ponieważ
# Start epoch 16 of training; Temperature: 0.1 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z wronich piór. do sukni miał bardzo chmurami. nagle zadrżała mu w oczach, po czym wyciągnęła z kieszeni palec wołając: o! ta skała nazywa się uszczęśliwiony, podniósł głowę, spojrzał na nią i rzekł:
# - ach, mój drogi, uważam, że masz takie złe strony. jeśli jednak jesteś brzemienna moim żoną. w tym nie mam napój. gdybym był kapitanem, zrobiłem ci już na
# Start epoch 16 of training; Temperature: 0.2 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z najpiękniejszych wróżek klara zaś nie mogła się oprzeć pokusie i przystał na nie chciał, ani nawet nie był w stanie dać żonie i jego córkę. rozstali się ze swoim królem, by go mógł znaleźć w domu za jego córkę. rozstali się i po pewnym czasie znów i zobaczył tam już komornika, który miał na imię było za niego za
# Start epoch 16 of training; Temperature: 0.3 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z głazów, które w noc tańczyły ich! zerwali wody z lasu, na które się przez gałęzie, a potem na wyścigi ku polu niezliczoną ilość kawałków. miały moc pełne są przyjaźni i różne sposoby pozbycia się wyrobem siodeł, a bez powodu tak samo na tym świecie, jak to się mówi, a dla mnie to nie moja wszedłeś do jednego z ale
# Start epoch 16 of training; Temperature: 0.5 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z woreczka do ucieczki. ale on sam nie wiedział, co to za spytał go że wyszliśmy za niewolnikami już kawałek drogi i w ogóle jaśnienka nie dawała spokoju. a wilk puścił się pędem i spotkał psa z dwunastoma złotymi w czerwonym kieszeni o pień drzewa, na którym siedziała królowa chór, ale chustą, a nie widać było kwiatów. od tego czasu
# Start epoch 16 of training; Temperature: 0.8 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z wronich piór. do wieczerzy stawał się coraz i coraz liczniejsze głowy. kompani wyciągnęli ze swoją drużyną do odwiecznego kozy. szczęściem oraz służbą królewskiej, przygotował dla mnie jakąś wiarę, by mnie nie na takim dużym podziemiu koniec twój musi być dziś wieczór. ale nie mam z nim miejsca na prawe jej nie okrętowe, miasta bez nóżki, i zrosiła mu się
# Start epoch 16 of training; Temperature: 1.0 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z głazów, które razem z jej boku na czole rumiana i twarz tygrysa. gond chciał więc nie mieć brata jego, i
# przez dwór żółty wraz z nim wszystkimi dostrzegł piękny otwór w murze, a potem się z ust jego rzucały straszliwy manewr z umową którym się spytali po przebudzeniu mnie to się zainteresowała mię i spojrzała na mnie z ukosa
# Epoch 17/20
# 1095/1095 [==============================] - 184s 168ms/step - loss: 33.9529
# Start epoch 17 of training; Temperature: 0.0 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z wronich piór. do sukni miał być huczne wesele i zaproszono cud, że pastuszek się nad nim. bramin z rana mocno ostrzegła i nie zaznał się ani ani chwili nie mógł zasnąć. ledwie doszedł do polnej drogi, śpiewania jednak, rozkazał przepowiednia snów. podejdź do niej i pocieszać się w mojej i litościwym i orangutana, ale do ciebie i ducha i
# Start epoch 17 of training; Temperature: 0.1 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z wronich piór. do sukni miał być huczne wesele i zaproszono cud, że pastuszek się nad nim. bramin z rana mocno ostrzegła i nie zaznał się ani ani chwili nie mógł zasnąć. ledwie jednak spał i pomyślała, że się
# jej jakoś
# czy wstać. ale gdy tylko trollica śpi chyba u swego dworki i w końcu nie mogła się ani z
# Start epoch 17 of training; Temperature: 0.2 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z wronich piór. do sukni miał być huczne wesele i zaproszono cud, że pastuszek się nad nim. bramin z rana mocno ostrzegła i nie zaznał się ani ani ani słowa.
#  - pytał go król spójrz na ten okropny pomyśl tylko, co się stanie. teraz już ja się do tego nie bo gdy sezamu się na nim już nie wiem, czy
# Start epoch 17 of training; Temperature: 0.3 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z wronich piór. do sukni miał być huczne wesele i zaproszono cud, że pastuszek się nad nim. kiedy zebrała się na odwagę i wyłamał bramy i wyszła z nim na zamek, nie znalazł ani otworu, ani był zachwycony ani groźby nie mógł się powstrzymać od zwycięskiego no proszę! - napotkała na tłuszcz pieszo. urodą radża z długą włosach i z
# Start epoch 17 of training; Temperature: 0.5 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z mlekiem. zaniesiono go do kuchni na spotkanie i je na sam koniec z wielką powagą wracał na sam z ruszył do i czarownica zamknęła drzwi. chłopczyk przywdziała napis: z jakiego kiedykolwiek nadarza się królewiczowi rybą dla biednego to mój mąż nieboszczyk też tak że zbójca w domu jest w tym starym chustę, jaką sobie kiedykolwiek kto potrafił dorównać w
# Start epoch 17 of training; Temperature: 0.8 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek na których kwitną wspaniałe naczynia i śpiewały smutnie, ponad którym harfa uderzyły niekiedy ogromne miasto. zbójcy ustawili się w wielkiej sali, gdzie dwanaście i strzała. po pewnym czasie nadjechał królewicz i majster z powrotem do domu. księżniczka nie mogła usiedzieć w domu i odezwać się dziedzic.
# - to jest tym sposobem piękne! kiedy z najdroższej rękoma koszałek-opałek, gdyż oszczep uciekać,
# Start epoch 17 of training; Temperature: 1.0 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z wronich piór. do sukni miał być nadzwyczaj sznurem i szczęśliwiec po kolei otrząsnął się, bo widocznie chciał ją poślubić. ona wtedy królowa wpadła w taką rozpacz, żeby powstrzymać okolicę, kiedy poszedł na naukę do a to dlatego, że ondra zrobiłby masło królowi. ale sołtys stracił a co jednak tęsknica wszedł do siodeł. po chwili uspokoił się głośno i zmienił
# Epoch 18/20
# 1095/1095 [==============================] - 189s 172ms/step - loss: 32.1609
# Start epoch 18 of training; Temperature: 0.0 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z pokrytych białym pod aby rządzili swoją i w ten sposób bajki umieszczono ten od piętnastu mil po brzegach smutek pięciu i trzech dziewcząt z końmi, z szerokimi mieczami w ręku, z biczów i bale, z jeziora nie byli podobnymi puste; jak czarowny wypadek nie będziesz, i nie w rudej choć z klęczek i na na czym z na się
# Start epoch 18 of training; Temperature: 0.1 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z pokrytych białym pod aby rządzili swoją i w ten sposób bajki umieszczono ten od piętnastu mil po brzegach smutek pięciu i trzech dziewcząt z końmi, z szerokimi mieczami w ręku, z biczów i bale, i to wszystko w tych spodniach odbili i na łysą górę. wtedy księżna postanowił złapać aby obejrzeć wszystkie swoje pestki w najbliższą wigilię gdy po
# Start epoch 18 of training; Temperature: 0.2 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z pokrytych białym pod aby rządzili swoją i w ten sposób bajki umieszczono ten od piętnastu miesięcy po dziś dzień czerpie najczystszą baśń ludowa dosłownie w królestwie tego samego i jego był z tego niezadowolona i często gderała na męża. często musiała się położyć do jednego ze starych i wytrawnych ciekawy jestem, co mam robić z tym do i z
# Start epoch 18 of training; Temperature: 0.3 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z główkami dwa czarne do stawu. czyż w naszej stolicy nie było ani psów, ani samotności. w chwili gdy byłem już na schodach, obejrzałem się jej brzęczenie i rozesłał po raz pierwszy skrzydła, i aż dziw, że go nie zdradzi i nikt z gości nie był już w domu i nie słyszał nic o studni i jagna! był z tego
# Start epoch 18 of training; Temperature: 0.5 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z pokrytych białym do wrót, które zamknęły się i w końcu znalazł się w ciemnej wieży, gdzie właśnie ma matka? - myślał uradowany zachodem słońca odparł, że tak jest w tej samej chwili per z rodziną. rozstała się z wsiadła z powrotem do komnaty, w której żołnierze w swym pokoju i w wodzie. i tak się już złożyło, że obydwaj
# Start epoch 18 of training; Temperature: 0.8 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek za jednego z medyków królewskich, wszędzie, gdzie nie mieli nic w ustach. tym bardziej zębami poznała że że ten także bardzo się i położyła na stole. nie wiedziała, kto musi być jej duchem i że jeśli się gnoju, to minie trzydzieści lat, a uczyniła przez tyle lat, ile tylko zobaczę. ubrał się i otworzył drzwi przed wieczorem. podszedł wreszcie do
# Start epoch 18 of training; Temperature: 1.0 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z łuku, czy choćby były mieszkańcy królestwa - okazała się ona tak samo jak brzęczenie tych lipy pozostał tylko dziewcząt w owych strzelistych wysłuchaniu jakiegoś dziwnego kiedy dotarli nad morze. piękny karmin biegał i płynął w ślad za tłumem dotarł do trąbki. na schodach leżał ogromny ruch i gdy zdobią jej skrzat, pisał swe odmawiają kotwicę, gdy na głowach, potoczyły
# Epoch 19/20
# 1095/1095 [==============================] - 191s 175ms/step - loss: 30.3819
# Start epoch 19 of training; Temperature: 0.0 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z pokrytych małymi przez dołki i korzenie w marysia zaś, pełnymi rękami jak woda, a nogi ślicznie z najczystszego miodu. nad ranem też zaświtało, z miasteczka, pioruny, wielką złotą pięknie myszy, błyszczały jak dwie grudki i dała znak ręką. klara myślała, że to wszystko nie jest blask zachodzącego słońca dookoła i w tej samej chwili gęsta czynili, a w końcu
# Start epoch 19 of training; Temperature: 0.1 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z pokrytych małymi po brzegi po obu stronach jaskini. na tronie chryzeidy, w tej chwili piorun swoje duże włosy, szedł gościńcem mosiężnymi powietrze zaś się potem w górę, a maruda od zaczarowany wyciągnął z kieszeni list i udał się do pokoju, gdzie
# był w tym samym miejscu, zegar na samym środku i z na której szczycie się żywcem, i po
# Start epoch 19 of training; Temperature: 0.2 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z pokrytych małymi przez dołki i korzenie w marysia zaś, pełnymi rękami i gwarem i bębnów, a potem rzuciły się w objęcia ojca, a bazyliszek rad ze swego młodszego brata i go do pracy. a co z jego wysokości wyrosły na kolację do grodu, gdzie nikt inny nie potrafił oszczędzić jej po tak jak oka w tysięcy? rzekła królewna nie
# Start epoch 19 of training; Temperature: 0.3 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek z pokrytych małymi po ostatnim i grajek pany, księżna schowała swoją do ugotuj - pomyślał skąpiec i że miał rację, gdy się tak bardzo a może mu się panienka dobrze bajka o twardym pirlipaty była piękną i dobrą, a teraz królewicza jest uparte i nie się ani jedzenia, ani picia. i stało się to, co się dalekim, ludzkim zbudzić a
# Start epoch 19 of training; Temperature: 0.5 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek za mąż. aladyn zaproponował o tym dzisiaj liście i upadłem na łóżeczko i nie się głupiec z nie jest pewien, czy rzeczywiście zapomniał o tem, jak to się zwykle na ziemi, i o mało co nie było widać, a królewna wyszła z niej na i cudną, rozwarły się nagle siekiera i stanęła w nim dysząc, a stara baba, zapomnieli o
# Start epoch 19 of training; Temperature: 0.8 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek za mąż. a potem zaczęła płakać i głaskać jej tak wysoko, że zapomniała i pozwalał koniowi wpadłby na oparcie i stłuc ją w i prosto z go promienie słoneczne stawały się coraz gęstsze i czuł, jak szybko robiło jej się jak w tym spokojnym, że aż z chaty przelewa się od przebywania tam, gdzie się znajduje lampa złota, obrzydliwe jeziora.
# Start epoch 19 of training; Temperature: 1.0 Generated text: dawno temu czerwony kapturek poszedł do lasu. w rękach trzymała koszyczek na obu aby zerwać gwiazdę, zaczęli mu dokuczać, lecz udaje, że nie chce brać was. owce ojca, ile razy odezwali się kilka nie, to z pewnością nie to nastąpi. zacząłem zbierać wonne i proste. raz na zawsze w kilkunastu miejscach, obawiali się o los ich i jego większych nie ma mowy. ojciec jej był nieco był jednak zbitą była to
# Epoch 20/20
# 1095/1095 [==============================] - 189s 173ms/step - loss: 28.9368

# %%
from tqdm import tqdm
        
text_seed = "dawno temu czerwony kapturek poszedł do lasu"
for temperature in tqdm([0, 0.1, 0.2, 0.3, 0.5, 0.8, 1.0]):
    pr = PredictCallback(text_seed, 250, LEN_MAX_LIMIT, tokenizer, padding, temperature, model)
    text = pr.generate_text()
    with open(f'../generated_texts/text_temperature_{temperature:.2f}', 'w') as f:
        f.write(f'Seed: {text_seed}\n')
        f.write(text)
