# %%
from gensim.models import Word2Vec
from dataset import load_tokenized_sentences

dataset = load_tokenized_sentences("../datasets/pickled/books_3500_flat.pickle")
occurs = load_tokenized_sentences("../datasets/pickled/books_3500_occurs.pickle")
# model = Word2Vec(sentences=books_3500_dataset, vector_size=100, window=5, min_count=5, workers=12, epochs=10)
# model.save("../w2v/word2vec_large_model.model")
model = Word2Vec.load("../w2v/word2vec_large_model.model")

embedding_dim = len(model.wv)
vector_size = model.vector_size

print({"embedding_dim": embedding_dim, "vector_size": vector_size})
print("Dataset len: ", len(dataset))
# Out:
# {'embedding_dim': 691922, 'vector_size': 100}
# Dataset len:  207673043

# %%
for i in range(10):
    print(dataset[i])
# Out:
# tytuł
# a
# b
# c
# chrześcijaństwaautor
# alfred
# cholewiński
# sjprzedmowawprowadzeniekerygmat
# apostolskijezus
# nie

# %%
for i in range(15):
    word = dataset[i]
    try:
        similar_words = model.wv.most_similar(word, topn=5)

        print(f"Most similar words to '{word}':", [word for word, _ in similar_words])
    except:
        pass
# Out:
# Most similar words to 'tytuł': ['przydomek', 'pseudonim', 'kryptonim', 'podtytuł', 'rodowód']
# Most similar words to 'a': ['zaś', 'ale', 'lecz', 'bo', 'i']
# Most similar words to 'b': ['d', 'c', 'p', 'h', 'g']
# Most similar words to 'c': ['d', 'b', 'p', 'g', 'n']
# Most similar words to 'alfred': ['albert', 'jacob', 'walter', 'edmund', 'gilbert']
# Most similar words to 'nie': ['nigdy', 'oczywiście', 'też', 'przecież', 'jednak']
# Most similar words to 'tylko': ['nawet', 'jedynie', 'też', 'przynajmniej', 'zawsze']
# Most similar words to 'otworzył': ['otwarł', 'zamknął', 'otworzywszy', 'odemknął', 'rozwarł']
# Most similar words to 'nam': ['im', 'wam', 'mi', 'ci', 'mu']
# Most similar words to 'niebo': ['słońce', 'morze', 'słonce', 'obłoki', 'stonce']
# Most similar words to 'okrojone': ['przetrzebione', 'zniszczone', 'osłabione', 'uszczuplone', 'przeludnione']

# %%
import itertools
import os
import random
from typing import Dict, List, Tuple
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, LSTM, Input, Embedding
from keras import optimizers, Model
from gensim.models import Word2Vec
import keras
import math

def get_log_probs(occurs: Dict[str, List[int]], gamma: float = 1.0) -> Dict[str, float]:    
    probs = {}
    for word in occurs:
        probs[word] = math.log((len(occurs[word]) ** gamma + 1))
    _sum = sum(probs.values())
    for word in probs:
        probs[word] /= _sum
    return probs

def dataset_batch_generator1(
    model: Word2Vec, dataset: List[str], sequence_length: int = 5, batch_size: int = 64, randomize_len = False
) -> Tuple[np.ndarray, np.ndarray]:
    while True:
        perms = np.array_split(
            np.random.permutation(len(dataset) - sequence_length),
            len(dataset) // batch_size,
        )
        if randomize_len:
            length = np.random.randint(1, sequence_length, len(perms))
        else:
            length = np.full(len(perms), sequence_length)
        
        for indexes, s_len in zip(perms, length):
            vector_sequences = []
            vector_targets = []
            indexes = np.random.randint(0, len(dataset) - s_len, batch_size)
            for index in indexes:
                sequence = dataset[index : index + s_len]
                target = dataset[index + s_len]
                vector_sequence = []
                for word in sequence:
                    try:
                        vector_sequence.append(model.wv[word])
                    except KeyError:
                        vector_sequence.append(np.random.rand(vector_size))
                vectors_padded = np.zeros((1, sequence_length, model.vector_size))
                vectors_padded[0, sequence_length - s_len:, :] = np.array(vector_sequence)
                
                vector_sequences.append(vectors_padded)
                
                try:
                    vector_targets.append(model.wv[target])
                except KeyError:
                    vector_targets.append(np.random.rand(vector_size))
                    
            vector_sequences = np.concatenate(vector_sequences, axis=0)
            vector_targets = np.array(vector_targets)
            yield vector_sequences, vector_targets
            
def dataset_batch_generator2(
    model: Word2Vec, dataset: List[str], sequence_length: int = 5, batch_size: int = 64, randomize_len = False
) -> Tuple[np.ndarray, np.ndarray]:

    vectorized_dataset = []
    for word in dataset:
        try:
            vectorized_dataset.append(model.wv[word])
        except KeyError:
            vectorized_dataset.append(np.random.rand(vector_size))
    
    while True:
        perms = np.array_split(
            np.random.permutation(len(vectorized_dataset) - sequence_length),
            len(vectorized_dataset) // batch_size,
        )
        if randomize_len:
            length = np.random.randint(1, sequence_length, len(perms))
        else:
            length = np.full(len(perms), sequence_length)
        
        for indexes, s_len in zip(perms, length):
            vector_sequences = []
            vector_targets = []
            indexes = np.random.randint(0, len(vectorized_dataset) - s_len, batch_size)
            for index in indexes:
                sequence = vectorized_dataset[index : index + s_len]
                target = vectorized_dataset[index + s_len]


                vectors_padded = np.zeros((1, sequence_length, model.vector_size))
                vectors_padded[0, sequence_length - s_len:, :] = sequence
                
                vector_sequences.append(vectors_padded)
                vector_targets.append(target)
                    
            vector_sequences = np.concatenate(vector_sequences, axis=0)
            vector_targets = np.array(vector_targets)
            yield vector_sequences, vector_targets
            
def dataset_batch_generator3(
    model: Word2Vec, dataset: List[str], occurs: Dict[str, List[int]], sequence_length: int = 5, batch_size: int = 64, randomize_len = False, gamma=5.0
) -> Tuple[np.ndarray, np.ndarray]:

    vectorized_dataset = {}
    for word in occurs:
        try:
            vectorized_dataset[word] = model.wv[word]
        except KeyError:
            vectorized_dataset[word] = np.random.rand(vector_size)
    probs = get_log_probs(occurs, gamma)

    while True:
        choosen_words = random.choices(list(probs.keys()), list(probs.values()), k=len(dataset))
        random_indexes = []
        for word in choosen_words:
            index = random.choice(occurs[word])
            if index > sequence_length:
                random_indexes.append(index)
        random.shuffle(random_indexes)

        if randomize_len:
            seq_lengths = np.random.randint(2, sequence_length, len(random_indexes))
        else:
            seq_lengths = np.full(len(random_indexes), sequence_length)

        random_indexes = np.array_split(random_indexes, len(random_indexes) // batch_size)
        seq_lengths = np.array_split(seq_lengths, len(seq_lengths) // batch_size)
        
        for indexes, lengths in zip(random_indexes, seq_lengths):
            vector_sequences = []
            vector_targets = []

            for index, length in zip(indexes, lengths):
                sequence = [vectorized_dataset[word] for word in dataset[index - length : index]]
                target = vectorized_dataset[dataset[index]]

                if randomize_len:
                    vectors_padded = np.zeros((1, sequence_length, model.vector_size))
                    vectors_padded[0, sequence_length - length:, :] = sequence
                    sequence = vectors_padded
                else:
                    sequence = [sequence]
                
                vector_sequences.append(sequence)
                vector_targets.append(target)
        
            yield np.concatenate(vector_sequences, axis=0), np.array(vector_targets)

def preprocess_input_text1(text: str, word2vec_model: Word2Vec, max_len=5):
    # Transform input text into vector representation
    input_vectors = []
    words = text.split()
    words = words[len(words) - max_len :]
    for word in words:
        try:
            input_vectors.append(word2vec_model.wv[word])
        except KeyError:
            input_vectors.append(
                np.random.rand(word2vec_model.vector_size)
            )  # initialize randomly

    # Pad the input text to the required length
    if max_len != len(words):
        input_vectors_padded = np.zeros(
            (1, max_len, word2vec_model.vector_size), dtype="float32"
        )
        input_vectors_padded[0, max_len - len(words):, :] = np.array(input_vectors)
        return input_vectors_padded
    return np.array(input_vectors)[np.newaxis]

def generate_text1(
    model: Model,
    word2vec_model: Word2Vec,
    input_text: str,
    num_words_to_generate=10,
    max_len=5,
    radomize=False,
):
    generated_text = input_text

    for _ in range(num_words_to_generate):
        # Preprocess and pad the input text
        input_vectors_padded = preprocess_input_text1(
            generated_text, word2vec_model, max_len
        )

        # Predict the next word using the LSTM model
        prediction = model.predict_on_batch(input_vectors_padded)
        predicted_vector = prediction[0]

        # Find the corresponding word for the predicted index
        predicted_word = word2vec_model.wv.most_similar(
            positive=[predicted_vector], topn=10
        )
        if radomize:
            top_word = random.choice([word for word, _ in predicted_word])
        else:
            top_word = predicted_word[0][0]

        # Append the predicted word to the input text
        generated_text += " " + top_word

    return generated_text


class PredictCallback(keras.callbacks.Callback):
    def __init__(
        self,
        w2v_model: Word2Vec,
        input_text="Dawno dawno temu był sobie",
        num_words_to_generate=8,
        max_len=5,
        randomize=False,
    ):
        self.w2v_model = w2v_model
        self.input_text = input_text
        self.num_words_to_generate = num_words_to_generate
        self.max_len = max_len
        self.randomize = randomize

    def on_epoch_begin(self, epoch, logs=None):
        text = generate_text1(
            self.model,
            self.w2v_model,
            self.input_text,
            self.num_words_to_generate,
            self.max_len,
            self.randomize,
        )
        print(f"Start epoch {epoch} of training; Generated text:", text)


class SaveCallback(keras.callbacks.Callback):
    def __init__(self, save_path: str):
        self.save_path = save_path

    def on_epoch_end(self, epoch, logs=None):
        self.model.save_weights(os.path.join(self.save_path, f"{epoch}.h5"))

# %%
sequence_length = 25
batch_size = 128
gen = dataset_batch_generator3(model, dataset, occurs, sequence_length, batch_size, randomize_len=False, gamma=10)
a, b = next(gen)
print(a.shape, b.shape)

for i, wb in enumerate(b):
    all_words = ""
    for wa in a[i]:
        words = model.wv.most_similar(positive=[wa], topn=1)[0][0]
        all_words += " " + words
    words = model.wv.most_similar(positive=[wb], topn=3)
    print(all_words, words)
# Out:
# (129, 25, 100) (129, 100)
#  swój autorytet teza dalsze zaoenia everton to ksztacenie nowej rewolucyjnej wiadomoci i rozszerzanie jej wród ludu lub ptaszycy systemie przygotowanie nowych kierowniczych orodków które rozwin [('awulsów', 0.4050384759902954), ('sejmie', 0.3951239287853241), ('bogdańcu', 0.39329272508621216)]
#  tułowia a rozwojowo należą do mięśniówki brzusznej o czym świadczy między innymi źródło ich unerwienia są unerwione przez gałęzie brzuszne nerwów rdzeniowych rami ventrales nervorum [('spinalium', 1.0), ('ventrales', 0.8902422785758972), ('lymphatica', 0.8534058332443237)]
#  dobra tylko jeść i z palców zlizywać jak jej ta mufce nie smakuje to niepostrzeżone do choroby bedziem my jo karmić pytam sie dunajów nie [('bojś', 0.9999998807907104), ('warknł', 0.6302300095558167), ('pękaj', 0.6272857189178467)]
#  wszystko na komodę fotografię podstawkę szkiełko tekturkę sofia aleksandrowna opadła na fotel i rozpłakała się zakrywając twarz dłońmi funkcjonariusz grzebał teraz w wyciągniętych szufladach komody [('glorii', 0.4123556911945343), ('czasiejego', 0.4123325049877167), ('stanmore', 0.4082886278629303)]
#  w marcu tego samego roku uświadomił sobie że nie sposób skreślić człowieka z tą samą obojętnością z jaką odkłada się szachowego króla do pudełka karl [('lochtkamper', 1.0000001192092896), ('froede', 0.8356338739395142), ('koliknikow', 0.8331114649772644)]
#  awulsów l kultura towarzyska zachowywanie nienagannych manier i elegancja także szerzej doskonałość i sprawność w jakiejś dziedzinie które sprawiają że działanie w niej i jego [('wytwory', 0.9999998807907104), ('twory', 0.7791107296943665), ('wynalazki', 0.7195415496826172)]
#  wewnętrzna zatoka skalista dolna i t oponowa tylna między piramidą k skroniowej a k potyliczną przebiega szczelina mgłach petrooccipitalis u żywego wypełniona jałcie brukowcach otwór [('pomyślniejsze', 0.4057254195213318), ('kongresowe', 0.40392637252807617), ('samanthy', 0.39955538511276245)]
#  milczeć zawył bordenave któryz wściekłością skoczył na fotelu nie słyszę ani słowa jeżeli chcecie miesiącpóźniej z teatru my tu pracujemy barillot jeśli jeszcze usłyszę jedno [('jałcie', 0.4467710256576538), ('listopadzie', 0.43940478563308716), ('maju', 0.4273708760738373)]
#  jeszcze musiano przesunąć w czasie smutnym komentarzem do tej sprawy jest to że admirał raeder został skazany w procesie norymberskim za spisek w celu okupowania [('neutralnej', 1.0000001192092896), ('przygranicznej', 0.7683055400848389), ('karaibskiej', 0.7390515208244324)]
#  franc taka fraza w bajce rosyjskiej pojawia się rzadko afanasjew odnotowuje wprawdzie wyrażenie w dawnych czasach była sobie wioska ale ma ono odcień książkowy i [('znamionuje', 1.0), ('cechuje', 0.8334689736366272), ('odzwierciedla', 0.7925026416778564)]
#  pędami winorośli był uszkodzony w jednym miejscu nad skrawkiem gołej ziemi zawisło blade światełko kadiya zbliżyła się chwiejnym krokiem pochyliła się i zaciskając dłonie na [('bezdnie', 0.4154517352581024), ('fortach', 0.4142703115940094), ('kasztanach', 0.39591535925865173)]
#  w kości ale jeśli masz tylko parę marnych miedziaków nie ma o czym mówić ja gram tylko o duże stawki nie wierz mu wtrąciła hibli [('mhuma', 1.0000001192092896), ('gordini', 0.7883660793304443), ('jasnobrody', 0.783344566822052)]
#  dalej następnie opowiedział mi że po otrzymaniu propozycji zachował się wymijająco wyjaśnił że musi przemyśleć całą sprawę i porozmawiać o tym z żoną dlaczego nie [('przyjąłeś', 1.0), ('przyjmiesz', 0.8424173593521118), ('przyjęłaś', 0.8412340879440308)]
#  obrazu schodzie mimo tak oczywistych dallu w minnesocie wicie wierzy si w prawdziwo reliktu muzeumw aleksandrii jakby na przekór krytykom eksponuje jeszczew bocznej gablocie kilka [('dawne', 0.437685489654541), ('pierwszychdniach', 0.4068738520145416), ('komendantowej', 0.40299874544143677)]
#  przy nauce skoro trefi się na ustępy y historye które farniente być wyłożone abo też chanowe się same trzeba im ie wyłożyć y odczytać nie [('niezauważenie', 0.4449657201766968), ('zielonce', 0.4077070653438568), ('swojejżony', 0.39689403772354126)]
#  wschód prawdopodobnie do altary w każdym razie tak blisko abili dwudziestu żołnierzy alliandre oraz tyluż mayenian ze skrzydlatej gwardii stanowiło dostateczną ochronę proporce na ich [('lancach', 1.0), ('włóczniach', 0.7315801382064819), ('mieczach', 0.7203035950660706)]
#  w tło tutejszej ulicy mimo że jestem amerykaninem to cud że te chłopaki po prostu nie spuszczą ci lania zamiast przyjmować cię do swojej bandy [('ciągu', 0.4104616940021515), ('sprzed', 0.400532603263855), ('dągu', 0.3671647012233734)]
#  gadało mi się z nikim tak miło jak z wami szczerze powiem że tej nocy zasnę z lżejszym sercem jest o czym myśleć po tej [('rozmówce', 1.0), ('dziewuszce', 0.6813170909881592), ('rozbebeszonej', 0.6688174605369568)]
#  masz efficiency curve sprężystego wygięcia pręta wytrz elastica stanów czynnika condition curve brukowcach curve in steam turbines wody inż botów curve stratności el loss curve [('sznurowa', 0.9999999403953552), ('metalowa', 0.8182647824287415), ('zwisająca', 0.7964767217636108)]
#  drplik jest krotszy niz ciag brukowcach dw offset awulsów awulsów equ h dw offset brukowcach ptaszycy equ h dw offset ciągu pierwszychdniach equ h dw [('offset', 1.0), ('cx', 0.8734084963798523), ('register', 0.8675133585929871)]
#  kiedy oddział seana wyruszył przez zimowe brązowe pola ku rysującym się na horyzoncie górom drakensberg powozik jechał na końcu kolumny wyładowany po brzegi agarów i [('skrzynkami', 1.0), ('skrzyniami', 0.894688606262207), ('pudłami', 0.8742218017578125)]
#  nikomu nie powiesz no ja cóź brukowcach ale on położył rękę na ksawuni i już poowijani że mnie teczkach agarów a on wtedy samanthy ciało [('rewera', 0.9999999403953552), ('wawrzecki', 0.6748391389846802), ('potocki', 0.674785315990448)]
#  czeskiego i ochotniczej agarów luzów rosyjskiej admirała kołczaka od awulsów na mgłach francuskim wobec luzów sfę tej czasiektórych dywizja po walkach z ksawuni awulsów broussac [('welawskobydgoskich', 0.39179298281669617), ('awulsów', 0.3800901770591736), ('agarów', 0.36801183223724365)]
#  bogactwie odmiennych reakcji nakażde ze wspólnych doświadczeń utrzymuje się niezmiennie phnom narodowościowych i w obrębie kultur zapomniane w łonie europejskiej cywilizacji można ją dostrzecw zmiennych [('rytmach', 1.0), ('rytmów', 0.7824355363845825), ('tempach', 0.7766876220703125)]
#  uważaj rzekł indri który tak samo jak toby nie poznał był fakira człowiek ten pokaże ci zdumiewającą sztuczkę jakiej nigdy nie widziałeś znam istotnie jałcie [('zręczność', 1.0), ('pomysłowość', 0.8578000068664551), ('zwinność', 0.833448588848114)]
#  kto mógł wiedzieć kiedy dojdzie do wznowienia walk czy będą jeszcze mieli podobną szansę obojgu zresztą potrzebna była chwila odpoczynku nadal myrny wiadomość od matki [('roberta', 1.0000001192092896), ('edwarda', 0.876174807548523), ('williama', 0.8711647987365723)]
#  ogóle tymstanie za złotych które mu dałam nadto korzystając z ptaszycy przepisów dotyczących przyznania inwalidztwa brukowcach iii środa milska dała nam broszurę chruszczowa którą tu [('wrzosowe', 0.4294399321079254), ('kongresowe', 0.4160401225090027), ('dharme', 0.3864738345146179)]
#  nasiennego u mężczyzny a do środkowej części pochwy u kobiety tętniczka ta zespala się z t drugostronną oraz z innymi tętnicami zjednoczone druga gałąź t [('pęcherzowej', 1.0), ('krezkowej', 0.7868250012397766), ('nabrzusznej', 0.7581539154052734)]
#  reżimie albo niderlandach obozowy o szczególnym reżimie ksawuni ta jest ostateczna i nie podlega miesiącpóźniej t k niestety wspomnianych w uchwale podań i charakterystyki w [('archiwaliach', 1.0), ('materiałach', 0.6979278922080994), ('inskrypcjach', 0.668857216835022)]
#  ostatnich promieniach ksiezycowego sierpa ciemne sylwetki orków na przedzie pochodu brukowcach i awulsów sie we mgle hej czolo zwolnic kroku krzyknal ugluk który zamykal pochód [('nagla', 1.0), ('gleboka', 0.7766985893249512), ('gwaltowna', 0.7333637475967407)]
#  kilka matek obraziło się tak że złapały się za włosy i zaczęły się tarmosić kiedy kilkoro dzieci otrzymało od swoich matek takie lanie że naprawdę [('dostały', 0.9999998807907104), ('dostawały', 0.8570615649223328), ('dostałyby', 0.7981720566749573)]
#  tego nie rozstrzygnąłem muszę najpierw zebrać więcej wiadomości odparł frodo ilu zbirów jest w pobliżu trudno powiedzieć rzekł cotton kręcą się wciąż to przychodzą to [('odchodzą', 1.0), ('biegną', 0.7803744077682495), ('uciekają', 0.7531757354736328)]
#  wzrosła w tym czasie ilość torowiskach i liczebność tego zakonu ważnym dlakościoła wydarzeniem było przyjęcie w roku awulsów kler uchwał soboru trydenckiego stało sito podstawą [('opracowywanej', 0.9999999403953552), ('standardowej', 0.6869179606437683), ('równoległej', 0.6793574094772339)]
#  na podstawowym artykule paula ekmana an argument for basic emotions cognition and emo tion s to spostrzeżenie jednak powtarzam za arty kułem pn johnsonlaird k [('oatley', 0.9999999403953552), ('johnsonlaird', 0.9069606065750122), ('cits', 0.89543616771698)]
#  achajów ok pne charakteryzująca się wysokim poziomem architektury i rzemiosła artystycznego oraz np własnym szatniach brukowcach w muzyce jeden z dwu trybów za pomocą których [('porządkuje', 1.0000001192092896), ('uzupełnia', 0.7796290516853333), ('odtwarza', 0.7680541276931763)]
#  wyniki dzenia w miesiącpóźniej nie wiem ie nie wiem miesiącpóźniej raz dania próbne tania nie sąnie mogą być dku bracławszczyźnie kwestionariuszy ankiet cyjne rozstrzyganie podziału [('uzyskanych', 0.9999998807907104), ('uzyskiwanych', 0.8775830268859863), ('osiąganych', 0.8285318613052368)]
#  i ja w zorganizowanie którychod z marokiem p wa z wypowiedzieć się za niepodległością welawskobydgoskich administrowanie tym myrny tygodnie pwd data rena wyników brukowcach ptaszycy [('jałcie', 0.4407677948474884), ('konstytucjach', 0.4083937406539917), ('welawskobydgoskich', 0.4055914878845215)]
#  imię jestem już w odległości kilku kroków od przewróconego stolika gdy dziewczynka awulsów się z ziemi ma chyba pięć sześć najwyżej siedem lat buzia trochę [('umorusana', 0.9999998807907104), ('okopcona', 0.8133505582809448), ('potargana', 0.7863189578056335)]
#  powszechny udział w wyborach prezydenta państwa jest również naszym awulsów w wywiadzie udzielonym rzymskiemu dziennikowi tempo kardynał glemp czuł się zmuszony ostatecznie wyjaśnić preferencje polskiego [('kościoław', 1.0), ('kolegiaty', 0.6593742966651917), ('arcybiskupstwa', 0.6549457907676697)]
#  złoczyńcą skradał się wymijając ludzi powozy zwierzęta na szczęście złodziej nie próbował kluczyć ani się ukrywać był pewny że mu się udało nie zauważył drobnej [('przemykającej', 0.9999999403953552), ('przesuwającej', 0.6661261916160583), ('wychylającej', 0.6646796464920044)]
#  nigdy nie byli kochankami w magicznej chwilce uraczyła mnie herbatą constant comment wspominał po latach obrazy w balladzie są reminiscencjami ze zwiedzenia przez cohena la [('chapelle', 0.9999998807907104), ('duque', 0.8350520730018616), ('reole', 0.8334103226661682)]
#  wspomnieniem i morgon ryjąc świadomością pod gruzami budził ich swoją żałobą nie widział ich ale na wichrowej równinie i na równinie królewskich ust w ruinach [('ruhn', 1.0), ('baktrii', 0.6738207340240479), ('lukanii', 0.6593118906021118)]
#  kanwa rozważań nad zasadniczymi kwestiami natury najniklejszego re dz siestra moja uczennicach sowr dram l sad bież ziemli zawiera też pod odnoj dorogaja kodiaku sad [('awulsów', 0.44346603751182556), ('agarów', 0.4068657159805298), ('sprzed', 0.39382633566856384)]
#  brukowcach ci mgłach zamierzchłe że co luzów co z nami panieńskiego na ogrodzie rosi zaciszach byli sami fortach idzie pod stodołę sabaudiapiemont co idze ty [('sprzed', 0.3938874304294586), ('awulsów', 0.374328076839447), ('zapomniane', 0.37017861008644104)]
#  zaś z tym skończył naprawdę jednak przestał nim być jak odkryłem wiele lat wcześniej nie trafiłem na żaden ślad brudnopisu o glendowerze ani jakiejkolwiek innej [('poważnej', 0.9999999403953552), ('błahej', 0.82364821434021), ('nieprzyjemnej', 0.8110392093658447)]
#  każe ją sprowadzić do siebie każe ją przywieźć wozem drabiniastym zawieszą im tabliczki na szyjach i wszyscy wieśniacy po drodze wyjdą z domów by obrzucić [('marnotrawną', 1.0), ('wyrodną', 0.6565935015678406), ('karmiącą', 0.6383615136146545)]
#  wymagało to trochę czasu tymczasem rack był kompletnie bezbronny i całkowicie osłonięty mój boże co teraz zrobimy zamknij się próbuję myśleć wartownicy dostrzegli maniona i [('dharme', 0.425199419260025), ('bognor', 0.4110948145389557), ('predappio', 0.40833163261413574)]
#  do głównego wejścia i sprowadzić tutaj któregoś ze strażaków ale to zajęłoby zbyt wiele czasu zwłaszcza że zacząłby ją pewnie wypytywać mogła też zejść po [('drabinie', 1.0), ('drabince', 0.9147118926048279), ('kładce', 0.8219192028045654)]
#  zmusić ją do powiedzenia tego co wie prawdopodobnie nic nie wie tylko popisuje się josephine lubi czuć się ważna wiesz przecież to coś więcej czy [('wiedzą', 1.0), ('wiedzieli', 0.8070626854896545), ('wiemy', 0.7839585542678833)]
#  wielu krajach bogatego zachodu depopulacji spowodowanej przez ujemny przyrost naturalny zapobiega napływ emigrantów z ubogich krajów awulsów w socjologii związany z samanthy powodujący brukowcach procesy [('jałcie', 0.49861466884613037), ('pierwszychdniach', 0.4602664113044739), ('poczdamie', 0.44432753324508667)]
#  stefan może on kogoś widział tego pani też broni mruknął niechętnie prokurator a co mam go oskarżać to pańska domena zwracam pani uwagę że jak [('odbieraliśmy', 1.0), ('przekazywałam', 0.6981114149093628), ('zestawiałem', 0.6936658620834351)]
#  na wierne woła brukowcach wszyscy się zgromadzają na rozkaz hektora w agarów ich męstwo najtęższa podpora poszedł na lewe skrzydło gdzie walczyli hardornie helen azjos [('adamas', 1.0), ('stiepnoj', 0.7372139096260071), ('busiris', 0.72818523645401)]
#  na ryby i polowania naboje robiliśmy sami miałem ich z rana zawsze dwanaście sztuk tyle bowiem miedzianych łusek przyniosłem z sobą z miasta co wieczór [('myło', 1.0), ('żuło', 0.7186722755432129), ('suszyło', 0.7172660827636719)]
#  reach maximum value maksymalną wysokość lotn hit the ceiling porozumienie reach an agreement postęp make progress równowagę attain equilibrium reach equilibrium szybkość reach a speed [('achieve', 0.9999998807907104), ('greater', 0.8544795513153076), ('rational', 0.85099858045578)]
#  nadzieję bo sprawa jest przegrana w rzeczpospolitą zwątpiono już i zaciszne ją kilku młodzieży ze szlachty a na ich czele lucjusz cecyliusz metellus kieruje wzrok [('publiusz', 1.0), ('lucjusz', 0.9062135219573975), ('gajusz', 0.896279513835907)]
#  niż książęta byli lojal nymi członkami tych francjiń fratrii które opierały się na fortach stwach i łączyły w plemiona każdy kto nie był członkiem braterstwa [('franconii', 0.428730309009552), ('jałcie', 0.40844547748565674), ('farniente', 0.4073064625263214)]
#  usiłowali oni rozbić grecką falangę katastrofę armii leonidasa sprowadziła dopiero zdrada sięobiektem efialtesa który wskazał persom ścieżkę górską przez przełęcz brukowcach gwardia perska pod wodzą [('fortach', 0.4568707346916199), ('awulsów', 0.40988972783088684), ('jałcie', 0.39677250385284424)]
#  ogarnięte okiem szły pod bramę też na tę drogę wolny czas robiło się aby dzień zeszedł bo materiału było mało spędzaliśmy na perskim rynku u [('blokowych', 1.0000001192092896), ('śpiewaczych', 0.6749832034111023), ('dialogowych', 0.6745156645774841)]
#  tie otoczyła prom jak kokonem uniemożliwiając mu zboczenie z kursu i wyrwanie się ze strefy przyciągania promienia niszczyciel gwiezdny gorgona otworzył wrota ogromnego lądowiska żeby [('wchłonąć', 1.0000001192092896), ('pochłonąć', 0.8309389352798462), ('unicestwić', 0.8249390125274658)]
#  kontrolą po podjęciu służby w liniach lotniczych żeby mieć pewność że ciągle się nadają do użytku tak kochanie będziemy sprawdzali latające maszyny i naprawiali wszelkie [('usterki', 1.0), ('niedokładności', 0.7839395999908447), ('niedociągnięcia', 0.7495010495185852)]
#  ze złej drogi i wydać wszystkich handlarzy z san diego powiedz mu żeby się odpierdolił dobra zaproponował spokojnie delaura sięgając do szuflady po buteleczkę z [('aspiryną', 1.0), ('melasą', 0.8004783987998962), ('sałatą', 0.7876526117324829)]
#  pięć kabin telefonicznych w jednej jest aparat do fortach harvey pomaszerował we wskazanym kierunku pokój rzucił siedzącemu w małym boksie brukowcach zielonym mundurze ze złotymi [('wieżami', 1.0), ('blankami', 0.8959299325942993), ('wieżyczkami', 0.8945685029029846)]
#  u mankietów jedwabne pończochy surdut spodnie i kamizelkę z błękitnego aksamitu oraz piękne trzewiki na klamry z czarnej skóry przy czym prawy trzewik zręcznie maskował [('szpotawą', 1.0), ('złamaną', 0.818102240562439), ('zgruchotaną', 0.8046625852584839)]
#  ciało rozerwane zostało na tysice kawałków odsłaniajc now postać czarn i lnic awulsów się grzyw długich włosów wrongle zaczęły pierzchać by uchronić się przed jego [('rosnc', 1.0), ('degradowały', 0.6217664480209351), ('odkrywajac', 0.58787602186203)]
#  o martialu twarz oczuw rozjaśniła się niespokojnie i niecierpliwie patrzyła kilka minut na drzwi lecz ku jej żalowi wszedł w końcu mikołaj przyszły wspólnik zbrodni [('barbillona', 1.0), ('ciętu', 0.5415424704551697), ('tiwierzinów', 0.5414648056030273)]
#  słomą awulsów w ten sposób robią sobie dach i drzwi do domów swoich houyhnhnmowie używają wklęsłej części swej nogi między pęciną i kopytem jak my [('zwycięstwach', 0.4249466061592102), ('powodach', 0.4134685695171356), ('bitwach', 0.4118799865245819)]
#  dane awulsów weryfikację prawdziwości równania i a także pozwolą po klasyfikacji luzów w oparciu o własności procesów stacjonarnych na wyznaczenie warunków przy których zachodzi i [('awulsów', 0.42238226532936096), ('ptaszycy', 0.3992340862751007), ('tarasowate', 0.39542436599731445)]
#  cit serwiusz o eneidzie wergiliusza v plutarch atuan zemście bogów pauzaniasz vii hyginus fabulae eurypides herakles i nast serwiusz o eneidzie wergiliusza viii scholia do [('czerwcowe', 0.42834895849227905), ('mgłach', 0.4261987507343292), ('awulsów', 0.40703314542770386)]
#  przed brukowcach tej rozmowy pożegnała się z panią heleną odłożyła słuchawkę słyszałeś spytała krzysztofa słyszałem idę tam zaraz czy cyprek zająknął się nie wiedział jak [('karstenowi', 0.42439523339271545), ('kinję', 0.42054054141044617), ('aurorze', 0.41906964778900146)]
#  pań i panów i wszyscy jechali obejrzeć szałas gdzie cię uśmiercili czasami przybijali do brzegu żeby odpocząć zanim się przeprawią na drugą stronę i z [('uśmiechach', 0.4113347828388214), ('nieszawie', 0.4065825045108795), ('fortach', 0.4029221832752228)]
#  po mieście i znów wyjedziecie a skąd mogę wiedzieć że tak będzie naprawdę powiedziałem ja wam daję słowo honoru ja to słyszałem w paryżu wtedy [('rojewski', 0.9999998211860657), ('pamicki', 0.8224644064903259), ('losifowicz', 0.8203402757644653)]
#  ucisków jednostajnych i powolnego roztrząsania ge stymulacyjny działający pobudzająco na tkankę mięśniową masaż polega na wykonaniu energicznych głaskań i rozcierań ugniatań zwłaszcza poprzecznych i ze [('skręceniem', 1.0000001192092896), ('zwichnięciem', 0.7911167144775391), ('zginaniem', 0.7637279629707336)]
#  równinę przeżegnał się nie oglądając się wiedział że idący za nim mnisi uczynili to samo brnęli powoli jeden za drugim zostawiając na śniegu głęboki ślad [('zgrabiałymi', 1.0), ('zdrętwiałymi', 0.8686812520027161), ('drżcymi', 0.855380117893219)]
#  pojęcie o co tu w ogóle chodzi malwina wcale nie siedziała w łazience i wcale nie płakała nie zamierzała niszczyć dzieła kosmetyczki która tak genialnie [('awulsów', 0.44453102350234985), ('przypowiednie', 0.4134485721588135), ('minroud', 0.41042470932006836)]
#  był tam niewielki podest i osiem czy dziewięć stopni najniklejszego dół do głównego pomieszczenia wszystko w nim było awulsów przedsejmowe na biało ściany konsola aparatury [('którychod', 0.3881530165672302), ('mgłach', 0.37152498960494995), ('zaniechań', 0.3710850477218628)]
#  charles elston michael everson awulsów jałcie charles zapomniane christopher gilson carl ksawuni aleksiej kondratiew patrick wynne david luzów i ali niezauważenie z wydawnictwa harpercollins w [('oksfordzie', 1.0), ('oxfordzie', 0.9214566349983215), ('edynburgu', 0.8519963622093201)]
#  z tego że ufa pan temu człowiekowi powiedział jessad i że chce pan wprowadzić go w swe sprawy niech pan mądrze dobiera sobie sprzymierzeńców panie [('lukas', 1.0), ('denkmal', 0.7598296403884888), ('ramsey', 0.7539043426513672)]
#  względem najważniejszych cech osobniki australopithecus afarensis posiadały ludzkie ciała o małych rozmiarach jednak niektórzy uczeni zdecydowanie nie zgodzili się z taką opinią przedstawili daleko bardziej [('welawskobydgoskich', 0.4767524302005768), ('dallu', 0.4444696009159088), ('jałcie', 0.4167073667049408)]
#  opanowanie całego zestawu ćwiczeń trwa zwykle miesiące w następnym etapie ćwiczeń można do powtarzanych formuł słownych dodawać bardziej specyficzne miesiącpóźniej jest mi obojętny inną odmianą [('odprężającej', 1.0), ('szampańskiej', 0.6135827898979187), ('orzeźwiającej', 0.6057168841362)]
#  potem ginąć w rozerwanym na kawałki samolocie mogła zająćsię tą swoją wielką miłością teatrem i żyć do tej pory z kontem w banku i dobrą [('renomą', 0.9999999403953552), ('reputacją', 0.8551514744758606), ('estymą', 0.8498241305351257)]
#  oczy lśniły w świetle księżyca wpatrując się uważnie w otoczenie jakby to stanowiło jego jedyną ochronę w miejscu gdzie stara droga wchodziła do pola emonda [('samanthy', 0.42909345030784607), ('miesiącpóźniej', 0.41054585576057434), ('maciejowickiej', 0.40731900930404663)]
#  w tym miejscu i nie pozostawił mnie bukowińskie dzikim choć pięknym francuskim krajobrazie siedząca obok bernadette obrzucała mnie niespokojnymi spojrzeniami a ja nachylony nad kierownicą [('najniklejszego', 0.43318918347358704), ('brukowcach', 0.4253038763999939), ('awulsów', 0.419121116399765)]
#  na rozmowę ointeresach murgo uśmiechnął się przelotnie co robiło ksawuni na jego poznaczonej twarzy zawsze warto spróbować chętnie za to pochwalę twojego kucharza komplement dla [('agarów', 0.43863165378570557), ('minroud', 0.43063268065452576), ('miesiącpóźniej', 0.42936065793037415)]
#  słodki i śmierć siostra snu ptaszycy jego ostatki wziąwszy na pierwszychdniach go do krain likiji obszernych tam otoczon od krewnych i przyjaciół wiernych ich łzami [('pasiedzenia', 0.4292145073413849), ('ptaszycy', 0.41191238164901733), ('schodzie', 0.40458351373672485)]
#  jak studiował w andover cholernie ważny szkoda żeście nie byli przy tym jak sally zapytała go co myśli o tej sztuce należał do tego typu [('cymbałów', 1.0), ('piszczałek', 0.9097864627838135), ('fletów', 0.874995768070221)]
#  circuit syn d obwód różniczkujący hericourt syn d obwód agarów kujący florentyńczyków adj rozproszony rozmyty obraz v rozpraszać białoniebieskie isolation izolacja złączowa elementów w układzie [('scalonym', 1.0), ('immunologicznym', 0.7316333651542664), ('niejednorodnym', 0.718309760093689)]
#  deprawacji znajduje się piramida bez wierzchołka piramida sabaudiapiemont niedoskonała przedstawiająca upadłego adama i eldio zdeprawowane grzeszne i potępione abraham i inni żyjący w owym dniu [('usprawiedliwieni', 1.0), ('zbawieni', 0.8344550728797913), ('uświęceni', 0.8147221803665161)]
#  ferrite elektron ferrite magnetycznie miękki soft ferrite pierwotny delta ferrite bambie zob ferryt wolny wolny free ferrite excess ferrite wysokotemperaturowy zob ferryt ksawuni a met [('głębokoci', 0.4526432752609253), ('rozpromienienie', 0.39821645617485046), ('mglei', 0.3780893087387085)]
#  języka walki zasalutował wykręcił się na pięcie i pośpieszył w ślad za fremenem nieziszczalnych jego oddalających się korytarzem kroków leto i hawat popatrzyli na siebie [('porozumiewawczo', 0.9999999403953552), ('szelmowsko', 0.8345524072647095), ('łobuzersko', 0.808052659034729)]
#  cały jest poświęcony znaczeniu wieszadło wewnętrznego uszezęśliwienia człowieka są ciągu o cenzurze ksiąg o fajfie na którekażdy się mógł i może zgodzić ale i tam [('predappio', 0.4383748769760132), ('pierwszychdniach', 0.41189783811569214), ('poczdamie', 0.4049799144268036)]
#  nad jałcie klęka przed rybą ryba śpiewa jałcie rybę o lżejsze pływanie w rzece gruzach ryba pojedyncza ja ryba brukowcach od ryby drzewa i ryby [('awulsów', 0.4599519371986389), ('agarów', 0.38131096959114075), ('fortach', 0.37448057532310486)]
#  dostęp du morza gdzie gocka flota nadal operowała z baz w kalabrii i na sardynii przypuszczalnie zamierzał przyjść z pomocy najniklejszego llll jejtwarzy niderlandach nin [('brukowcach', 0.42938050627708435), ('welawskobydgoskich', 0.41444242000579834), ('jałcie', 0.4025047719478607)]
#  się w utworach całego pokolenia literackiego do którego należał emr fo hrl dz fragm powieści czisła i alkowach paris wyd ciągu paris ano dokończone iii [('chożdienije', 1.0), ('mukam', 0.9029905200004578), ('dorogie', 0.7773895859718323)]
#  zatrudnienia wchodzą w zupełnie inne układy hobbitanii i ksawuni własne kręgi dawne się ze wspólnoty rodziny pochodzenia w tych warunkach więź pokrewieństwa i awulsów wyraźnie [('zawężona', 1.0), ('adekwatna', 0.7685416340827942), ('empiryczna', 0.7371753454208374)]
#  orientować się na mało pocieszające dane cyfrowe płynące ze źródła niegdyś obiektywnego teraz zaś opanowanego przez tego miesiącpóźniej faworyta nierżyna przyzwyczajony już do chodzenia w [('koleinie', 1.0), ('zaspie', 0.7223606705665588), ('szczelinie', 0.7218471169471741)]
#  pochodni słychać było cichy śpiew słów nie można było zrozumieć lecz melodia wyrażała ogromny smutek i bezgraniczną tęsknotę okręt sunął powoli płytką zatoką po czym [('przycumował', 1.0000001192092896), ('zacumował', 0.8313919901847839), ('przycumowali', 0.8109217286109924)]
#  jako bardzo wysoki wystarczy tylko wyobrazić sobie co to znaczy oddawać swoich zarobków każdego miesiąca na cele charytatywne przy założeniu że jest się osobą średnio [('zarabiającą', 1.0), ('fajną', 0.6358879804611206), ('urodzoną', 0.608555018901825)]
#  opal ognisty opal pospolity opal hobbitanii opal serpentynowy opal szklisty opal szlachetny opal węgierski opal wodnisty opal woskowy opal welawskobydgoskich ortoklaz wersalskiej zasępienia agarów torowiskach [('pallad', 1.0000001192092896), ('wanad', 0.8580149412155151), ('molibden', 0.8472502827644348)]
#  badaniu ksawuni wycinka skórnomięśniowego przed włączeniem fortach leczeniem z wyboru jest nieszezęścia ads zapalenie wielkokomórkowe tętnic do tej grupy zapaleń należya choroba takayasu choroba młodych [('bezdnie', 0.3888026177883148), ('niepowrotnie', 0.3800289034843445), ('ksawuni', 0.37782740592956543)]
#  bogumiłem tę sprawę dopiero nazajutrz pilnując bawiącej się agnisi rozalia już gdzieś jak zazwyczaj przepadła pani barbara otworzyła kopertę teresy i ze wzruszeniem przypatrywała się [('różnobarwnym', 1.0000001192092896), ('wielobarwnym', 0.8026175498962402), ('czerwonawym', 0.7960333824157715)]
#  o nie wszystkie jednak schematy tak otrzymanych reguł są jałcie ważne niezawodne hobbitanii się jako tezy systemu sylogistyki głównych trybów o jałcie zaznaczonych w następujących [('nazwach', 1.0), ('tytułach', 0.78962641954422), ('imionach', 0.7644487619400024)]
#  czerwcowe agarów pży miesiącpóźniej ścianie wieży leniwcuw blisko którychod ukosem tunelu ktury prowadził aż do limeńskich bitwapod pierwszychdniach awulsów kiedy zaglądałem tu podczas awulsów nurkowań [('okzało', 1.0000001192092896), ('omyliliśmy', 0.7129311561584473), ('zorientowałaś', 0.703755259513855)]
#  ze względu na genezę i strukturę wyróżniamy neologizmy słowotwórcze tworzone na gruncie danego języka od wyrazów już istniejących za pomocą odpowiednich formantów np samanthy oprogramowanie [('oszołom', 0.9999999403953552), ('pieczeniarz', 0.6660938858985901), ('cricetus', 0.6660241484642029)]
#  krystyny kersten która nawet teraz we wstępie do czarnej księgi komunizmu próbuje jeszcze osłabiać wymowe tej książki demaskującej zbrodnie komunizmu przypomnijmy że nawet skrajnie tendencyjny [('antypolski', 1.0), ('reakcyjny', 0.7794660329818726), ('rasistowski', 0.7318315505981445)]
#  w innym świecie mamy zupełnie współczesne słowo od autora dalej jest już podobnie pojawia się bowiem wyraźnie zarysowany narrator a pierwszy rozdział petersburg poświęcony kolejnym [('wypadkunie', 0.40205681324005127), ('zamieszaniu', 0.4007529616355896), ('niezdecydowaniu', 0.38875114917755127)]
#  być informowany na bieżąco zdaje się że najchętniej prowadziłby to sam bo jest wyjątkowo na nich cięty ale brakuje mu czasu co do wydarzenia z [('paczką', 1.0), ('kopertą', 0.8057187795639038), ('paczuszką', 0.7948536276817322)]
#  miala zamiar wywolac udana rewolucje w chinach zajac agarów mongolie zewnetrzna i sinciang czyniac z nich panstwa satelitarne oraz wprowadzic komunizm do korei przedsiewziecie to [('obejmowalo', 0.9999999403953552), ('określałyby', 0.6818121075630188), ('ydowskie', 0.6789951324462891)]
#  ucha do ucha jezu słodki dlaczego w ogóle opuszczałem st louis pomyślał przejechał prawie dwa i pół tysiąca kilometrów samochodem z radiem do bani i [('jałcie', 0.40953508019447327), ('sięzakończy', 0.40288475155830383), ('samanthy', 0.3953263759613037)]
#  gdy wyjdzie będzie zgrzybiałym starcem dowie się wszystkiego za chwilę przed nim parkowały dwa wozyz widocznymi w środku ludźmi gdy podjechał bliżej jeden z nich [('miesiącpóźniej', 0.4170253872871399), ('agarów', 0.41531702876091003), ('ksawuni', 0.4085083603858948)]
#  w innym czasie penetrując kontrolne pole siłowe izolujące ziemię i sprawiające że była niedostępna jako biblioteka cywilizacje te mogły rozkwitać przez lub lat potem siłom [('władającym', 0.9999999403953552), ('władając', 0.7838435769081116), ('władający', 0.7454493045806885)]
#  natomiast znakomitymi wspinaczami i bez trudu uciekały po stromiznach ale nie umiały odgarniać śniegu wolały zatem wietrzne skaliste wyżyny podobne do kóz gatunki spokrewnione z [('kongresowe', 0.4031747877597809), ('przededniu', 0.3980584442615509), ('czasiejego', 0.39170172810554504)]
#  i dała lepsze życie jego córce i wnukom w augustynie może się to obudziło dopiero na łożu odbitkach dowiedział się że krzysztof dostał pracę przy [('luzów', 0.42225632071495056), ('pugilaresie', 0.4129725992679596), ('katandze', 0.4086841344833374)]
#  siłę włożyły w jego spojrzenie takie fortach w jego oczy iż wszyscy dobrze zrozumieli co poszperała i chorągwie przejeżdżały w milczeniu koło niego a on [('którychod', 0.4211914837360382), ('dallu', 0.3897521495819092), ('najniklejszego', 0.3770101070404053)]
#  tym pytanie rand rozejrzał się dookoła gdzie haslin chyba się znowu nie upił mówiłem przecież jemu wolno pić wino tylko wieczorami agarów haslin był mistrzem [('miecza', 0.9999999403953552), ('topora', 0.8948944807052612), ('sztyletu', 0.8764700293540955)]
#  twarzy pułkownika ohydną szramę viscarra oddał się rozpaczy i poprzysiągł zabić swego wroga nieszczędząc mu największych męczarni tak mówił pułkownik powinienem się zemścić nie wolnonam [('zaniechać', 0.9999998807907104), ('zaprzestać', 0.9268918037414551), ('poniechać', 0.8898435831069946)]
#  najdalszy był choćby cień dogmatyzmu dogmatyzacja nadanie czemuś cech dogmatyzmu lub dogmatu dogmatyzacja myślenia dogmatyzacja twierdzeń ksawuni nadawać czemuś cechy dogmatyzmu lub dogmatu ksawuni poglądy [('ksawuni', 0.4205044209957123), ('otworzyłaoczy', 0.4072902500629425), ('oldaków', 0.40657153725624084)]
#  wyrównywać szansę życiowe i warunki bytu tzn ma odbierać grupom bogatym i zaradnym część dochodu i przeznaczać go np na równy start dla wszystkich czyli [('dotowanie', 1.0), ('kredytowanie', 0.6667343378067017), ('eksploatacje', 0.6645925045013428)]
#  nawet śmierć oddala się od człowieka i nadaje jej ludzką formę ceremonie trwają krótko ciało zmarłego przypomina kwitnącą młodość specjalne zakłady usługowe ułatwiają jak mogą [('omijanie', 1.0000001192092896), ('wyszukiwanie', 0.7696705460548401), ('ominięcie', 0.7556686401367188)]
#  tytułu cesarskiego była jak pisał zwinalem monarsze frankijskiemu niemiła jeśli wierzyć temu luzów różne co do tego są w nauce opinie wypadałoby sądzić że karol [('bezentuzjazmu', 0.9999998807907104), ('sharpinski', 0.747714102268219), ('porozumieniaw', 0.7413215041160583)]
#  a ściskać a obłapiać y co więcey ieszcze bowiem były miedzy sobą sięstąd do tych igrów barzo ustawicznie one dwie damy były w t ym [('barziey', 1.0), ('więcey', 0.84409099817276), ('lepiey', 0.7693520188331604)]
#  szlachcie bogaczom i panom wkrótce śmierć wszystkiemu co żyje bo pijanej krwią czerni nie sposób było już okiełznać rebelia zaczęła się rozszerzać na inne kraje [('nilfgaardzcy', 1.0000001192092896), ('duńscy', 0.7794694900512695), ('północni', 0.7663558721542358)]
#  a delikatnych szufladach y nieładzie ciałek wżdy daią się nawiedzać pod bogatemi zasłonami y ksawuni jałcie zasępienia y tam wyciągała swóy żołd miłosny y grosz [('minroud', 0.44010642170906067), ('krajacheuropy', 0.42920738458633423), ('szpargałach', 0.427167147397995)]
#  jak to ty nic nie wiesz stryj wie że kasztelanic nie zwykł do porady brać nikogo awulsów miał o tym wiedzieć muszę lecieć żeby się [('rozpytać', 1.0000001192092896), ('wypytać', 0.8377946019172668), ('poprosić', 0.7564085125923157)]
#  marmaduk temple tymczasem wyskoczy z sani zdjć futrzane jałcie welawskobydgoskich zamszowe wydoby strzelb i opatrzywszy austriackie skierowa si do lasu wkrótce ukaza si pikny daniel [('nieziszczalnych', 0.392267644405365), ('zmierzch', 0.38041743636131287), ('tajemniczysposób', 0.37773504853248596)]
#  licznych mięśni uśmiechach rectus capitis posterior major et minor m obliquus cdpitis ksawuni kongresowe kodiaku cdpitis splenius cdpitis brukowcach v szyim ciągu ściana boczna gdy [('czaszka', 1.0), ('głowa', 0.8067494034767151), ('szczęka', 0.7999899387359619)]
#  samo nie zaczerwieniła się wprawdzie ale sama nynaeve mogłaby być dumna z kwaśnego spojrzenia jakim obdarzyła brązową siostrę adeleas tylko się uśmiechnęła tajemniczym uśmiechem równie [('bladym', 0.9999999403953552), ('jasnym', 0.8486943244934082), ('mdłym', 0.8103762865066528)]
#  r został ksawuni w akademii krakowskiej płasienki został bakałarzem następnie magistrem a po kilku latach zasępienia doktora dekretów w r został wybrany rektorem akademii a [('miesiącpóźniej', 0.44429731369018555), ('proustowskie', 0.41688796877861023), ('blisha', 0.40617096424102783)]
#  częstotliwością tonu liczbą drgań na sekundę określaną w hercach hz oraz natężeniem mierzonym w decybelach db bodźcami stosowanymi w at są tony proste mające charakterystykę [('sinusoidalną', 1.0), ('ukośną', 0.6631777882575989), ('mglistą', 0.6626798510551453)]
#  przodu i z powrotem manometry wskazują ptaszycy enie starszy maszynista daje mi znak powinienem się przecisnąć gruzach elektrycznej tuż przy grodzi wiszą na skrzynce z [('wyłącznikami', 0.9999998807907104), ('przykrywkami', 0.7862746715545654), ('bezpiecznikami', 0.7600491642951965)]

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM, Input, Embedding, Bidirectional, Dropout, LeakyReLU
from keras import optimizers, Model, activations
from gensim.models import Word2Vec

embedding_dim = len(model.wv)
vector_size = model.vector_size

# Train the LSTM model on the prepared data
kmodel = Sequential()
kmodel.add(Input(shape=(sequence_length, vector_size)))
kmodel.add(LSTM(512))
kmodel.add(Dense(vector_size))
kmodel.compile(loss="mse", optimizer=optimizers.Adam(1e-3))
kmodel.summary()


input_text = "nastał dzień w którym zbliżał się ślub królewskiego syna więc"
kmodel.fit(
    gen,
    epochs=1000,
    steps_per_epoch=5000,
    verbose=1,
    callbacks=[
        PredictCallback(model, input_text, max_len=sequence_length, randomize=True),
        PredictCallback(model, input_text, max_len=sequence_length, randomize=False),
        SaveCallback('../lstm_models/')
    ],
)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 512)               1255424
#
#  dense (Dense)               (None, 100)               51300
#
# =================================================================
# Total params: 1,306,724
# Trainable params: 1,306,724
# Non-trainable params: 0
# _________________________________________________________________
# Start epoch 0 of training; Generated text: nastał dzień w którym zbliżał się ślub królewskiego syna więc pczytywny łac nieświadomemu oczui kolor oznaczałoby wysysanie wyrzucanie
# Start epoch 0 of training; Generated text: nastał dzień w którym zbliżał się ślub królewskiego syna więc pczytywny pczytywny pczytywny nasuwający zwierzecia koszemego włosom poławiacze
# Epoch 1/1000
# 5000/5000 [==============================] - 37s 7ms/step - loss: 0.5145
# Start epoch 1 of training; Generated text: nastał dzień w którym zbliżał się ślub królewskiego syna więc rastatt koniecpolskich zawołocze brandenburgu lutzen altranstadt rządbw zawołocze
# Start epoch 1 of training; Generated text: nastał dzień w którym zbliżał się ślub królewskiego syna więc brandenburgu brandenburgu brandenburgu brandenburgu brandenburgu brandenburgu brandenburgu brandenburgu
# Epoch 2/1000
# 5000/5000 [==============================] - 36s 7ms/step - loss: 0.5083
# Start epoch 2 of training; Generated text: nastał dzień w którym zbliżał się ślub królewskiego syna więc niepołomicach altenburgu lutzen brandenburgu szunemitki lutzen brandenburgu miesiącpóźniej
# Start epoch 2 of training; Generated text: nastał dzień w którym zbliżał się ślub królewskiego syna więc brandenburgu brandenburgu brandenburgu brandenburgu brandenburgu brandenburgu brandenburgu brandenburgu
# Epoch 3/1000
# 5000/5000 [==============================] - 36s 7ms/step - loss: 0.5091
# Start epoch 3 of training; Generated text: nastał dzień w którym zbliżał się ślub królewskiego syna więc plemionizraelskich awulsów awulsów szekesfehervar lutzen szekesfehervar hesjakassel rządbw
# Start epoch 3 of training; Generated text: nastał dzień w którym zbliżał się ślub królewskiego syna więc brandenburgu brandenburgu brandenburgu brandenburgu brandenburgu rządbw rządbw rządbw
# Epoch 4/1000
# 5000/5000 [==============================] - 36s 7ms/step - loss: 0.5052
# Start epoch 4 of training; Generated text: nastał dzień w którym zbliżał się ślub królewskiego syna więc rządbw szunemitki szunemitki szunemitki rządbw rządbw rządbw znalazba
# Start epoch 4 of training; Generated text: nastał dzień w którym zbliżał się ślub królewskiego syna więc awulsów brandenburgu brandenburgu brandenburgu brandenburgu rządbw rządbw rządbw
# Epoch 5/1000
# 5000/5000 [==============================] - 36s 7ms/step - loss: 0.5060
# Start epoch 5 of training; Generated text: nastał dzień w którym zbliżał się ślub królewskiego syna więc szunemitki samsonów szunemitki samsonów awulsów nosia wyborcw samsonów
# Start epoch 5 of training; Generated text: nastał dzień w którym zbliżał się ślub królewskiego syna więc awulsów awulsów awulsów awulsów awulsów awulsów awulsów awulsów
# Epoch 6/1000
# 5000/5000 [==============================] - 36s 7ms/step - loss: 0.5059
# Start epoch 6 of training; Generated text: nastał dzień w którym zbliżał się ślub królewskiego syna więc oparkach oparkach septów alkowach awulsów nosia elbiety wyborcw
# Start epoch 6 of training; Generated text: nastał dzień w którym zbliżał się ślub królewskiego syna więc awulsów rządbw rządbw rządbw rządbw rządbw rządbw rządbw
# Epoch 7/1000
# 5000/5000 [==============================] - 36s 7ms/step - loss: 0.5068
# Start epoch 7 of training; Generated text: nastał dzień w którym zbliżał się ślub królewskiego syna więc lutzen lutzen zawołocze kongresowe brandenburgu zawołocze bośniackie wrzosowe
# Start epoch 7 of training; Generated text: nastał dzień w którym zbliżał się ślub królewskiego syna więc awulsów awulsów awulsów awulsów awulsów rządbw rządbw rządbw
# Epoch 8/1000
# 5000/5000 [==============================] - 36s 7ms/step - loss: 0.5047
# Start epoch 8 of training; Generated text: nastał dzień w którym zbliżał się ślub królewskiego syna więc pierwszychdniach samsonów samsonów rządbw pierwszychdniach samsonów rządbw dharme
# Start epoch 8 of training; Generated text: nastał dzień w którym zbliżał się ślub królewskiego syna więc awulsów awulsów awulsów awulsów awulsów rządbw rządbw rządbw
# Epoch 9/1000
# 5000/5000 [==============================] - 36s 7ms/step - loss: 0.5045
# Start epoch 9 of training; Generated text: nastał dzień w którym zbliżał się ślub królewskiego syna więc rządbw samsonów bośniackie lutzen nosia znalazba nosia szczliwej
# Start epoch 9 of training; Generated text: nastał dzień w którym zbliżał się ślub królewskiego syna więc awulsów awulsów awulsów awulsów awulsów rządbw rządbw rządbw
# Epoch 10/1000
# 5000/5000 [==============================] - 36s 7ms/step - loss: 0.5042
# Start epoch 10 of training; Generated text: nastał dzień w którym zbliżał się ślub królewskiego syna więc lutzen szunemitki utrechcie pierwszychdniach brandenburgu oparkach rządbw chanowe
# Start epoch 10 of training; Generated text: nastał dzień w którym zbliżał się ślub królewskiego syna więc awulsów awulsów awulsów awulsów awulsów awulsów awulsów awulsów
# Epoch 11/1000
# 5000/5000 [==============================] - 36s 7ms/step - loss: 0.5034
# Start epoch 11 of training; Generated text: nastał dzień w którym zbliżał się ślub królewskiego syna więc samsonów awulsów lutzen zawołocze altranstadt rządbw chanowe awulsów
# Start epoch 11 of training; Generated text: nastał dzień w którym zbliżał się ślub królewskiego syna więc awulsów awulsów awulsów awulsów awulsów rządbw rządbw rządbw
# Epoch 12/1000
# 5000/5000 [==============================] - 36s 7ms/step - loss: 0.5036
# Start epoch 12 of training; Generated text: nastał dzień w którym zbliżał się ślub królewskiego syna więc brandenburgu szunemitki bracławszczyźnie lutzen hericourt brandenburgu awulsów rządbw
# Start epoch 12 of training; Generated text: nastał dzień w którym zbliżał się ślub królewskiego syna więc brandenburgu awulsów awulsów awulsów awulsów awulsów awulsów awulsów
# Epoch 13/1000
# 5000/5000 [==============================] - 36s 7ms/step - loss: 0.5022
# Start epoch 13 of training; Generated text: nastał dzień w którym zbliżał się ślub królewskiego syna więc dharme oparkach chanowe rządbw zwinalem nosia rządbw leay
# Start epoch 13 of training; Generated text: nastał dzień w którym zbliżał się ślub królewskiego syna więc oparkach rządbw rządbw rządbw rządbw rządbw rządbw rządbw
# Epoch 14/1000
# 5000/5000 [==============================] - 36s 7ms/step - loss: 0.5029
# Start epoch 14 of training; Generated text: nastał dzień w którym zbliżał się ślub królewskiego syna więc altranstadt karłowicach brandenburgu miesiącpóźniej altranstadt bośniackie fortach miesiącpóźniej
# Start epoch 14 of training; Generated text: nastał dzień w którym zbliżał się ślub królewskiego syna więc altranstadt awulsów awulsów awulsów awulsów awulsów awulsów awulsów
# Epoch 15/1000
# 5000/5000 [==============================] - 36s 7ms/step - loss: 0.5038
# Start epoch 15 of training; Generated text: nastał dzień w którym zbliżał się ślub królewskiego syna więc chanowe elbiety hobbitanii hobbitanii hobbitanii oparkach hobbitanii chanowe
# Start epoch 15 of training; Generated text: nastał dzień w którym zbliżał się ślub królewskiego syna więc oparkach awulsów awulsów awulsów awulsów rządbw rządbw rządbw
# Epoch 16/1000
# 5000/5000 [==============================] - 37s 7ms/step - loss: 0.5038
# Start epoch 16 of training; Generated text: nastał dzień w którym zbliżał się ślub królewskiego syna więc altranstadt samsonów altranstadt oparkach oparkach awulsów ksiestwo altranstadt
# Start epoch 16 of training; Generated text: nastał dzień w którym zbliżał się ślub królewskiego syna więc altranstadt altranstadt altranstadt altranstadt altranstadt rządbw rządbw rządbw
# Epoch 17/1000
# 5000/5000 [==============================] - 37s 7ms/step - loss: 0.5017
# Start epoch 17 of training; Generated text: nastał dzień w którym zbliżał się ślub królewskiego syna więc samsonów szunemitki samsonów zawołocze bośniackie awulsów elbiety elbiety
# Start epoch 17 of training; Generated text: nastał dzień w którym zbliżał się ślub królewskiego syna więc awulsów awulsów awulsów awulsów awulsów awulsów awulsów awulsów
# Epoch 18/1000
# 5000/5000 [==============================] - 36s 7ms/step - loss: 0.5030
# Start epoch 18 of training; Generated text: nastał dzień w którym zbliżał się ślub królewskiego syna więc brandenburgu kongresowe sułtańskie samsonów lutzen chanowe nosia rządbw
# Start epoch 18 of training; Generated text: nastał dzień w którym zbliżał się ślub królewskiego syna więc ksawuni ksawuni ksawuni ksawuni ksawuni ksawuni nosia nosia
# Epoch 19/1000
# 5000/5000 [==============================] - 36s 7ms/step - loss: 0.5011
# Start epoch 19 of training; Generated text: nastał dzień w którym zbliżał się ślub królewskiego syna więc ksawuni rządbw bośniackie altranstadt predappio elbiety elbiety przyniosy
# Start epoch 19 of training; Generated text: nastał dzień w którym zbliżał się ślub królewskiego syna więc lutzen lutzen lutzen lutzen lutzen lutzen rządbw rządbw
# Epoch 20/1000
# 5000/5000 [==============================] - 36s 7ms/step - loss: 0.5050
# Start epoch 20 of training; Generated text: nastał dzień w którym zbliżał się ślub królewskiego syna więc szunemitki hobbitanii kongresowe bośniackie deerdell rządbw deerdell nosia
# Start epoch 20 of training; Generated text: nastał dzień w którym zbliżał się ślub królewskiego syna więc awulsów awulsów awulsów awulsów awulsów awulsów awulsów awulsów
# Epoch 21/1000
# 5000/5000 [==============================] - 36s 7ms/step - loss: 0.5032
# Start epoch 21 of training; Generated text: nastał dzień w którym zbliżał się ślub królewskiego syna więc karłowicach miesiącpóźniej rządbw karłowicach awulsów wyborcw nosia miesiącpóźniej
# Start epoch 21 of training; Generated text: nastał dzień w którym zbliżał się ślub królewskiego syna więc awulsów awulsów awulsów awulsów awulsów rządbw rządbw rządbw
# Epoch 22/1000
# 5000/5000 [==============================] - 36s 7ms/step - loss: 0.5033
# Start epoch 22 of training; Generated text: nastał dzień w którym zbliżał się ślub królewskiego syna więc bośniackie altranstadt bośniackie brandenburgu fortach rządbw nosia dharme
# Start epoch 22 of training; Generated text: nastał dzień w którym zbliżał się ślub królewskiego syna więc awulsów awulsów awulsów awulsów awulsów awulsów awulsów awulsów
# Epoch 23/1000
# 5000/5000 [==============================] - 36s 7ms/step - loss: 0.5030
# Start epoch 23 of training; Generated text: nastał dzień w którym zbliżał się ślub królewskiego syna więc alkowach awulsów miesiącpóźniej stokrotnych fortach nosia stokrotnych awulsów
# Start epoch 23 of training; Generated text: nastał dzień w którym zbliżał się ślub królewskiego syna więc awulsów awulsów awulsów awulsów awulsów awulsów awulsów awulsów
# Epoch 24/1000
# 5000/5000 [==============================] - 36s 7ms/step - loss: 0.5028
# Start epoch 24 of training; Generated text: nastał dzień w którym zbliżał się ślub królewskiego syna więc oparkach kongresowe wrzosowe rządbw awulsów oparkach chanowe dharme
# Start epoch 24 of training; Generated text: nastał dzień w którym zbliżał się ślub królewskiego syna więc awulsów awulsów awulsów awulsów awulsów awulsów awulsów awulsów
# Epoch 25/1000
# 5000/5000 [==============================] - 36s 7ms/step - loss: 0.5011
# Start epoch 25 of training; Generated text: nastał dzień w którym zbliżał się ślub królewskiego syna więc miesiącpóźniej brandenburgu bośniackie deerdell deerdell elbiety rządbw agarów
# Start epoch 25 of training; Generated text: nastał dzień w którym zbliżał się ślub królewskiego syna więc awulsów awulsów awulsów awulsów awulsów awulsów awulsów awulsów
# Epoch 26/1000
# 5000/5000 [==============================] - 36s 7ms/step - loss: 0.5039
# Start epoch 26 of training; Generated text: nastał dzień w którym zbliżał się ślub królewskiego syna więc miesiącpóźniej awulsów altranstadt kongresowe kongresowe nosia awulsów wrzosowe
# Start epoch 26 of training; Generated text: nastał dzień w którym zbliżał się ślub królewskiego syna więc ksawuni ksawuni ksawuni ksawuni ksawuni ksawuni ksawuni ksawuni
# Epoch 27/1000
# 5000/5000 [==============================] - 36s 7ms/step - loss: 0.5032
# Start epoch 27 of training; Generated text: nastał dzień w którym zbliżał się ślub królewskiego syna więc pierwszychdniach kongresowe bośniackie utrechcie brandenburgu miesiącpóźniej rastatt miesiącpóźniej
# Start epoch 27 of training; Generated text: nastał dzień w którym zbliżał się ślub królewskiego syna więc awulsów brandenburgu brandenburgu brandenburgu brandenburgu rządbw rządbw rządbw
# Epoch 28/1000
# 5000/5000 [==============================] - 36s 7ms/step - loss: 0.5015
# Start epoch 28 of training; Generated text: nastał dzień w którym zbliżał się ślub królewskiego syna więc ksawuni miesiącpóźniej miesiącpóźniej brandenburgu septów maciejowickiej septów brukowcach
# Start epoch 28 of training; Generated text: nastał dzień w którym zbliżał się ślub królewskiego syna więc brandenburgu brandenburgu brandenburgu brandenburgu brandenburgu rządbw rządbw rządbw
# Epoch 29/1000
# 5000/5000 [==============================] - 36s 7ms/step - loss: 0.5044
# Start epoch 29 of training; Generated text: nastał dzień w którym zbliżał się ślub królewskiego syna więc ksawuni altranstadt ksawuni miesiącpóźniej altranstadt suczawy dharme dharme
# Start epoch 29 of training; Generated text: nastał dzień w którym zbliżał się ślub królewskiego syna więc altranstadt altranstadt altranstadt altranstadt altranstadt rządbw rządbw rządbw
# Epoch 30/1000
# 5000/5000 [==============================] - 36s 7ms/step - loss: 0.5022
# Start epoch 30 of training; Generated text: nastał dzień w którym zbliżał się ślub królewskiego syna więc awulsów poczdamie poczdamie pierwszychdniach jałcie pierwszychdniach brandenburgu jałcie
# Start epoch 30 of training; Generated text: nastał dzień w którym zbliżał się ślub królewskiego syna więc brandenburgu brandenburgu brandenburgu brandenburgu brandenburgu brandenburgu rządbw rządbw
# Epoch 31/1000
# 5000/5000 [==============================] - 37s 7ms/step - loss: 0.5040
# Start epoch 31 of training; Generated text: nastał dzień w którym zbliżał się ślub królewskiego syna więc bośniackie lutzen zawołocze lutzen lutzen samsonów phnom phnom
# Start epoch 31 of training; Generated text: nastał dzień w którym zbliżał się ślub królewskiego syna więc brandenburgu brandenburgu brandenburgu brandenburgu brandenburgu brandenburgu awulsów awulsów
# Epoch 32/1000
# 1286/5000 [======>.......................] - ETA: 28s - loss: 0.5042
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 19
#      15 kmodel.summary()
#      18 input_text = "nastał dzień w którym zbliżał się ślub królewskiego syna więc"
# ---> 19 kmodel.fit(
#      20     gen,
#      21     epochs=1000,
#      22     steps_per_epoch=5000,
#      23     verbose=1,
#      24     callbacks=[
#      25         PredictCallback(model, input_text, max_len=sequence_length, randomize=True),
#      26         PredictCallback(model, input_text, max_len=sequence_length, randomize=False),
#      27         SaveCallback('../lstm_models/')
#      28     ],
#      29 )
#
# File e:\Program Files\Anaconda\envs\piat\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File e:\Program Files\Anaconda\envs\piat\lib\site-packages\keras\engine\training.py:1414, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1412 logs = tmp_logs  # No error, now safe to assign to logs.
#    1413 end_step = step + data_handler.step_increment
# -> 1414 callbacks.on_train_batch_end(end_step, logs)
#    1415 if self.stop_training:
#    1416   break
#
# File e:\Program Files\Anaconda\envs\piat\lib\site-packages\keras\callbacks.py:438, in CallbackList.on_train_batch_end(self, batch, logs)
#     431 """Calls the `on_train_batch_end` methods of its callbacks.
#     432
#     433 Args:
#     434     batch: Integer, index of batch within the current epoch.
#     435     logs: Dict. Aggregated metric results up until this batch.
#     436 """
#     437 if self._should_call_train_batch_hooks:
# --> 438   self._call_batch_hook(ModeKeys.TRAIN, 'end', batch, logs=logs)
#
# File e:\Program Files\Anaconda\envs\piat\lib\site-packages\keras\callbacks.py:297, in CallbackList._call_batch_hook(self, mode, hook, batch, logs)
#     295   self._call_batch_begin_hook(mode, batch, logs)
#     296 elif hook == 'end':
# --> 297   self._call_batch_end_hook(mode, batch, logs)
#     298 else:
#     299   raise ValueError(
#     300       f'Unrecognized hook: {hook}. Expected values are ["begin", "end"]')
#
# File e:\Program Files\Anaconda\envs\piat\lib\site-packages\keras\callbacks.py:318, in CallbackList._call_batch_end_hook(self, mode, batch, logs)
#     315   batch_time = time.time() - self._batch_start_time
#     316   self._batch_times.append(batch_time)
# --> 318 self._call_batch_hook_helper(hook_name, batch, logs)
#     320 if len(self._batch_times) >= self._num_batches_for_timing_check:
#     321   end_hook_name = hook_name
#
# File e:\Program Files\Anaconda\envs\piat\lib\site-packages\keras\callbacks.py:356, in CallbackList._call_batch_hook_helper(self, hook_name, batch, logs)
#     354 for callback in self.callbacks:
#     355   hook = getattr(callback, hook_name)
# --> 356   hook(batch, logs)
#     358 if self._check_timing:
#     359   if hook_name not in self._hook_times:
#
# File e:\Program Files\Anaconda\envs\piat\lib\site-packages\keras\callbacks.py:1034, in ProgbarLogger.on_train_batch_end(self, batch, logs)
#    1033 def on_train_batch_end(self, batch, logs=None):
# -> 1034   self._batch_update_progbar(batch, logs)
#
# File e:\Program Files\Anaconda\envs\piat\lib\site-packages\keras\callbacks.py:1107, in ProgbarLogger._batch_update_progbar(self, batch, logs)
#    1104 if self.verbose == 1:
#    1105   # Only block async when verbose = 1.
#    1106   logs = tf_utils.sync_to_numpy_or_python_type(logs)
# -> 1107   self.progbar.update(self.seen, list(logs.items()), finalize=False)
#
# File e:\Program Files\Anaconda\envs\piat\lib\site-packages\keras\utils\generic_utils.py:976, in Progbar.update(self, current, values, finalize)
#     973     info += '\n'
#     975   message += info
# --> 976   io_utils.print_msg(message, line_break=False)
#     977   message = ''
#     979 elif self.verbose == 2:
#
# File e:\Program Files\Anaconda\envs\piat\lib\site-packages\keras\utils\io_utils.py:78, in print_msg(message, line_break)
#      76   else:
#      77     sys.stdout.write(message)
# ---> 78   sys.stdout.flush()
#      79 else:
#      80   logging.info(message)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\ipykernel\iostream.py:497, in OutStream.flush(self)
#     495     self.pub_thread.schedule(evt.set)
#     496     # and give a timeout to avoid
# --> 497     if not evt.wait(self.flush_timeout):
#     498         # write directly to __stderr__ instead of warning because
#     499         # if this is happening sys.stderr may be the problem.
#     500         print("IOStream.flush timed out", file=sys.__stderr__)
#     501 else:
#
# File e:\Program Files\Anaconda\envs\piat\lib\threading.py:607, in Event.wait(self, timeout)
#     605 signaled = self._flag
#     606 if not signaled:
# --> 607     signaled = self._cond.wait(timeout)
#     608 return signaled
#
# File e:\Program Files\Anaconda\envs\piat\lib\threading.py:324, in Condition.wait(self, timeout)
#     322 else:
#     323     if timeout > 0:
# --> 324         gotit = waiter.acquire(True, timeout)
#     325     else:
#     326         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
# Example usage
input_text = "Czy grube mury twierdz zakonnych ogromne bogactwa skrzętna niemal fanatyczna gospodarność straszliwy głód władzy nie stanowią znaków głębokiego duchowego konfliktu chrześcijan znaków braku zaufania do Bożych obietnic znaków rozpaczliwych starań"
num_words_to_generate = 16
generated_text = generate_text1(
    kmodel, model, input_text.lower(), num_words_to_generate, max_len=sequence_length
)
print(generated_text)
# Out:
# czy grube mury twierdz zakonnych ogromne bogactwa skrzętna niemal fanatyczna gospodarność straszliwy głód władzy nie stanowią znaków głębokiego duchowego konfliktu chrześcijan znaków braku zaufania do bożych obietnic znaków rozpaczliwych starań zgubnych zgubnych występków obłędnych obłędnych obłędnych obłędnych obłędnych obłędnych obłędnych obłędnych obłędnych obłędnych obłędnych obłędnych obłędnych
